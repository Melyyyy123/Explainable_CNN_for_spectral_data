# %% [markdown]
# # Optimal Model

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import random
import math

from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold, TimeSeriesSplit
from mlxtend.evaluate import GroupTimeSeriesSplit
from mlxtend.evaluate.time_series import plot_splits
from sklearn.metrics import mean_squared_error, r2_score

import keras

import tensorflow as tf
from tensorflow.keras.layers import MaxPooling1D
from tensorflow.keras import layers
import datetime

# %load_ext tensorboard
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %%
# GPU Availability Check
print(f"TensorFlow version: {tf.__version__}")
gpus = tf.config.experimental.list_physical_devices('GPU')
print(f"Num GPUs Available: {len(gpus)}")

# List all physical devices
physical_devices = tf.config.list_physical_devices()
print("\n📱 All Physical Devices:")
for device in physical_devices:
    print(f"  {device}")

# Check if TensorFlow is built with CUDA support
print(f"\n🔧 CUDA Support: {tf.test.is_built_with_cuda()}")

# Prevent TensorFlow from allocating all GPU memory at once
if gpus:
    try:
        # Enable memory growth for each GPU
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        print(f"✅ Memory growth enabled for {len(gpus)} GPU(s)")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(f"❌ Error setting memory growth: {e}")
        
# tf.keras.mixed_precision.set_global_policy('mixed_float16')
# Out:
# TensorFlow version: 2.16.1
# Num GPUs Available: 0
#
# 📱 All Physical Devices:
#   PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')
#
# 🔧 CUDA Support: True

# %%
def set_reproducible(seed=12345):
    np.random.seed(seed)
    random.seed(seed)
    tf.random.set_seed(seed)
    keras.utils.set_random_seed(seed)

# %%
dps1200 = pd.read_csv("../../data/dps1200.csv")
dps1200 = dps1200[dps1200["year"] >= 1800]
dps1200 = dps1200.sort_values("year", ascending=True)
print(dps1200.shape)
dps1200.head()
# Out:
# (575, 414)
#       year       tree Origin    type     X2970     X2968     X2966     X2964  \
# 821   1800      JMS7a    FIN  living  0.021011  0.021199  0.021412  0.021632
# 1192  1801   SZLPS08a    AUT  living  0.016859  0.017079  0.017309  0.017557
# 394   1801     Bre029    NOR   water  0.019230  0.019520  0.019827  0.020153
# 947   1801      LUO8a    FIN  living  0.020787  0.021227  0.021688  0.022151
# 268   1802  BHNPS193a    AUT  constr  0.017848  0.018055  0.018265  0.018482
#
#          X2962     X2960  ...      X818      X816      X814      X812  \
# 821   0.021853  0.022087  ... -0.025427 -0.025378 -0.025341 -0.025321
# 1192  0.017827  0.018115  ... -0.018325 -0.018201 -0.018095 -0.018010
# 394   0.020490  0.020822  ... -0.021681 -0.021514 -0.021360 -0.021229
# 947   0.022604  0.023049  ... -0.022127 -0.022025 -0.021931 -0.021851
# 268   0.018713  0.018962  ... -0.018974 -0.018840 -0.018722 -0.018627
#
#           X810      X808      X806      X804      X802      X800
# 821  -0.025318 -0.025326 -0.025347 -0.025387 -0.025442 -0.025503
# 1192 -0.017949 -0.017914 -0.017908 -0.017935 -0.017990 -0.018064
# 394  -0.021131 -0.021068 -0.021037 -0.021038 -0.021070 -0.021125
# 947  -0.021795 -0.021769 -0.021770 -0.021796 -0.021841 -0.021903
# 268  -0.018559 -0.018519 -0.018508 -0.018525 -0.018568 -0.018631
#
# [5 rows x 414 columns]

# %%
dpa = pd.read_csv("../../data/dpa.csv")
dpa = dpa[dpa["year"] >= 1800]
dpa = dpa.sort_values("year", ascending=True)
print(dpa.shape)
dpa.head()
# Out:
# (327, 414)
#       year origin  Jahr     X3996     X2970     X2968     X2966     X2964  \
# 658   1800    SWS  1800  0.011154  0.018527  0.018810  0.019103  0.019405
# 521   1800    DST  1800  0.010303  0.017534  0.017898  0.018272  0.018653
# 1498  1800    WIE  1800  0.016896  0.017539  0.017709  0.017885  0.018058
# 373   1801    DST  1801  0.015178  0.018400  0.018671  0.018954  0.019247
# 419   1801    DST  1801  0.005733  0.015686  0.016034  0.016397  0.016774
#
#          X2962     X2960  ...      X818      X816      X814      X812  \
# 658   0.019715  0.020033  ... -0.021223 -0.021109 -0.021012 -0.020936
# 521   0.019039  0.019431  ... -0.020985 -0.020822 -0.020683 -0.020574
# 1498  0.018231  0.018422  ... -0.023917 -0.023788 -0.023676 -0.023586
# 373   0.019551  0.019866  ... -0.021866 -0.021789 -0.021727 -0.021685
# 419   0.017165  0.017569  ... -0.018596 -0.018426 -0.018277 -0.018157
#
#           X810      X808      X806      X804      X802      X800
# 658  -0.020887 -0.020866 -0.020876 -0.020915 -0.020980 -0.021068
# 521  -0.020504 -0.020474 -0.020486 -0.020540 -0.020633 -0.020758
# 1498 -0.023522 -0.023489 -0.023486 -0.023509 -0.023560 -0.023635
# 373  -0.021666 -0.021674 -0.021708 -0.021769 -0.021855 -0.021962
# 419  -0.018072 -0.018027 -0.018022 -0.018057 -0.018129 -0.018234
#
# [5 rows x 414 columns]

# %%
daa = pd.read_csv("../../data/daa.csv")
daa = daa[daa["year"] >= 1800]
daa = daa.sort_values("year", ascending=True)
print(daa.shape)
daa.head()
# Out:
# (268, 414)
#      year origin  Jahr     X3996     X2970     X2968     X2966     X2964  \
# 684  1800    WIE  1800  0.009552  0.018023  0.018200  0.018379  0.018557
# 682  1800    WIE  1800  0.003135  0.012487  0.012566  0.012661  0.012760
# 448  1800    WFA  1800  0.008141  0.017552  0.017774  0.018003  0.018239
# 352  1800    WFA  1800  0.006262  0.017778  0.018066  0.018364  0.018669
# 407  1800    WFA  1800  0.008700  0.016876  0.017095  0.017325  0.017567
#
#         X2962     X2960  ...      X818      X816      X814      X812  \
# 684  0.018730  0.018902  ... -0.020795 -0.020624 -0.020473 -0.020346
# 682  0.012853  0.012950  ... -0.018802 -0.018652 -0.018516 -0.018399
# 448  0.018483  0.018736  ... -0.019149 -0.019014 -0.018895 -0.018801
# 352  0.018981  0.019303  ... -0.018022 -0.017905 -0.017807 -0.017732
# 407  0.017819  0.018081  ... -0.019397 -0.019227 -0.019073 -0.018945
#
#          X810      X808      X806      X804      X802      X800
# 684 -0.020250 -0.020191 -0.020173 -0.020194 -0.020244 -0.020316
# 682 -0.018305 -0.018237 -0.018200 -0.018192 -0.018209 -0.018241
# 448 -0.018735 -0.018700 -0.018697 -0.018724 -0.018780 -0.018861
# 352 -0.017685 -0.017670 -0.017686 -0.017733 -0.017808 -0.017908
# 407 -0.018847 -0.018785 -0.018759 -0.018769 -0.018814 -0.018889
#
# [5 rows x 414 columns]

# %%
frames = [dps1200, dpa, daa]

result = pd.concat(frames)
result = result.sort_values("year", ascending=True)
result.head()

#result = dps1200  # comment out to use all datasets
# Out:
#      year   tree Origin    type     X2970     X2968     X2966     X2964  \
# 821  1800  JMS7a    FIN  living  0.021011  0.021199  0.021412  0.021632
# 658  1800    NaN    NaN     NaN  0.018527  0.018810  0.019103  0.019405
# 521  1800    NaN    NaN     NaN  0.017534  0.017898  0.018272  0.018653
# 407  1800    NaN    NaN     NaN  0.016876  0.017095  0.017325  0.017567
# 448  1800    NaN    NaN     NaN  0.017552  0.017774  0.018003  0.018239
#
#         X2962     X2960  ...      X812      X810      X808      X806  \
# 821  0.021853  0.022087  ... -0.025321 -0.025318 -0.025326 -0.025347
# 658  0.019715  0.020033  ... -0.020936 -0.020887 -0.020866 -0.020876
# 521  0.019039  0.019431  ... -0.020574 -0.020504 -0.020474 -0.020486
# 407  0.017819  0.018081  ... -0.018945 -0.018847 -0.018785 -0.018759
# 448  0.018483  0.018736  ... -0.018801 -0.018735 -0.018700 -0.018697
#
#          X804      X802      X800  origin    Jahr     X3996
# 821 -0.025387 -0.025442 -0.025503     NaN     NaN       NaN
# 658 -0.020915 -0.020980 -0.021068     SWS  1800.0  0.011154
# 521 -0.020540 -0.020633 -0.020758     DST  1800.0  0.010303
# 407 -0.018769 -0.018814 -0.018889     WFA  1800.0  0.008700
# 448 -0.018724 -0.018780 -0.018861     WFA  1800.0  0.008141
#
# [5 rows x 417 columns]

# %%
features = result.iloc[:, 4:414].values
labels = result.iloc[:, 0].values
print(features.shape)
# Out:
# (1170, 410)

# %%
def convertToDecade(y:int) -> int: 
    return int(str(y)[:3])

def calculate_sample_weights(y_train):

    decades = [convertToDecade(year) for year in y_train]

    unique_decades, counts = np.unique(decades, return_counts=True)
    total_samples = len(y_train)
    
    weights = {}
    for decade, count in zip(unique_decades, counts):
        weights[decade] = 1 - count/total_samples

    sample_weights = []
    for year in y_train:
        sample_weights.append(weights[convertToDecade(year)])
        
    return np.array(sample_weights)

# %%
# Add learning rate scheduling callback
def create_lr_scheduler():
    # reduces LR when validation loss plateaus
    scheduler = tf.keras.callbacks.ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=80,
        min_lr=1e-6,
        verbose=1
    )
    return scheduler

# %%
def create_optimizer():
    # opt = keras.optimizers.AdamW(learning_rate=0.001, weight_decay=1e-5)  # causes underfitting?
    opt = keras.optimizers.Adam(learning_rate=0.001)
    return opt

# %%
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (
    Input, Conv1D, BatchNormalization, Activation, Add,
    MaxPooling1D, GlobalAveragePooling1D, Dense, Concatenate
)

# best so far at loss around 3e-4
# praise be Gemini Pro 2.5, https://g.co/gemini/share/e3f26b1e78f3
def inception_residual_module(input_tensor, num_filters):
    """
    The core building block of the network. It processes data at multiple scales
    and includes a residual connection for stable training.
    """
    # Use a 1x1 convolution as a "bottleneck" to reduce computational cost
    bottleneck = Conv1D(filters=num_filters // 4, kernel_size=1, padding='same', use_bias=False)(input_tensor)
    bottleneck = BatchNormalization()(bottleneck)
    bottleneck = Activation('relu')(bottleneck)

    # --- Parallel branches for multi-scale feature extraction ---
    # Small kernel for sharp peaks
    branch1 = Conv1D(filters=num_filters // 4, kernel_size=3, padding='same', use_bias=False)(bottleneck)

    # Medium kernel for wider features
    branch2 = Conv1D(filters=num_filters // 2, kernel_size=7, padding='same', use_bias=False)(bottleneck)
    
    # Large kernel for broad shapes
    branch3 = Conv1D(filters=num_filters // 4, kernel_size=11, padding='same', use_bias=False)(bottleneck)

    # Combine the features from all branches
    concatenated = Concatenate()([branch1, branch2, branch3])
    
    # Final 1x1 convolution to restore the desired number of filters
    final_conv = Conv1D(filters=num_filters, kernel_size=1, padding='same', use_bias=False)(concatenated)
    final_conv = BatchNormalization()(final_conv)

    # --- Residual Connection ---
    # Add the original input to the output of the convoluted path.
    # This helps prevent vanishing gradients in a deep network.
    if input_tensor.shape[-1] != num_filters:
        shortcut = Conv1D(filters=num_filters, kernel_size=1, padding='same', use_bias=False)(input_tensor)
        shortcut = BatchNormalization()(shortcut)
    else:
        shortcut = input_tensor
        
    output = Add()([final_conv, shortcut])
    output = Activation('relu')(output)
    
    return output

def build_wood_age_incepresnet(input_dim):
    """
    Constructs the full Inception-Residual model.
    """

    inputs = Input(shape=(input_dim, 1))

    # --- Stem: Initial Feature Extraction ---
    # A standard convolution to process the raw input and reduce dimensionality.
    x = Conv1D(filters=64, kernel_size=13, strides=2, padding='same', use_bias=False)(inputs)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling1D(pool_size=3, strides=2, padding='same')(x)

    # --- Core Blocks: Deep Feature Learning ---
    # Stack the custom modules to learn increasingly complex features.
    x = inception_residual_module(x, num_filters=128)
    x = inception_residual_module(x, num_filters=128)
    x = MaxPooling1D(pool_size=3, strides=2, padding='same')(x)

    x = inception_residual_module(x, num_filters=256)
    x = inception_residual_module(x, num_filters=256)
    x = MaxPooling1D(pool_size=3, strides=2, padding='same')(x)

    # --- Head: Final Prediction ---
    # Global Average Pooling is the key to fighting overfitting.
    # It creates one feature per filter, summarizing the entire spectrum.
    x = GlobalAveragePooling1D()(x)
    
    # A small dense head for the final regression output.
    x = Dense(64, activation='relu')(x)
    outputs = Dense(1, activation='linear', name='age_output')(x)

    model = Model(inputs=inputs, outputs=outputs)
    model.compile(loss=tf.keras.losses.Huber(), optimizer=create_optimizer(), metrics=['mean_absolute_error', 'root_mean_squared_error'])
    model.summary()

    return model, 'incepresnet'

# %% [markdown]
# # Crossvalidation

# %% [markdown]
# Since NN training involves random sampling and weights initialization (in this case), it is usefull to use cross-validation.

# %%
## Compute error metrics
def error_metrics(y_true_train, y_predicted_train, y_true_test, y_predicted_test):
    rmse_train = np.sqrt(mean_squared_error(y_true_train, y_predicted_train))
    rmse_test = np.sqrt(mean_squared_error(y_true_test, y_predicted_test))
    R2_train= r2_score(y_true_train, y_predicted_train)
    R2_test= r2_score(y_true_test, y_predicted_test)
    h = tf.keras.losses.Huber()
    hub_train = h(y_true_train, y_predicted_train).numpy()
    hub_test = h(y_true_test, y_predicted_test).numpy()
    
    print('*********** Benchmark results ***********\n')
    print(f"R2    (Train/Test) = {R2_train:.3f} / {R2_test:.3f}")
    print(f"RMSE  (Train/Test) = {rmse_train:.3f} / {rmse_test:.3f}")
    print(f"Huber (Train/Test) = {hub_train:.3f} / {hub_test:.3f}")

    return (rmse_train, rmse_test, R2_train, R2_test, hub_train, hub_test)

class ModelWithData:
    def __init__(self, history, train_x, train_label, train_predicted, test_x, test_label, test_predicted, score:float, model) -> None:
        self.history = history
        self.train_x = train_x
        self.train_label = train_label
        self.train_predicted = train_predicted
        self.test_x = test_x
        self.test_label = test_label
        self.test_predicted = test_predicted
        self.score = score
        self.model = model

    def isBetter(self, otherScore: float) -> bool:
        return otherScore < 0 or (self.score >= 0 and self.score <= otherScore)

EMPTY_MWD = ModelWithData(None, 0, 0, 0, 0, 0, 0, -1, None)

# %%
def calculate_groups(years, years_in_group=100):
    groups = np.zeros(len(years))

    for i in range(len(years)):
        groups[i] = years[i] // years_in_group
    
    print("Groups:")
    print(groups)
    return groups

# %%
class HarmonizedTimeSplit:
    def __init__(self, validation_portion=0.1, random_seed=12345):
        self._validation_portion = validation_portion
        self._random_seed = random_seed
        self._random = random.Random(random_seed)

    def split(self, X, y = None, groups = None):

        if groups is None:
            raise ValueError("The groups should be specified")
        
        self._random = random.Random(self._random_seed)
        group_dict = self._calculate_group_indices(groups)
        train_indices = []
        test_indices = []

        for group_start, group_end in group_dict.values():
            group_indices = []

            for index in range(group_start, group_end):
                group_indices.append(index)
            
            self._random.shuffle(group_indices)

            validation_end = math.floor(len(group_indices)*self._validation_portion)

            if validation_end <= 0:
                train_indices.extend(group_indices)
            else:
                test_indices.extend(group_indices[:validation_end])
                train_indices.extend(group_indices[validation_end:])

        yield np.asarray(sorted(train_indices)), np.asarray(sorted(test_indices))

        
    def _calculate_group_indices(self, groups) -> dict[str, tuple[int,int]]:
        group_dict = {}
        current_group = None

        for index in range(len(groups)):
            group = str(groups[index])

            if group in group_dict:
                if group != current_group:
                    raise ValueError(f"The groups should be specified in consequtive order. Found group '{group}' again at index {index}")
            else:
                if current_group is not None:
                    (current_group_start, current_group_end) = group_dict[current_group]
                    group_dict[current_group] = (current_group_start, index)
                
                current_group = group
                group_dict[group] = (index, len(groups))

        return group_dict

    def plot_splits(self, groups):
        for train_indices, test_indices in self.split(None, None, groups):
            self._plot_split(train_indices, test_indices, groups)
    
    def _plot_split(self, train_indices, test_indices, groups):
        group_dict = self._calculate_group_indices(groups)

        train_in_group = np.zeros(len(group_dict))
        test_in_group = np.zeros(len(group_dict))
        groups = sorted(group_dict.keys())

        for group_index, group_name in enumerate(groups):
            (group_start, group_end) = group_dict[group_name]
            train_in_group[group_index] = self._count_in_group(train_indices, group_start, group_end)
            test_in_group[group_index] = self._count_in_group(test_indices, group_start, group_end)

        x_values = np.arange(len(groups))
        width = 0.33

        rects = plt.bar(x_values, train_in_group, width, color='k', label='Train')
        plt.bar_label(rects, padding=3)
        rects = plt.bar(x_values + width, test_in_group, width, color='r', label='Test')
        plt.bar_label(rects, padding=3)

        # Labels, legend, and title
        plt.xlabel('Groups')
        plt.xticks(x_values + width/2, groups)
        plt.ylabel('Sample Count')
        plt.legend()
        plt.title('Distribution of Train vs Test in Split')

        # Show the plot
        plt.show()
    
    def _count_in_group(self, indices, group_start, group_end):
        count = 0
        for train_index in indices:
            if train_index >= group_start and train_index < group_end:
                count += 1
            elif train_index >= group_end:
                break

        return count

# %%
hts = HarmonizedTimeSplit(validation_portion=0.1)
y = np.array(labels)
groups = calculate_groups(y, 100)
hts.plot_splits(groups)
# Out:
# Groups:
# [18. 18. 18. ... 20. 20. 20.]

# %%
def evaluations_of_models(features, labels, seed=12345, epochs=100, years_in_group=100, validation_portion=0.01):

    # batch_size = 128
    batch_size = 45
    set_reproducible(seed)

    x = np.array(features, dtype=np.float32)  # Convert to float32 upfront
    y_int = np.array(labels)
    y = y_int.astype(np.float32)  # Use float32
    
    groups = calculate_groups(y_int, years_in_group)
    input_dim = 410
    
    # Ensure proper shape for CNN (add channel dimension if needed)
    if x.ndim == 2:
        x = x.reshape((x.shape[0], x.shape[1], 1))
    
    x_full_tensor = tf.convert_to_tensor(x, dtype=tf.float32)
    y_full_tensor = tf.convert_to_tensor(y, dtype=tf.float32)

    model, name = build_wood_age_incepresnet(input_dim)

    # Define the number of folds for Cross-Validation
    hts = HarmonizedTimeSplit(validation_portion=validation_portion)
    hts.plot_splits(groups)

    scores_train = { "rmse": [], "r2": [], "huber": []}
    scores_test = { "rmse": [], "r2": [], "huber": []}

    bestMwd = EMPTY_MWD

    tensorboard_base_dir = "tb_logs"

    all_mwds = []
    
    for train_index, test_index in hts.split(x, y, groups):
        set_reproducible(seed)

        tensorboard_log_dir = f"{tensorboard_base_dir}/{name}/{seed}"
        tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=tensorboard_log_dir)
        
        # Early stopping to prevent overfitting
        # early_stopping = tf.keras.callbacks.EarlyStopping(
        #     monitor='val_loss',
        #     patience=300,
        #     restore_best_weights=True,
        #     verbose=1
        # )
        
        x_train_tensor = tf.gather(x_full_tensor, train_index)
        y_train_tensor = tf.gather(y_full_tensor, train_index)
        x_test_tensor = tf.gather(x_full_tensor, test_index)
        y_test_tensor = tf.gather(y_full_tensor, test_index)
        x_train = x[train_index]
        y_train = y[train_index]
        x_test = x[test_index]
        y_test = y[test_index]
        
        sample_weight = calculate_sample_weights(y_int[train_index])
        sample_weight_tensor = tf.convert_to_tensor(sample_weight, dtype=tf.float32)
        
        weight_dataset = tf.data.Dataset.from_tensor_slices(sample_weight_tensor)
        
        train_dataset_with_weights = tf.data.Dataset.zip((
            tf.data.Dataset.from_tensor_slices(x_train_tensor),
            tf.data.Dataset.from_tensor_slices(y_train_tensor), 
            weight_dataset
        ))
        
        train_dataset_with_weights = train_dataset_with_weights.shuffle(buffer_size=len(train_index))
        train_dataset_with_weights = train_dataset_with_weights.batch(batch_size)
        train_dataset_with_weights = train_dataset_with_weights.prefetch(tf.data.AUTOTUNE)

        val_dataset = tf.data.Dataset.from_tensor_slices((x_test_tensor, y_test_tensor))
        val_dataset = val_dataset.batch(batch_size).prefetch(tf.data.AUTOTUNE)
        
        callbacks = [tensorboard_callback]
        callbacks += [create_lr_scheduler()]
        # callbacks += [early_stopping]
        
        history = model.fit(train_dataset_with_weights,
                            epochs=epochs,
                            validation_data=val_dataset,
                            verbose=1,
                            callbacks=callbacks)
        
        #evaluation_results = model.evaluate(val_dataset, verbose=0)
        #evaluation_labels = model.metrics_names

        #for j in range(len(evaluation_results)):
        #    print(f'{evaluation_labels[j]}: {evaluation_results[j]}')

        train_pred_dataset = tf.data.Dataset.from_tensor_slices(x_train_tensor).batch(batch_size)
        test_pred_dataset = tf.data.Dataset.from_tensor_slices(x_test_tensor).batch(batch_size)
        train_pred = model.predict(train_pred_dataset, verbose=0)
        test_pred = model.predict(test_pred_dataset, verbose=0)

        train_pred = train_pred.flatten()  # Remove extra dimensions
        test_pred = test_pred.flatten()

        (rmse_train, rmse_test, r2_train, r2_test, huber_train, huber_test) = error_metrics(y_train, train_pred, y_test, test_pred)

        mwd = ModelWithData(history, x_train, y_train, train_pred, x_test, y_test, test_pred, rmse_train, model)

        all_mwds.append(mwd)

        if mwd.isBetter(bestMwd.score):
            bestMwd = mwd

        scores_train["rmse"].append(rmse_train)
        scores_train["r2"].append(r2_train)
        scores_train["huber"].append(huber_train)

        scores_test["rmse"].append(rmse_test)
        scores_test["r2"].append(r2_test)
        scores_test["huber"].append(huber_test)

    ## clear session 
    tf.keras.backend.clear_session()

    scores_train_mean = {}
    scores_test_mean = {}
    num_model = len(scores_train["rmse"])

    for metric in scores_train.keys():
        scores_train_mean[metric] = np.mean(scores_train[metric])
        scores_test_mean[metric] = np.mean(scores_test[metric])
        print(f'Train: {metric} (mean of {num_model} models)= {scores_train_mean[metric]} \nTest: {metric} (mean of {num_model} models)= {scores_test_mean[metric]}')
    
    return (bestMwd, all_mwds)

# %%
seeds = [3173 ]#, 6113, 1]
all_mwds : list[ModelWithData] = []

for seed in seeds:
    print(f"Using seed {seed}")
    (bestMwd, all_mwds_of_run) = evaluations_of_models(features, labels, seed=seed, epochs=261, years_in_group=100, validation_portion=0.1)
    all_mwds.extend(all_mwds_of_run)

# 260 rmse 19/24
# Out:
# Using seed 3173
# Groups:
# [18. 18. 18. ... 20. 20. 20.]
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 410, 1)    │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d (Conv1D)     │ (None, 205, 64)   │        832 │ input_layer[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 205, 64)   │        256 │ conv1d[0][0]      │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 205, 64)   │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d       │ (None, 103, 64)   │          0 │ activation[0][0]  │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_1 (Conv1D)   │ (None, 103, 32)   │      2,048 │ max_pooling1d[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 103, 32)   │        128 │ conv1d_1[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 103, 32)   │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_2 (Conv1D)   │ (None, 103, 32)   │      3,072 │ activation_1[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_3 (Conv1D)   │ (None, 103, 64)   │     14,336 │ activation_1[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_4 (Conv1D)   │ (None, 103, 32)   │     11,264 │ activation_1[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 103, 128)  │          0 │ conv1d_2[0][0],   │
# │ (Concatenate)       │                   │            │ conv1d_3[0][0],   │
# │                     │                   │            │ conv1d_4[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_5 (Conv1D)   │ (None, 103, 128)  │     16,384 │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_6 (Conv1D)   │ (None, 103, 128)  │      8,192 │ max_pooling1d[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 103, 128)  │        512 │ conv1d_5[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 103, 128)  │        512 │ conv1d_6[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 103, 128)  │          0 │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 103, 128)  │          0 │ add[0][0]         │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_7 (Conv1D)   │ (None, 103, 32)   │      4,096 │ activation_2[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 103, 32)   │        128 │ conv1d_7[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 103, 32)   │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_8 (Conv1D)   │ (None, 103, 32)   │      3,072 │ activation_3[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_9 (Conv1D)   │ (None, 103, 64)   │     14,336 │ activation_3[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_10 (Conv1D)  │ (None, 103, 32)   │     11,264 │ activation_3[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 103, 128)  │          0 │ conv1d_8[0][0],   │
# │ (Concatenate)       │                   │            │ conv1d_9[0][0],   │
# │                     │                   │            │ conv1d_10[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_11 (Conv1D)  │ (None, 103, 128)  │     16,384 │ concatenate_1[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 103, 128)  │        512 │ conv1d_11[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 103, 128)  │          0 │ batch_normalizat… │
# │                     │                   │            │ activation_2[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 103, 128)  │          0 │ add_1[0][0]       │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d_1     │ (None, 52, 128)   │          0 │ activation_4[0][… │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_12 (Conv1D)  │ (None, 52, 64)    │      8,192 │ max_pooling1d_1[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 52, 64)    │        256 │ conv1d_12[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (None, 52, 64)    │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_13 (Conv1D)  │ (None, 52, 64)    │     12,288 │ activation_5[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_14 (Conv1D)  │ (None, 52, 128)   │     57,344 │ activation_5[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_15 (Conv1D)  │ (None, 52, 64)    │     45,056 │ activation_5[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 52, 256)   │          0 │ conv1d_13[0][0],  │
# │ (Concatenate)       │                   │            │ conv1d_14[0][0],  │
# │                     │                   │            │ conv1d_15[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_16 (Conv1D)  │ (None, 52, 256)   │     65,536 │ concatenate_2[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_17 (Conv1D)  │ (None, 52, 256)   │     32,768 │ max_pooling1d_1[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 52, 256)   │      1,024 │ conv1d_16[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 52, 256)   │      1,024 │ conv1d_17[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 52, 256)   │          0 │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_6        │ (None, 52, 256)   │          0 │ add_2[0][0]       │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_18 (Conv1D)  │ (None, 52, 64)    │     16,384 │ activation_6[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 52, 64)    │        256 │ conv1d_18[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_7        │ (None, 52, 64)    │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_19 (Conv1D)  │ (None, 52, 64)    │     12,288 │ activation_7[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_20 (Conv1D)  │ (None, 52, 128)   │     57,344 │ activation_7[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_21 (Conv1D)  │ (None, 52, 64)    │     45,056 │ activation_7[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 52, 256)   │          0 │ conv1d_19[0][0],  │
# │ (Concatenate)       │                   │            │ conv1d_20[0][0],  │
# │                     │                   │            │ conv1d_21[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_22 (Conv1D)  │ (None, 52, 256)   │     65,536 │ concatenate_3[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 52, 256)   │      1,024 │ conv1d_22[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 52, 256)   │          0 │ batch_normalizat… │
# │                     │                   │            │ activation_6[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_8        │ (None, 52, 256)   │          0 │ add_3[0][0]       │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d_2     │ (None, 26, 256)   │          0 │ activation_8[0][… │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 256)       │          0 │ max_pooling1d_2[… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 64)        │     16,448 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ age_output (Dense)  │ (None, 1)         │         65 │ dense[0][0]       │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 545,217 (2.08 MB)
#  Trainable params: 542,401 (2.07 MB)
#  Non-trainable params: 2,816 (11.00 KB)
# Epoch 1/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 1788.7905 - mean_absolute_error: 1880.2000 - root_mean_squared_error: 1881.1892 - val_loss: 1906.0059 - val_mean_absolute_error: 1896.3031 - val_root_mean_squared_error: 1897.1229 - learning_rate: 0.0010
# Epoch 2/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1660.1069 - mean_absolute_error: 1744.8705 - root_mean_squared_error: 1746.3207 - val_loss: 1886.4232 - val_mean_absolute_error: 1876.7207 - val_root_mean_squared_error: 1877.5491 - learning_rate: 0.0010
# Epoch 3/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1380.8170 - mean_absolute_error: 1451.3971 - root_mean_squared_error: 1454.3794 - val_loss: 1840.5625 - val_mean_absolute_error: 1830.8616 - val_root_mean_squared_error: 1831.7103 - learning_rate: 0.0010
# Epoch 4/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 949.4373 - mean_absolute_error: 998.3344 - root_mean_squared_error: 1005.1983 - val_loss: 1755.0358 - val_mean_absolute_error: 1745.3384 - val_root_mean_squared_error: 1746.2284 - learning_rate: 0.0010
# Epoch 5/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 376.6922 - mean_absolute_error: 396.6452 - root_mean_squared_error: 422.8493 - val_loss: 1623.2421 - val_mean_absolute_error: 1613.5483 - val_root_mean_squared_error: 1614.5100 - learning_rate: 0.0010
# Epoch 6/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 69.5639 - mean_absolute_error: 73.5653 - root_mean_squared_error: 97.3702 - val_loss: 1325.4049 - val_mean_absolute_error: 1315.7588 - val_root_mean_squared_error: 1316.9331 - learning_rate: 0.0010
# Epoch 7/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 40.7074 - mean_absolute_error: 43.2191 - root_mean_squared_error: 54.6805 - val_loss: 970.4111 - val_mean_absolute_error: 960.7495 - val_root_mean_squared_error: 962.3652 - learning_rate: 0.0010
# Epoch 8/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 32.9386 - mean_absolute_error: 35.0788 - root_mean_squared_error: 43.8202 - val_loss: 928.3211 - val_mean_absolute_error: 918.7877 - val_root_mean_squared_error: 920.4509 - learning_rate: 0.0010
# Epoch 9/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 32.8524 - mean_absolute_error: 35.0099 - root_mean_squared_error: 43.7342 - val_loss: 943.3152 - val_mean_absolute_error: 933.8127 - val_root_mean_squared_error: 935.4376 - learning_rate: 0.0010
# Epoch 10/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 27.4206 - mean_absolute_error: 29.2855 - root_mean_squared_error: 37.3009 - val_loss: 843.1775 - val_mean_absolute_error: 833.7746 - val_root_mean_squared_error: 835.5770 - learning_rate: 0.0010
# Epoch 11/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 29.1200 - mean_absolute_error: 31.1060 - root_mean_squared_error: 38.9958 - val_loss: 818.8264 - val_mean_absolute_error: 809.4597 - val_root_mean_squared_error: 811.3264 - learning_rate: 0.0010
# Epoch 12/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 24.9130 - mean_absolute_error: 26.6508 - root_mean_squared_error: 34.2052 - val_loss: 831.7836 - val_mean_absolute_error: 822.4630 - val_root_mean_squared_error: 824.3041 - learning_rate: 0.0010
# Epoch 13/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 24.4076 - mean_absolute_error: 26.0817 - root_mean_squared_error: 33.7353 - val_loss: 830.7829 - val_mean_absolute_error: 821.4034 - val_root_mean_squared_error: 823.2557 - learning_rate: 0.0010
# Epoch 14/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 27.8887 - mean_absolute_error: 29.7882 - root_mean_squared_error: 38.2214 - val_loss: 798.7791 - val_mean_absolute_error: 789.4887 - val_root_mean_squared_error: 791.3953 - learning_rate: 0.0010
# Epoch 15/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 25.6560 - mean_absolute_error: 27.4416 - root_mean_squared_error: 35.2481 - val_loss: 798.8564 - val_mean_absolute_error: 789.8663 - val_root_mean_squared_error: 791.7086 - learning_rate: 0.0010
# Epoch 16/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 25.3620 - mean_absolute_error: 27.1434 - root_mean_squared_error: 36.2092 - val_loss: 792.5371 - val_mean_absolute_error: 783.7934 - val_root_mean_squared_error: 785.6345 - learning_rate: 0.0010
# Epoch 17/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 23.8008 - mean_absolute_error: 25.5037 - root_mean_squared_error: 32.4798 - val_loss: 831.7066 - val_mean_absolute_error: 823.3444 - val_root_mean_squared_error: 825.0558 - learning_rate: 0.0010
# Epoch 18/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 23.9534 - mean_absolute_error: 25.6516 - root_mean_squared_error: 33.6641 - val_loss: 733.3040 - val_mean_absolute_error: 724.7441 - val_root_mean_squared_error: 726.7809 - learning_rate: 0.0010
# Epoch 19/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 22.2832 - mean_absolute_error: 23.8762 - root_mean_squared_error: 31.4100 - val_loss: 658.7656 - val_mean_absolute_error: 650.4546 - val_root_mean_squared_error: 652.9117 - learning_rate: 0.0010
# Epoch 20/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 23.4568 - mean_absolute_error: 25.1369 - root_mean_squared_error: 32.2629 - val_loss: 634.4747 - val_mean_absolute_error: 626.6771 - val_root_mean_squared_error: 629.2568 - learning_rate: 0.0010
# Epoch 21/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 25.9184 - mean_absolute_error: 27.7259 - root_mean_squared_error: 34.7123 - val_loss: 460.0479 - val_mean_absolute_error: 451.9194 - val_root_mean_squared_error: 456.0494 - learning_rate: 0.0010
# Epoch 22/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 24.2938 - mean_absolute_error: 25.9861 - root_mean_squared_error: 33.2043 - val_loss: 359.7161 - val_mean_absolute_error: 351.6228 - val_root_mean_squared_error: 357.5109 - learning_rate: 0.0010
# Epoch 23/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 21.9157 - mean_absolute_error: 23.4954 - root_mean_squared_error: 31.3202 - val_loss: 314.4808 - val_mean_absolute_error: 306.1278 - val_root_mean_squared_error: 313.9504 - learning_rate: 0.0010
# Epoch 24/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 25.2609 - mean_absolute_error: 27.0220 - root_mean_squared_error: 33.9918 - val_loss: 122.7737 - val_mean_absolute_error: 115.7972 - val_root_mean_squared_error: 130.6701 - learning_rate: 0.0010
# Epoch 25/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 28.3961 - mean_absolute_error: 30.3536 - root_mean_squared_error: 39.0068 - val_loss: 151.1968 - val_mean_absolute_error: 143.6597 - val_root_mean_squared_error: 157.5597 - learning_rate: 0.0010
# Epoch 26/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 23.4197 - mean_absolute_error: 25.0751 - root_mean_squared_error: 32.1135 - val_loss: 208.3289 - val_mean_absolute_error: 200.6153 - val_root_mean_squared_error: 212.3708 - learning_rate: 0.0010
# Epoch 27/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 23.6888 - mean_absolute_error: 25.3354 - root_mean_squared_error: 32.9636 - val_loss: 169.1987 - val_mean_absolute_error: 162.8937 - val_root_mean_squared_error: 171.6127 - learning_rate: 0.0010
# Epoch 28/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 21.4633 - mean_absolute_error: 23.0572 - root_mean_squared_error: 29.8219 - val_loss: 113.0645 - val_mean_absolute_error: 107.8865 - val_root_mean_squared_error: 118.6430 - learning_rate: 0.0010
# Epoch 29/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 24.5176 - mean_absolute_error: 26.2405 - root_mean_squared_error: 33.3692 - val_loss: 52.0547 - val_mean_absolute_error: 48.6369 - val_root_mean_squared_error: 58.3137 - learning_rate: 0.0010
# Epoch 30/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 21.7887 - mean_absolute_error: 23.3741 - root_mean_squared_error: 29.8885 - val_loss: 36.4870 - val_mean_absolute_error: 39.2042 - val_root_mean_squared_error: 49.5219 - learning_rate: 0.0010
# Epoch 31/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 24.9953 - mean_absolute_error: 26.7567 - root_mean_squared_error: 34.2680 - val_loss: 87.0270 - val_mean_absolute_error: 90.6289 - val_root_mean_squared_error: 99.3439 - learning_rate: 0.0010
# Epoch 32/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 24.2434 - mean_absolute_error: 25.9610 - root_mean_squared_error: 32.3742 - val_loss: 91.0151 - val_mean_absolute_error: 94.0592 - val_root_mean_squared_error: 101.2248 - learning_rate: 0.0010
# Epoch 33/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 23.0804 - mean_absolute_error: 24.7251 - root_mean_squared_error: 32.2671 - val_loss: 149.9227 - val_mean_absolute_error: 152.9068 - val_root_mean_squared_error: 156.9983 - learning_rate: 0.0010
# Epoch 34/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 20.7620 - mean_absolute_error: 22.3129 - root_mean_squared_error: 29.5861 - val_loss: 56.2885 - val_mean_absolute_error: 59.0794 - val_root_mean_squared_error: 67.7772 - learning_rate: 0.0010
# Epoch 35/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 21.1055 - mean_absolute_error: 22.6487 - root_mean_squared_error: 28.9178 - val_loss: 67.7918 - val_mean_absolute_error: 70.5604 - val_root_mean_squared_error: 78.0935 - learning_rate: 0.0010
# Epoch 36/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 19.8893 - mean_absolute_error: 21.3825 - root_mean_squared_error: 29.1810 - val_loss: 39.6634 - val_mean_absolute_error: 41.1832 - val_root_mean_squared_error: 51.4323 - learning_rate: 0.0010
# Epoch 37/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 22.4327 - mean_absolute_error: 24.0760 - root_mean_squared_error: 31.4855 - val_loss: 54.7695 - val_mean_absolute_error: 57.1890 - val_root_mean_squared_error: 64.4397 - learning_rate: 0.0010
# Epoch 38/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 20.6733 - mean_absolute_error: 22.2157 - root_mean_squared_error: 29.1402 - val_loss: 32.4276 - val_mean_absolute_error: 32.9555 - val_root_mean_squared_error: 38.2392 - learning_rate: 0.0010
# Epoch 39/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 23.5625 - mean_absolute_error: 25.2530 - root_mean_squared_error: 32.4995 - val_loss: 72.7378 - val_mean_absolute_error: 74.3450 - val_root_mean_squared_error: 80.9853 - learning_rate: 0.0010
# Epoch 40/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 21.7705 - mean_absolute_error: 23.3778 - root_mean_squared_error: 31.1876 - val_loss: 87.8473 - val_mean_absolute_error: 89.7209 - val_root_mean_squared_error: 96.8487 - learning_rate: 0.0010
# Epoch 41/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 20.9562 - mean_absolute_error: 22.5002 - root_mean_squared_error: 29.9941 - val_loss: 30.8476 - val_mean_absolute_error: 30.9101 - val_root_mean_squared_error: 36.6375 - learning_rate: 0.0010
# Epoch 42/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 20.3600 - mean_absolute_error: 21.8689 - root_mean_squared_error: 28.9687 - val_loss: 29.5541 - val_mean_absolute_error: 31.5675 - val_root_mean_squared_error: 40.2743 - learning_rate: 0.0010
# Epoch 43/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 19.5961 - mean_absolute_error: 21.0628 - root_mean_squared_error: 27.4656 - val_loss: 74.2471 - val_mean_absolute_error: 75.1565 - val_root_mean_squared_error: 81.5645 - learning_rate: 0.0010
# Epoch 44/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 19.4420 - mean_absolute_error: 20.9099 - root_mean_squared_error: 28.1106 - val_loss: 30.2032 - val_mean_absolute_error: 31.7572 - val_root_mean_squared_error: 40.7425 - learning_rate: 0.0010
# Epoch 45/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 18.6197 - mean_absolute_error: 20.0523 - root_mean_squared_error: 26.8468 - val_loss: 30.0563 - val_mean_absolute_error: 30.3427 - val_root_mean_squared_error: 37.0046 - learning_rate: 0.0010
# Epoch 46/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 20.3863 - mean_absolute_error: 21.8757 - root_mean_squared_error: 28.3878 - val_loss: 61.7536 - val_mean_absolute_error: 60.6367 - val_root_mean_squared_error: 67.0044 - learning_rate: 0.0010
# Epoch 47/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 21.6796 - mean_absolute_error: 23.2690 - root_mean_squared_error: 30.0990 - val_loss: 40.5509 - val_mean_absolute_error: 42.2641 - val_root_mean_squared_error: 51.3539 - learning_rate: 0.0010
# Epoch 48/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 19.9643 - mean_absolute_error: 21.4692 - root_mean_squared_error: 27.6483 - val_loss: 24.6106 - val_mean_absolute_error: 25.4872 - val_root_mean_squared_error: 31.9294 - learning_rate: 0.0010
# Epoch 49/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 20.4321 - mean_absolute_error: 21.9819 - root_mean_squared_error: 28.3839 - val_loss: 99.6782 - val_mean_absolute_error: 97.4393 - val_root_mean_squared_error: 102.3332 - learning_rate: 0.0010
# Epoch 50/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 20.4487 - mean_absolute_error: 21.9694 - root_mean_squared_error: 28.7048 - val_loss: 101.6104 - val_mean_absolute_error: 103.0372 - val_root_mean_squared_error: 109.0174 - learning_rate: 0.0010
# Epoch 51/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 20.2426 - mean_absolute_error: 21.7602 - root_mean_squared_error: 28.0396 - val_loss: 39.3008 - val_mean_absolute_error: 38.3721 - val_root_mean_squared_error: 44.5462 - learning_rate: 0.0010
# Epoch 52/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 19.4695 - mean_absolute_error: 20.9503 - root_mean_squared_error: 28.1905 - val_loss: 51.8547 - val_mean_absolute_error: 51.2947 - val_root_mean_squared_error: 58.3325 - learning_rate: 0.0010
# Epoch 53/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 21.1375 - mean_absolute_error: 22.7072 - root_mean_squared_error: 28.8784 - val_loss: 24.2119 - val_mean_absolute_error: 25.7452 - val_root_mean_squared_error: 34.9006 - learning_rate: 0.0010
# Epoch 54/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 19.7873 - mean_absolute_error: 21.2858 - root_mean_squared_error: 28.2840 - val_loss: 27.2680 - val_mean_absolute_error: 28.0246 - val_root_mean_squared_error: 33.7405 - learning_rate: 0.0010
# Epoch 55/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 24.9154 - mean_absolute_error: 26.6898 - root_mean_squared_error: 33.6519 - val_loss: 76.5478 - val_mean_absolute_error: 78.4063 - val_root_mean_squared_error: 84.8458 - learning_rate: 0.0010
# Epoch 56/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 20.6373 - mean_absolute_error: 22.1632 - root_mean_squared_error: 28.6009 - val_loss: 114.4269 - val_mean_absolute_error: 115.3956 - val_root_mean_squared_error: 119.3294 - learning_rate: 0.0010
# Epoch 57/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 24.7943 - mean_absolute_error: 26.5346 - root_mean_squared_error: 33.9203 - val_loss: 27.3100 - val_mean_absolute_error: 29.3581 - val_root_mean_squared_error: 38.3113 - learning_rate: 0.0010
# Epoch 58/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 20.4006 - mean_absolute_error: 21.9250 - root_mean_squared_error: 28.2441 - val_loss: 271.9171 - val_mean_absolute_error: 273.3726 - val_root_mean_squared_error: 275.4642 - learning_rate: 0.0010
# Epoch 59/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 24.3161 - mean_absolute_error: 26.0537 - root_mean_squared_error: 32.2042 - val_loss: 169.9820 - val_mean_absolute_error: 171.1342 - val_root_mean_squared_error: 174.9265 - learning_rate: 0.0010
# Epoch 60/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 21.1919 - mean_absolute_error: 22.7286 - root_mean_squared_error: 29.4884 - val_loss: 149.6104 - val_mean_absolute_error: 151.1354 - val_root_mean_squared_error: 154.5806 - learning_rate: 0.0010
# Epoch 61/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 21.6891 - mean_absolute_error: 23.2859 - root_mean_squared_error: 30.5305 - val_loss: 108.0537 - val_mean_absolute_error: 109.3463 - val_root_mean_squared_error: 113.8241 - learning_rate: 0.0010
# Epoch 62/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 18.9354 - mean_absolute_error: 20.3820 - root_mean_squared_error: 27.2424 - val_loss: 59.9974 - val_mean_absolute_error: 61.0665 - val_root_mean_squared_error: 68.0420 - learning_rate: 0.0010
# Epoch 63/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 17.3387 - mean_absolute_error: 18.7173 - root_mean_squared_error: 24.7707 - val_loss: 61.0187 - val_mean_absolute_error: 60.0246 - val_root_mean_squared_error: 65.7071 - learning_rate: 0.0010
# Epoch 64/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 17.4284 - mean_absolute_error: 18.8070 - root_mean_squared_error: 25.2981 - val_loss: 49.2371 - val_mean_absolute_error: 51.7248 - val_root_mean_squared_error: 59.3911 - learning_rate: 0.0010
# Epoch 65/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 19.3699 - mean_absolute_error: 20.8312 - root_mean_squared_error: 27.8531 - val_loss: 70.6388 - val_mean_absolute_error: 68.3204 - val_root_mean_squared_error: 74.7849 - learning_rate: 0.0010
# Epoch 66/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 22.4805 - mean_absolute_error: 24.1111 - root_mean_squared_error: 30.3037 - val_loss: 174.2532 - val_mean_absolute_error: 176.3021 - val_root_mean_squared_error: 178.8691 - learning_rate: 0.0010
# Epoch 67/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 19.7803 - mean_absolute_error: 21.2724 - root_mean_squared_error: 28.1375 - val_loss: 84.2432 - val_mean_absolute_error: 86.5361 - val_root_mean_squared_error: 91.7708 - learning_rate: 0.0010
# Epoch 68/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 18.6997 - mean_absolute_error: 20.1414 - root_mean_squared_error: 26.6093 - val_loss: 49.5836 - val_mean_absolute_error: 52.1210 - val_root_mean_squared_error: 60.1107 - learning_rate: 0.0010
# Epoch 69/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 19.0632 - mean_absolute_error: 20.5191 - root_mean_squared_error: 26.3817 - val_loss: 73.8684 - val_mean_absolute_error: 75.8153 - val_root_mean_squared_error: 81.7640 - learning_rate: 0.0010
# Epoch 70/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 21.3519 - mean_absolute_error: 22.8975 - root_mean_squared_error: 28.9988 - val_loss: 40.9028 - val_mean_absolute_error: 39.8992 - val_root_mean_squared_error: 45.7670 - learning_rate: 0.0010
# Epoch 71/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 19.0701 - mean_absolute_error: 20.5240 - root_mean_squared_error: 26.8238 - val_loss: 44.1462 - val_mean_absolute_error: 44.9756 - val_root_mean_squared_error: 52.1290 - learning_rate: 0.0010
# Epoch 72/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 19.6837 - mean_absolute_error: 21.1758 - root_mean_squared_error: 27.6646 - val_loss: 34.1576 - val_mean_absolute_error: 36.5548 - val_root_mean_squared_error: 45.9132 - learning_rate: 0.0010
# Epoch 73/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 17.6950 - mean_absolute_error: 19.0824 - root_mean_squared_error: 25.2224 - val_loss: 27.6473 - val_mean_absolute_error: 27.7209 - val_root_mean_squared_error: 31.8900 - learning_rate: 0.0010
# Epoch 74/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 16.5577 - mean_absolute_error: 17.8860 - root_mean_squared_error: 23.6908 - val_loss: 80.7319 - val_mean_absolute_error: 79.6315 - val_root_mean_squared_error: 85.4723 - learning_rate: 0.0010
# Epoch 75/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 17.7563 - mean_absolute_error: 19.1638 - root_mean_squared_error: 24.9993 - val_loss: 23.8234 - val_mean_absolute_error: 24.6015 - val_root_mean_squared_error: 31.0693 - learning_rate: 0.0010
# Epoch 76/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 17.1549 - mean_absolute_error: 18.4870 - root_mean_squared_error: 24.4777 - val_loss: 23.1190 - val_mean_absolute_error: 24.5040 - val_root_mean_squared_error: 31.2479 - learning_rate: 0.0010
# Epoch 77/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 24.1844 - mean_absolute_error: 25.8888 - root_mean_squared_error: 32.9504 - val_loss: 81.5416 - val_mean_absolute_error: 82.9376 - val_root_mean_squared_error: 88.4554 - learning_rate: 0.0010
# Epoch 78/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 19.2245 - mean_absolute_error: 20.6921 - root_mean_squared_error: 26.4181 - val_loss: 51.1082 - val_mean_absolute_error: 52.9981 - val_root_mean_squared_error: 59.4846 - learning_rate: 0.0010
# Epoch 79/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 18.7700 - mean_absolute_error: 20.2076 - root_mean_squared_error: 26.0756 - val_loss: 85.6999 - val_mean_absolute_error: 87.1467 - val_root_mean_squared_error: 92.6272 - learning_rate: 0.0010
# Epoch 80/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 19.4319 - mean_absolute_error: 20.8861 - root_mean_squared_error: 27.0439 - val_loss: 138.9665 - val_mean_absolute_error: 140.8711 - val_root_mean_squared_error: 143.5904 - learning_rate: 0.0010
# Epoch 81/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 20.9421 - mean_absolute_error: 22.4891 - root_mean_squared_error: 29.1143 - val_loss: 33.7961 - val_mean_absolute_error: 35.8460 - val_root_mean_squared_error: 44.8585 - learning_rate: 0.0010
# Epoch 82/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 22.7930 - mean_absolute_error: 24.4662 - root_mean_squared_error: 31.5233 - val_loss: 100.9844 - val_mean_absolute_error: 102.4387 - val_root_mean_squared_error: 106.8231 - learning_rate: 0.0010
# Epoch 83/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 21.4769 - mean_absolute_error: 23.0493 - root_mean_squared_error: 30.0018 - val_loss: 102.8174 - val_mean_absolute_error: 104.0442 - val_root_mean_squared_error: 108.5754 - learning_rate: 0.0010
# Epoch 84/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 19.5287 - mean_absolute_error: 21.0119 - root_mean_squared_error: 26.8009 - val_loss: 76.4345 - val_mean_absolute_error: 77.0034 - val_root_mean_squared_error: 83.6724 - learning_rate: 0.0010
# Epoch 85/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 18.7968 - mean_absolute_error: 20.2556 - root_mean_squared_error: 26.8537 - val_loss: 95.6079 - val_mean_absolute_error: 97.5425 - val_root_mean_squared_error: 102.0919 - learning_rate: 0.0010
# Epoch 86/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 18.7376 - mean_absolute_error: 20.1794 - root_mean_squared_error: 27.0205 - val_loss: 31.0725 - val_mean_absolute_error: 32.9015 - val_root_mean_squared_error: 40.7289 - learning_rate: 0.0010
# Epoch 87/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 15.0986 - mean_absolute_error: 16.3322 - root_mean_squared_error: 21.5900 - val_loss: 28.8502 - val_mean_absolute_error: 28.8994 - val_root_mean_squared_error: 33.0048 - learning_rate: 0.0010
# Epoch 88/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 18.8626 - mean_absolute_error: 20.2997 - root_mean_squared_error: 26.2863 - val_loss: 52.7286 - val_mean_absolute_error: 54.1625 - val_root_mean_squared_error: 60.9989 - learning_rate: 0.0010
# Epoch 89/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 17.2127 - mean_absolute_error: 18.5769 - root_mean_squared_error: 24.3698 - val_loss: 53.0601 - val_mean_absolute_error: 54.2498 - val_root_mean_squared_error: 61.0207 - learning_rate: 0.0010
# Epoch 90/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 19.2254 - mean_absolute_error: 20.7033 - root_mean_squared_error: 26.4305 - val_loss: 37.9808 - val_mean_absolute_error: 39.3271 - val_root_mean_squared_error: 46.4863 - learning_rate: 0.0010
# Epoch 91/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 18.5433 - mean_absolute_error: 19.9844 - root_mean_squared_error: 26.1721 - val_loss: 58.7131 - val_mean_absolute_error: 60.3317 - val_root_mean_squared_error: 66.4754 - learning_rate: 0.0010
# Epoch 92/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 17.6603 - mean_absolute_error: 19.0447 - root_mean_squared_error: 25.0340 - val_loss: 49.3770 - val_mean_absolute_error: 48.1027 - val_root_mean_squared_error: 55.9328 - learning_rate: 0.0010
# Epoch 93/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 19.9944 - mean_absolute_error: 21.5206 - root_mean_squared_error: 27.5566 - val_loss: 26.7246 - val_mean_absolute_error: 26.6566 - val_root_mean_squared_error: 31.2223 - learning_rate: 0.0010
# Epoch 94/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 17.3136 - mean_absolute_error: 18.6736 - root_mean_squared_error: 24.4352 - val_loss: 71.5574 - val_mean_absolute_error: 70.2993 - val_root_mean_squared_error: 75.6765 - learning_rate: 0.0010
# Epoch 95/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 18.9897 - mean_absolute_error: 20.4400 - root_mean_squared_error: 26.1412 - val_loss: 79.8722 - val_mean_absolute_error: 81.1127 - val_root_mean_squared_error: 87.0905 - learning_rate: 0.0010
# Epoch 96/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 17.3776 - mean_absolute_error: 18.7577 - root_mean_squared_error: 24.6521 - val_loss: 30.0751 - val_mean_absolute_error: 30.4584 - val_root_mean_squared_error: 36.3590 - learning_rate: 0.0010
# Epoch 97/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 19.4572 - mean_absolute_error: 20.9509 - root_mean_squared_error: 27.1252 - val_loss: 27.2624 - val_mean_absolute_error: 27.4180 - val_root_mean_squared_error: 32.6458 - learning_rate: 0.0010
# Epoch 98/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 17.2638 - mean_absolute_error: 18.6375 - root_mean_squared_error: 24.8551 - val_loss: 25.8666 - val_mean_absolute_error: 27.0035 - val_root_mean_squared_error: 34.7978 - learning_rate: 0.0010
# Epoch 99/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 18.2988 - mean_absolute_error: 19.7039 - root_mean_squared_error: 25.6568 - val_loss: 64.3194 - val_mean_absolute_error: 65.3508 - val_root_mean_squared_error: 71.5284 - learning_rate: 0.0010
# Epoch 100/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 19.0300 - mean_absolute_error: 20.4907 - root_mean_squared_error: 26.8935 - val_loss: 67.4674 - val_mean_absolute_error: 66.9336 - val_root_mean_squared_error: 73.3581 - learning_rate: 0.0010
# Epoch 101/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 19.7631 - mean_absolute_error: 21.2454 - root_mean_squared_error: 27.7369 - val_loss: 39.9607 - val_mean_absolute_error: 41.2728 - val_root_mean_squared_error: 49.4890 - learning_rate: 0.0010
# Epoch 102/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 20.2075 - mean_absolute_error: 21.7279 - root_mean_squared_error: 28.3849 - val_loss: 40.6816 - val_mean_absolute_error: 42.1027 - val_root_mean_squared_error: 50.1116 - learning_rate: 0.0010
# Epoch 103/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 18.5424 - mean_absolute_error: 19.9573 - root_mean_squared_error: 26.3701 - val_loss: 38.0119 - val_mean_absolute_error: 39.9087 - val_root_mean_squared_error: 47.1320 - learning_rate: 0.0010
# Epoch 104/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 19.1454 - mean_absolute_error: 20.6066 - root_mean_squared_error: 26.8857 - val_loss: 25.6636 - val_mean_absolute_error: 27.1878 - val_root_mean_squared_error: 35.1323 - learning_rate: 0.0010
# Epoch 105/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 17.4830 - mean_absolute_error: 18.8595 - root_mean_squared_error: 25.1336 - val_loss: 39.6986 - val_mean_absolute_error: 39.0449 - val_root_mean_squared_error: 44.8479 - learning_rate: 0.0010
# Epoch 106/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 18.0785 - mean_absolute_error: 19.4777 - root_mean_squared_error: 25.4999 - val_loss: 25.4627 - val_mean_absolute_error: 27.2242 - val_root_mean_squared_error: 35.5808 - learning_rate: 0.0010
# Epoch 107/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 16.0810 - mean_absolute_error: 17.3760 - root_mean_squared_error: 23.1397 - val_loss: 45.4779 - val_mean_absolute_error: 47.4103 - val_root_mean_squared_error: 53.6460 - learning_rate: 0.0010
# Epoch 108/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 17.1190 - mean_absolute_error: 18.4807 - root_mean_squared_error: 24.7966 - val_loss: 72.8982 - val_mean_absolute_error: 74.7976 - val_root_mean_squared_error: 79.9288 - learning_rate: 0.0010
# Epoch 109/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 18.2470 - mean_absolute_error: 19.6549 - root_mean_squared_error: 25.9343 - val_loss: 24.9575 - val_mean_absolute_error: 26.6464 - val_root_mean_squared_error: 34.3279 - learning_rate: 0.0010
# Epoch 110/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 16.9411 - mean_absolute_error: 18.2803 - root_mean_squared_error: 23.9272 - val_loss: 26.6230 - val_mean_absolute_error: 26.2854 - val_root_mean_squared_error: 31.2567 - learning_rate: 0.0010
# Epoch 111/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 17.6336 - mean_absolute_error: 19.0317 - root_mean_squared_error: 24.6382 - val_loss: 83.0115 - val_mean_absolute_error: 84.9524 - val_root_mean_squared_error: 89.7084 - learning_rate: 0.0010
# Epoch 112/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 18.3199 - mean_absolute_error: 19.7299 - root_mean_squared_error: 25.7580 - val_loss: 71.4908 - val_mean_absolute_error: 72.8478 - val_root_mean_squared_error: 77.9692 - learning_rate: 0.0010
# Epoch 113/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 21.8563 - mean_absolute_error: 23.4760 - root_mean_squared_error: 29.4142 - val_loss: 45.9069 - val_mean_absolute_error: 48.7338 - val_root_mean_squared_error: 57.2898 - learning_rate: 0.0010
# Epoch 114/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 19.5868 - mean_absolute_error: 21.0873 - root_mean_squared_error: 26.8898 - val_loss: 61.7534 - val_mean_absolute_error: 62.4467 - val_root_mean_squared_error: 67.7464 - learning_rate: 0.0010
# Epoch 115/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 17.1955 - mean_absolute_error: 18.5540 - root_mean_squared_error: 24.2019 - val_loss: 141.1652 - val_mean_absolute_error: 142.6839 - val_root_mean_squared_error: 145.5243 - learning_rate: 0.0010
# Epoch 116/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 18.6262 - mean_absolute_error: 20.0426 - root_mean_squared_error: 26.2865 - val_loss: 53.6739 - val_mean_absolute_error: 55.3348 - val_root_mean_squared_error: 61.8502 - learning_rate: 0.0010
# Epoch 117/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 15.8013 - mean_absolute_error: 17.0960 - root_mean_squared_error: 23.2020 - val_loss: 42.8434 - val_mean_absolute_error: 44.0265 - val_root_mean_squared_error: 50.5502 - learning_rate: 0.0010
# Epoch 118/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 16.3005 - mean_absolute_error: 17.6265 - root_mean_squared_error: 23.1025 - val_loss: 24.3180 - val_mean_absolute_error: 24.6193 - val_root_mean_squared_error: 30.6978 - learning_rate: 0.0010
# Epoch 119/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 16.4117 - mean_absolute_error: 17.7084 - root_mean_squared_error: 24.1108 - val_loss: 59.0249 - val_mean_absolute_error: 58.6016 - val_root_mean_squared_error: 64.0952 - learning_rate: 0.0010
# Epoch 120/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 19.2499 - mean_absolute_error: 20.7163 - root_mean_squared_error: 26.8316 - val_loss: 30.4032 - val_mean_absolute_error: 31.6308 - val_root_mean_squared_error: 39.9602 - learning_rate: 0.0010
# Epoch 121/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 17.7405 - mean_absolute_error: 19.1451 - root_mean_squared_error: 24.4673 - val_loss: 24.0616 - val_mean_absolute_error: 24.1912 - val_root_mean_squared_error: 29.3207 - learning_rate: 0.0010
# Epoch 122/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 22.5363 - mean_absolute_error: 24.1781 - root_mean_squared_error: 30.0087 - val_loss: 25.8426 - val_mean_absolute_error: 27.0608 - val_root_mean_squared_error: 35.2580 - learning_rate: 0.0010
# Epoch 123/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 19.4606 - mean_absolute_error: 20.9291 - root_mean_squared_error: 27.5477 - val_loss: 69.0246 - val_mean_absolute_error: 67.6433 - val_root_mean_squared_error: 73.4856 - learning_rate: 0.0010
# Epoch 124/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 17.9318 - mean_absolute_error: 19.3312 - root_mean_squared_error: 25.2105 - val_loss: 35.7545 - val_mean_absolute_error: 35.0132 - val_root_mean_squared_error: 40.8812 - learning_rate: 0.0010
# Epoch 125/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 16.7685 - mean_absolute_error: 18.0856 - root_mean_squared_error: 23.6502 - val_loss: 66.6793 - val_mean_absolute_error: 65.5907 - val_root_mean_squared_error: 72.4562 - learning_rate: 0.0010
# Epoch 126/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 18.0956 - mean_absolute_error: 19.5148 - root_mean_squared_error: 24.9382 - val_loss: 22.9453 - val_mean_absolute_error: 23.5570 - val_root_mean_squared_error: 28.5048 - learning_rate: 0.0010
# Epoch 127/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 17.4884 - mean_absolute_error: 18.8792 - root_mean_squared_error: 25.0184 - val_loss: 21.6196 - val_mean_absolute_error: 23.1143 - val_root_mean_squared_error: 30.2432 - learning_rate: 0.0010
# Epoch 128/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 16.2503 - mean_absolute_error: 17.5439 - root_mean_squared_error: 23.6928 - val_loss: 29.1247 - val_mean_absolute_error: 29.5916 - val_root_mean_squared_error: 33.8454 - learning_rate: 0.0010
# Epoch 129/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 18.7192 - mean_absolute_error: 20.1743 - root_mean_squared_error: 26.6288 - val_loss: 42.1167 - val_mean_absolute_error: 44.8331 - val_root_mean_squared_error: 51.9566 - learning_rate: 0.0010
# Epoch 130/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 17.3969 - mean_absolute_error: 18.7480 - root_mean_squared_error: 24.6593 - val_loss: 59.3522 - val_mean_absolute_error: 61.1855 - val_root_mean_squared_error: 67.3490 - learning_rate: 0.0010
# Epoch 131/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 17.1652 - mean_absolute_error: 18.5324 - root_mean_squared_error: 23.8509 - val_loss: 30.7558 - val_mean_absolute_error: 32.9464 - val_root_mean_squared_error: 41.0611 - learning_rate: 0.0010
# Epoch 132/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 17.3358 - mean_absolute_error: 18.6956 - root_mean_squared_error: 25.0783 - val_loss: 24.5791 - val_mean_absolute_error: 26.2558 - val_root_mean_squared_error: 34.0506 - learning_rate: 0.0010
# Epoch 133/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 19.6642 - mean_absolute_error: 21.1592 - root_mean_squared_error: 26.7793 - val_loss: 59.4006 - val_mean_absolute_error: 60.1286 - val_root_mean_squared_error: 65.7248 - learning_rate: 0.0010
# Epoch 134/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 15.5362 - mean_absolute_error: 16.7801 - root_mean_squared_error: 22.3411 - val_loss: 62.1304 - val_mean_absolute_error: 64.2851 - val_root_mean_squared_error: 70.7496 - learning_rate: 0.0010
# Epoch 135/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 18.1409 - mean_absolute_error: 19.5610 - root_mean_squared_error: 25.0340 - val_loss: 61.1585 - val_mean_absolute_error: 61.9664 - val_root_mean_squared_error: 68.3103 - learning_rate: 0.0010
# Epoch 136/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 15.6865 - mean_absolute_error: 16.9902 - root_mean_squared_error: 22.6730 - val_loss: 64.5022 - val_mean_absolute_error: 65.7716 - val_root_mean_squared_error: 70.9585 - learning_rate: 0.0010
# Epoch 137/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 15.7444 - mean_absolute_error: 17.0357 - root_mean_squared_error: 23.3067 - val_loss: 27.4571 - val_mean_absolute_error: 29.2432 - val_root_mean_squared_error: 36.9066 - learning_rate: 0.0010
# Epoch 138/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 14.9859 - mean_absolute_error: 16.2270 - root_mean_squared_error: 21.7576 - val_loss: 22.8399 - val_mean_absolute_error: 23.4724 - val_root_mean_squared_error: 28.5177 - learning_rate: 0.0010
# Epoch 139/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 15.5355 - mean_absolute_error: 16.8229 - root_mean_squared_error: 22.7294 - val_loss: 34.8603 - val_mean_absolute_error: 36.7164 - val_root_mean_squared_error: 43.4528 - learning_rate: 0.0010
# Epoch 140/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 17.2319 - mean_absolute_error: 18.5645 - root_mean_squared_error: 24.5489 - val_loss: 31.3120 - val_mean_absolute_error: 31.0371 - val_root_mean_squared_error: 36.7058 - learning_rate: 0.0010
# Epoch 141/261
# ...
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 13.1948 - mean_absolute_error: 14.3280 - root_mean_squared_error: 18.6700 - val_loss: 69.1274 - val_mean_absolute_error: 71.5234 - val_root_mean_squared_error: 76.6444 - learning_rate: 0.0010
# Epoch 203/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 18.9420 - mean_absolute_error: 20.4066 - root_mean_squared_error: 26.1347 - val_loss: 46.8225 - val_mean_absolute_error: 48.2508 - val_root_mean_squared_error: 53.1884 - learning_rate: 0.0010
# Epoch 204/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 16.1547 - mean_absolute_error: 17.4707 - root_mean_squared_error: 22.5924 - val_loss: 21.6979 - val_mean_absolute_error: 22.9701 - val_root_mean_squared_error: 28.0382 - learning_rate: 0.0010
# Epoch 205/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 18.3434 - mean_absolute_error: 19.7356 - root_mean_squared_error: 25.0361 - val_loss: 30.2974 - val_mean_absolute_error: 30.4180 - val_root_mean_squared_error: 35.7950 - learning_rate: 0.0010
# Epoch 206/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 17.1387 - mean_absolute_error: 18.4792 - root_mean_squared_error: 23.8691 - val_loss: 38.3104 - val_mean_absolute_error: 39.5151 - val_root_mean_squared_error: 45.6723 - learning_rate: 0.0010
# Epoch 207/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 17.2179 - mean_absolute_error: 18.5906 - root_mean_squared_error: 23.8214 - val_loss: 66.6929 - val_mean_absolute_error: 67.7215 - val_root_mean_squared_error: 72.6710 - learning_rate: 0.0010
# Epoch 208/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 15.2414 - mean_absolute_error: 16.4866 - root_mean_squared_error: 21.7973 - val_loss: 21.7934 - val_mean_absolute_error: 23.2121 - val_root_mean_squared_error: 29.5597 - learning_rate: 0.0010
# Epoch 209/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 14.2366 - mean_absolute_error: 15.4140 - root_mean_squared_error: 20.7096 - val_loss: 59.7582 - val_mean_absolute_error: 60.5119 - val_root_mean_squared_error: 69.2505 - learning_rate: 0.0010
# Epoch 210/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 16.1440 - mean_absolute_error: 17.4593 - root_mean_squared_error: 23.0561 - val_loss: 25.5512 - val_mean_absolute_error: 25.6274 - val_root_mean_squared_error: 31.2300 - learning_rate: 0.0010
# Epoch 211/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 16.6237 - mean_absolute_error: 17.9437 - root_mean_squared_error: 23.9527 - val_loss: 22.7180 - val_mean_absolute_error: 23.8338 - val_root_mean_squared_error: 29.3039 - learning_rate: 0.0010
# Epoch 212/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 18.8855 - mean_absolute_error: 20.3359 - root_mean_squared_error: 25.3839 - val_loss: 23.9061 - val_mean_absolute_error: 24.3231 - val_root_mean_squared_error: 28.8849 - learning_rate: 0.0010
# Epoch 213/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 13.7884 - mean_absolute_error: 14.9694 - root_mean_squared_error: 19.7629 - val_loss: 22.4484 - val_mean_absolute_error: 23.0811 - val_root_mean_squared_error: 28.2585 - learning_rate: 0.0010
# Epoch 214/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 15.0308 - mean_absolute_error: 16.2838 - root_mean_squared_error: 21.7212 - val_loss: 22.8723 - val_mean_absolute_error: 23.0899 - val_root_mean_squared_error: 27.2766 - learning_rate: 0.0010
# Epoch 215/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 14.3107 - mean_absolute_error: 15.5064 - root_mean_squared_error: 20.5138 - val_loss: 25.2956 - val_mean_absolute_error: 26.8589 - val_root_mean_squared_error: 33.3066 - learning_rate: 0.0010
# Epoch 216/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 17.0055 - mean_absolute_error: 18.3121 - root_mean_squared_error: 23.9993 - val_loss: 49.0138 - val_mean_absolute_error: 51.0925 - val_root_mean_squared_error: 57.0992 - learning_rate: 0.0010
# Epoch 217/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 13.6003 - mean_absolute_error: 14.7781 - root_mean_squared_error: 19.7836 - val_loss: 19.6748 - val_mean_absolute_error: 21.0397 - val_root_mean_squared_error: 28.0756 - learning_rate: 0.0010
# Epoch 218/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 15.5523 - mean_absolute_error: 16.8251 - root_mean_squared_error: 22.5624 - val_loss: 67.9448 - val_mean_absolute_error: 69.1944 - val_root_mean_squared_error: 74.7878 - learning_rate: 0.0010
# Epoch 219/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 17.9207 - mean_absolute_error: 19.3187 - root_mean_squared_error: 25.1837 - val_loss: 23.5743 - val_mean_absolute_error: 24.1299 - val_root_mean_squared_error: 29.0622 - learning_rate: 0.0010
# Epoch 220/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 16.9180 - mean_absolute_error: 18.2230 - root_mean_squared_error: 23.7122 - val_loss: 40.7400 - val_mean_absolute_error: 42.4342 - val_root_mean_squared_error: 48.3829 - learning_rate: 0.0010
# Epoch 221/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 17.5618 - mean_absolute_error: 18.9510 - root_mean_squared_error: 24.7123 - val_loss: 41.7378 - val_mean_absolute_error: 40.5686 - val_root_mean_squared_error: 46.8109 - learning_rate: 0.0010
# Epoch 222/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 15.7566 - mean_absolute_error: 17.0463 - root_mean_squared_error: 22.6231 - val_loss: 50.6604 - val_mean_absolute_error: 48.8405 - val_root_mean_squared_error: 55.8384 - learning_rate: 0.0010
# Epoch 223/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 15.3525 - mean_absolute_error: 16.6195 - root_mean_squared_error: 22.0840 - val_loss: 26.0166 - val_mean_absolute_error: 28.0169 - val_root_mean_squared_error: 37.3150 - learning_rate: 0.0010
# Epoch 224/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 15.9777 - mean_absolute_error: 17.2930 - root_mean_squared_error: 23.1683 - val_loss: 90.6593 - val_mean_absolute_error: 89.7280 - val_root_mean_squared_error: 93.3337 - learning_rate: 0.0010
# Epoch 225/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 15.0990 - mean_absolute_error: 16.3442 - root_mean_squared_error: 21.7573 - val_loss: 30.5823 - val_mean_absolute_error: 32.0287 - val_root_mean_squared_error: 38.1378 - learning_rate: 0.0010
# Epoch 226/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 15.3544 - mean_absolute_error: 16.6256 - root_mean_squared_error: 21.4046 - val_loss: 55.6529 - val_mean_absolute_error: 54.7869 - val_root_mean_squared_error: 60.7506 - learning_rate: 0.0010
# Epoch 227/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 19.5194 - mean_absolute_error: 20.9835 - root_mean_squared_error: 27.2333 - val_loss: 28.9407 - val_mean_absolute_error: 28.9990 - val_root_mean_squared_error: 33.0762 - learning_rate: 0.0010
# Epoch 228/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 13.5914 - mean_absolute_error: 14.7774 - root_mean_squared_error: 19.5637 - val_loss: 30.9408 - val_mean_absolute_error: 31.0250 - val_root_mean_squared_error: 36.4109 - learning_rate: 0.0010
# Epoch 229/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 13.7192 - mean_absolute_error: 14.8787 - root_mean_squared_error: 20.0457 - val_loss: 20.9276 - val_mean_absolute_error: 21.7611 - val_root_mean_squared_error: 28.0610 - learning_rate: 0.0010
# Epoch 230/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 14.9481 - mean_absolute_error: 16.1796 - root_mean_squared_error: 21.2424 - val_loss: 36.3132 - val_mean_absolute_error: 36.4729 - val_root_mean_squared_error: 41.9955 - learning_rate: 0.0010
# Epoch 231/261
# 21/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 15.0212 - mean_absolute_error: 16.2656 - root_mean_squared_error: 21.5884
# Epoch 231: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 15.0524 - mean_absolute_error: 16.2756 - root_mean_squared_error: 21.5959 - val_loss: 39.9584 - val_mean_absolute_error: 40.7966 - val_root_mean_squared_error: 46.9295 - learning_rate: 0.0010
# Epoch 232/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 17.0956 - mean_absolute_error: 18.4422 - root_mean_squared_error: 23.0765 - val_loss: 18.4162 - val_mean_absolute_error: 19.5119 - val_root_mean_squared_error: 25.2412 - learning_rate: 5.0000e-04
# Epoch 233/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 14.4843 - mean_absolute_error: 15.7139 - root_mean_squared_error: 20.7261 - val_loss: 20.6147 - val_mean_absolute_error: 21.5404 - val_root_mean_squared_error: 26.8754 - learning_rate: 5.0000e-04
# Epoch 234/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 15.6448 - mean_absolute_error: 16.9207 - root_mean_squared_error: 21.4580 - val_loss: 18.4146 - val_mean_absolute_error: 19.6401 - val_root_mean_squared_error: 25.5610 - learning_rate: 5.0000e-04
# Epoch 235/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 12.4897 - mean_absolute_error: 13.5909 - root_mean_squared_error: 18.3237 - val_loss: 19.4418 - val_mean_absolute_error: 20.6968 - val_root_mean_squared_error: 26.5403 - learning_rate: 5.0000e-04
# Epoch 236/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 12.0912 - mean_absolute_error: 13.1913 - root_mean_squared_error: 17.8054 - val_loss: 18.2603 - val_mean_absolute_error: 19.0843 - val_root_mean_squared_error: 24.5671 - learning_rate: 5.0000e-04
# Epoch 237/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 10.5455 - mean_absolute_error: 11.5792 - root_mean_squared_error: 16.0325 - val_loss: 31.2480 - val_mean_absolute_error: 31.3324 - val_root_mean_squared_error: 36.5264 - learning_rate: 5.0000e-04
# Epoch 238/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 12.3571 - mean_absolute_error: 13.4671 - root_mean_squared_error: 18.3203 - val_loss: 21.9532 - val_mean_absolute_error: 22.2356 - val_root_mean_squared_error: 27.1602 - learning_rate: 5.0000e-04
# Epoch 239/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 13.2616 - mean_absolute_error: 14.4170 - root_mean_squared_error: 19.7831 - val_loss: 39.0030 - val_mean_absolute_error: 38.1587 - val_root_mean_squared_error: 44.2025 - learning_rate: 5.0000e-04
# Epoch 240/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 12.8045 - mean_absolute_error: 13.9303 - root_mean_squared_error: 18.9617 - val_loss: 18.5878 - val_mean_absolute_error: 19.4491 - val_root_mean_squared_error: 25.2762 - learning_rate: 5.0000e-04
# Epoch 241/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 11.5185 - mean_absolute_error: 12.5998 - root_mean_squared_error: 17.3832 - val_loss: 22.3832 - val_mean_absolute_error: 22.4493 - val_root_mean_squared_error: 27.9782 - learning_rate: 5.0000e-04
# Epoch 242/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 11.5294 - mean_absolute_error: 12.5873 - root_mean_squared_error: 17.6511 - val_loss: 25.0327 - val_mean_absolute_error: 25.1332 - val_root_mean_squared_error: 30.0410 - learning_rate: 5.0000e-04
# Epoch 243/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 11.5386 - mean_absolute_error: 12.6191 - root_mean_squared_error: 17.0906 - val_loss: 20.9855 - val_mean_absolute_error: 22.0434 - val_root_mean_squared_error: 28.0443 - learning_rate: 5.0000e-04
# Epoch 244/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 11.0441 - mean_absolute_error: 12.0750 - root_mean_squared_error: 16.4046 - val_loss: 26.3263 - val_mean_absolute_error: 26.4063 - val_root_mean_squared_error: 31.5096 - learning_rate: 5.0000e-04
# Epoch 245/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 11.7457 - mean_absolute_error: 12.8313 - root_mean_squared_error: 17.6297 - val_loss: 18.8696 - val_mean_absolute_error: 20.0163 - val_root_mean_squared_error: 26.2194 - learning_rate: 5.0000e-04
# Epoch 246/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 11.7448 - mean_absolute_error: 12.8202 - root_mean_squared_error: 17.8736 - val_loss: 21.6868 - val_mean_absolute_error: 22.8071 - val_root_mean_squared_error: 29.0730 - learning_rate: 5.0000e-04
# Epoch 247/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 13.8469 - mean_absolute_error: 15.0501 - root_mean_squared_error: 19.8110 - val_loss: 18.8236 - val_mean_absolute_error: 19.2847 - val_root_mean_squared_error: 24.3599 - learning_rate: 5.0000e-04
# Epoch 248/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 14.8185 - mean_absolute_error: 16.0432 - root_mean_squared_error: 20.8220 - val_loss: 33.3541 - val_mean_absolute_error: 34.3235 - val_root_mean_squared_error: 40.5469 - learning_rate: 5.0000e-04
# Epoch 249/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 13.2177 - mean_absolute_error: 14.3849 - root_mean_squared_error: 19.6697 - val_loss: 38.4253 - val_mean_absolute_error: 39.7625 - val_root_mean_squared_error: 45.3645 - learning_rate: 5.0000e-04
# Epoch 250/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 14.5264 - mean_absolute_error: 15.7566 - root_mean_squared_error: 21.2556 - val_loss: 35.8872 - val_mean_absolute_error: 36.9494 - val_root_mean_squared_error: 42.6439 - learning_rate: 5.0000e-04
# Epoch 251/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 12.8689 - mean_absolute_error: 14.0019 - root_mean_squared_error: 18.9582 - val_loss: 20.9569 - val_mean_absolute_error: 22.0145 - val_root_mean_squared_error: 29.1560 - learning_rate: 5.0000e-04
# Epoch 252/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 12.7321 - mean_absolute_error: 13.8618 - root_mean_squared_error: 18.2035 - val_loss: 23.0109 - val_mean_absolute_error: 24.1704 - val_root_mean_squared_error: 30.9697 - learning_rate: 5.0000e-04
# Epoch 253/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 12.2579 - mean_absolute_error: 13.3497 - root_mean_squared_error: 18.4972 - val_loss: 20.3273 - val_mean_absolute_error: 21.1040 - val_root_mean_squared_error: 27.2796 - learning_rate: 5.0000e-04
# Epoch 254/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 10.9761 - mean_absolute_error: 11.9972 - root_mean_squared_error: 16.2495 - val_loss: 22.9778 - val_mean_absolute_error: 24.4368 - val_root_mean_squared_error: 31.2603 - learning_rate: 5.0000e-04
# Epoch 255/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 13.2995 - mean_absolute_error: 14.4570 - root_mean_squared_error: 19.3742 - val_loss: 19.9081 - val_mean_absolute_error: 21.3242 - val_root_mean_squared_error: 27.7747 - learning_rate: 5.0000e-04
# Epoch 256/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 11.6583 - mean_absolute_error: 12.7499 - root_mean_squared_error: 16.9591 - val_loss: 17.5485 - val_mean_absolute_error: 18.5629 - val_root_mean_squared_error: 25.2990 - learning_rate: 5.0000e-04
# Epoch 257/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 12.7556 - mean_absolute_error: 13.8966 - root_mean_squared_error: 18.5243 - val_loss: 23.9453 - val_mean_absolute_error: 23.9266 - val_root_mean_squared_error: 29.5173 - learning_rate: 5.0000e-04
# Epoch 258/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 11.9197 - mean_absolute_error: 12.9924 - root_mean_squared_error: 16.8235 - val_loss: 40.6755 - val_mean_absolute_error: 41.8937 - val_root_mean_squared_error: 46.9960 - learning_rate: 5.0000e-04
# Epoch 259/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 12.0245 - mean_absolute_error: 13.1156 - root_mean_squared_error: 18.0533 - val_loss: 18.4660 - val_mean_absolute_error: 19.7309 - val_root_mean_squared_error: 26.7035 - learning_rate: 5.0000e-04
# Epoch 260/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 12.9114 - mean_absolute_error: 14.0632 - root_mean_squared_error: 18.6823 - val_loss: 20.5238 - val_mean_absolute_error: 21.3444 - val_root_mean_squared_error: 27.0942 - learning_rate: 5.0000e-04
# Epoch 261/261
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 13.0614 - mean_absolute_error: 14.2033 - root_mean_squared_error: 19.3381 - val_loss: 17.5723 - val_mean_absolute_error: 18.2525 - val_root_mean_squared_error: 24.1507 - learning_rate: 5.0000e-04
# *********** Benchmark results ***********
#
# R2    (Train/Test) = 0.928 / 0.812
# RMSE  (Train/Test) = 15.892 / 24.151
# Huber (Train/Test) = 10.733 / 17.757
# Train: rmse (mean of 1 models)= 15.892212867736816
# Test: rmse (mean of 1 models)= 24.15068817138672
# Train: r2 (mean of 1 models)= 0.9277735559345529
# Test: r2 (mean of 1 models)= 0.812447925679762
# Train: huber (mean of 1 models)= 10.732568740844727
# Test: huber (mean of 1 models)= 17.756540298461914

# %%
def plot_model_performance(mwd: ModelWithData):
    # undo log transformation for better interpretability
    x_train_label = mwd.train_label
    x_test_label = mwd.test_label
    y_train_predicted = mwd.train_predicted
    y_test_predicted = mwd.test_predicted
    
    # Create an array of x-values ranging from the minimum to maximum of the data
    x_values = np.linspace(min(x_train_label), max(x_train_label), 100)

    # Plot the line of equality (y=x)
    plt.plot(x_values, x_values, color='blue', linestyle='--', label='Y = X line')
    plt.grid(visible=True)

    # Scatter plot for predicted values
    plt.scatter(x_train_label, y_train_predicted, c='k', label='Train Labels')
    plt.scatter(x_test_label, y_test_predicted, c='r', label='Test Labels')

    # Labels, legend, and title
    plt.xlabel('True Labels')
    plt.ylabel('Predicted Labels')
    plt.legend()
    plt.title('Scatter Plot of True vs Predicted Labels with Line of Equality')

    # Show the plot
    plt.show()

# %%
bestMwd = EMPTY_MWD

for mwd in all_mwds:
    if mwd.isBetter(bestMwd.score):
            bestMwd = mwd

    plot_model_performance(mwd)

# %%
plt.plot(bestMwd.history.history['loss'], label='Loss')
plt.plot(bestMwd.history.history['val_loss'], label='Validation Loss')

plt.yscale('log')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.grid(visible=True, which='both', axis='y')
plt.legend()
# ax2 = plt.gca().twinx()
# ax2.plot(bestMwd.history.history['learning_rate'], color='r')
# ax2.set_ylabel('Learning Rate',color='r')

Eval_of_model = plt.legend()

# %%
# undo log transformation for better interpretability
x_train_label = bestMwd.train_label
x_test_label = bestMwd.test_label
y_train_predicted = bestMwd.train_predicted
y_test_predicted = bestMwd.test_predicted

# Create an array of x-values ranging from the minimum to maximum of the data
x_values = np.linspace(min(labels), max(labels), 100)

# Plot the line of equality (y=x)
plt.plot(x_values, x_values, color='blue', linestyle='--', label='Y = X line')

# Scatter plot for predicted values
plt.scatter(x_train_label, y_train_predicted, c='k', label='Train Labels')
plt.scatter(x_test_label, y_test_predicted, c='r', label='Test Labels')

# Labels, legend, and title
plt.xlabel('True Labels')
plt.ylabel('Predicted Labels')
plt.legend()
plt.title('Scatter Plot of True vs Predicted Labels with Line of Equality')

# Show the plot
plt.show()

# %% [markdown]
# ## Save the model

# %%
bestMwd.model.save('1800_sub_model.keras')

# %% [markdown]
# # Evaluation of the restored model

# %%
all_temp_sub_model = tf.keras.models.load_model('1800_sub_model.keras')

# Show the model architecture
all_temp_sub_model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 410, 1)    │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d (Conv1D)     │ (None, 205, 64)   │        832 │ input_layer[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 205, 64)   │        256 │ conv1d[0][0]      │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 205, 64)   │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d       │ (None, 103, 64)   │          0 │ activation[0][0]  │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_1 (Conv1D)   │ (None, 103, 32)   │      2,048 │ max_pooling1d[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 103, 32)   │        128 │ conv1d_1[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 103, 32)   │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_2 (Conv1D)   │ (None, 103, 32)   │      3,072 │ activation_1[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_3 (Conv1D)   │ (None, 103, 64)   │     14,336 │ activation_1[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_4 (Conv1D)   │ (None, 103, 32)   │     11,264 │ activation_1[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 103, 128)  │          0 │ conv1d_2[0][0],   │
# │ (Concatenate)       │                   │            │ conv1d_3[0][0],   │
# │                     │                   │            │ conv1d_4[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_5 (Conv1D)   │ (None, 103, 128)  │     16,384 │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_6 (Conv1D)   │ (None, 103, 128)  │      8,192 │ max_pooling1d[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 103, 128)  │        512 │ conv1d_5[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 103, 128)  │        512 │ conv1d_6[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 103, 128)  │          0 │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 103, 128)  │          0 │ add[0][0]         │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_7 (Conv1D)   │ (None, 103, 32)   │      4,096 │ activation_2[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 103, 32)   │        128 │ conv1d_7[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 103, 32)   │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_8 (Conv1D)   │ (None, 103, 32)   │      3,072 │ activation_3[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_9 (Conv1D)   │ (None, 103, 64)   │     14,336 │ activation_3[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_10 (Conv1D)  │ (None, 103, 32)   │     11,264 │ activation_3[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 103, 128)  │          0 │ conv1d_8[0][0],   │
# │ (Concatenate)       │                   │            │ conv1d_9[0][0],   │
# │                     │                   │            │ conv1d_10[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_11 (Conv1D)  │ (None, 103, 128)  │     16,384 │ concatenate_1[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 103, 128)  │        512 │ conv1d_11[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 103, 128)  │          0 │ batch_normalizat… │
# │                     │                   │            │ activation_2[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 103, 128)  │          0 │ add_1[0][0]       │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d_1     │ (None, 52, 128)   │          0 │ activation_4[0][… │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_12 (Conv1D)  │ (None, 52, 64)    │      8,192 │ max_pooling1d_1[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 52, 64)    │        256 │ conv1d_12[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (None, 52, 64)    │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_13 (Conv1D)  │ (None, 52, 64)    │     12,288 │ activation_5[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_14 (Conv1D)  │ (None, 52, 128)   │     57,344 │ activation_5[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_15 (Conv1D)  │ (None, 52, 64)    │     45,056 │ activation_5[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 52, 256)   │          0 │ conv1d_13[0][0],  │
# │ (Concatenate)       │                   │            │ conv1d_14[0][0],  │
# │                     │                   │            │ conv1d_15[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_16 (Conv1D)  │ (None, 52, 256)   │     65,536 │ concatenate_2[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_17 (Conv1D)  │ (None, 52, 256)   │     32,768 │ max_pooling1d_1[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 52, 256)   │      1,024 │ conv1d_16[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 52, 256)   │      1,024 │ conv1d_17[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 52, 256)   │          0 │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_6        │ (None, 52, 256)   │          0 │ add_2[0][0]       │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_18 (Conv1D)  │ (None, 52, 64)    │     16,384 │ activation_6[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 52, 64)    │        256 │ conv1d_18[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_7        │ (None, 52, 64)    │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_19 (Conv1D)  │ (None, 52, 64)    │     12,288 │ activation_7[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_20 (Conv1D)  │ (None, 52, 128)   │     57,344 │ activation_7[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_21 (Conv1D)  │ (None, 52, 64)    │     45,056 │ activation_7[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 52, 256)   │          0 │ conv1d_19[0][0],  │
# │ (Concatenate)       │                   │            │ conv1d_20[0][0],  │
# │                     │                   │            │ conv1d_21[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_22 (Conv1D)  │ (None, 52, 256)   │     65,536 │ concatenate_3[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 52, 256)   │      1,024 │ conv1d_22[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 52, 256)   │          0 │ batch_normalizat… │
# │                     │                   │            │ activation_6[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_8        │ (None, 52, 256)   │          0 │ add_3[0][0]       │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d_2     │ (None, 26, 256)   │          0 │ activation_8[0][… │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 256)       │          0 │ max_pooling1d_2[… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 64)        │     16,448 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ age_output (Dense)  │ (None, 1)         │         65 │ dense[0][0]       │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 1,630,021 (6.22 MB)
#  Trainable params: 542,401 (2.07 MB)
#  Non-trainable params: 2,816 (11.00 KB)
#  Optimizer params: 1,084,804 (4.14 MB)

# %%
def error_metrices_restored_model(y_true, y_predicted):
    rmse_train = np.sqrt(mean_squared_error(y_true, y_predicted))
    R2_train= r2_score(y_true, y_predicted)
    h = tf.keras.losses.Huber()
    hub_train = h(y_true, y_predicted).numpy()
    
    print('*********** Benchmark results ***********\n')
    print(f"R2    = {R2_train:.3f}")
    print(f"RMSE  = {rmse_train:.3f}")
    print(f"Huber = {hub_train:.3f}")

# %%
restored_pred = all_temp_sub_model.predict(features, verbose=0)

# %%
error_metrices_restored_model(labels, restored_pred)
# Out:
# *********** Benchmark results ***********
#
# R2    = 0.917
# RMSE  = 16.901
# Huber = 11.435
