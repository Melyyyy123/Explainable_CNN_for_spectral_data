# %% [markdown]
# # Optimal Model

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import random

from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold, TimeSeriesSplit
from mlxtend.evaluate import GroupTimeSeriesSplit
from mlxtend.evaluate.time_series import plot_splits
from sklearn.metrics import mean_squared_error, r2_score

import keras

import tensorflow as tf
from tensorflow.keras.layers import MaxPooling1D
from tensorflow.keras.callbacks import EarlyStopping,ReduceLROnPlateau
import datetime

# %load_ext tensorboard
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %%
def set_reproducible(seed=12345):
    np.random.seed(seed)
    random.seed(seed)
    tf.random.set_seed(seed)

# %%
dps1200 = pd.read_csv("dps1200.csv")
dps1200 = dps1200.sort_values("year", ascending=True)

# %%
features = dps1200.iloc[:, 4:].values
labels = dps1200.iloc[:, 0].values

# %%
def convertToDecade(y:int) -> int: 
    return int(str(y)[:3])

def calculate_sample_weights(y_train):

    decades = [convertToDecade(year) for year in y_train]

    unique_decades, counts = np.unique(decades, return_counts=True)
    total_samples = len(y_train)
    
    weights = {}
    for decade, count in zip(unique_decades, counts):
        weights[decade] = 1 - count/total_samples

    sample_weights = []
    for year in y_train:
        sample_weights.append(weights[convertToDecade(year)])
        
    return np.array(sample_weights)

# %% [markdown]
# First redifine the model into a function where the hyperparameters are inputs. This function evaluates the model and ouptups a desired score/metric.

# %%
def build_model(DenseN, DropoutR, C1_K, C1_S, C2_K, C2_S, C3_K, C3_S, input_dim):

    activation1='relu'
    activation2='linear'
    
    model = keras.Sequential()
    model.add(keras.layers.Input((input_dim, 1)))
    model.add(keras.layers.GaussianNoise(0.0001))

    model.add(keras.layers.Conv1D(C1_K, (C1_S), padding='valid', activation=activation1))
    model.add(keras.layers.Conv1D(C2_K, (C2_S), padding='valid', activation=activation1))
    model.add(keras.layers.Conv1D(C3_K, (C3_S), padding='valid', activation=activation1))
    model.add(MaxPooling1D(pool_size=2))

    model.add(keras.layers.Flatten())
    model.add(keras.layers.Dropout(DropoutR))
    
    model.add(keras.layers.Dense(DenseN, activation=activation1))
    model.add(keras.layers.Dense(DenseN, activation=activation1))
    model.add(keras.layers.Dense(DenseN, activation=activation1))
    model.add(keras.layers.Dense(1, activation=activation2))

    model.compile(loss=tf.keras.losses.Huber(), optimizer=keras.optimizers.Adam(learning_rate=0.001), metrics=['mean_absolute_error', tf.keras.metrics.R2Score()])
    
    return model

# %% [markdown]
# # Crossvalidation

# %% [markdown]
# Since NN training involves random sampling and weights initialization (in this case), it is usefull to use cross-validation.

# %%
## Compute error metrics
def error_metrices(y_true_train, y_predicted_train, y_true_test, y_predicted_test):
    rmse_train = np.sqrt(mean_squared_error(y_true_train, y_predicted_train))
    rmse_test = np.sqrt(mean_squared_error(y_true_test, y_predicted_test))
    R2_train= r2_score(y_true_train, y_predicted_train)
    R2_test= r2_score(y_true_test, y_predicted_test)
    h = tf.keras.losses.Huber()
    hub_train = h(y_true_train, y_predicted_train).numpy()
    hub_test = h(y_true_test, y_predicted_test).numpy()
    
    print('*********** Benchmark results ***********\n')
    print(f"R2    (Train/Test) = {R2_train:.3f} / {R2_test:.3f}")
    print(f"RMSE  (Train/Test) = {rmse_train:.3f} / {rmse_test:.3f}")
    print(f"Huber (Train/Test) = {hub_train:.3f} / {hub_test:.3f}")

    return (rmse_train, rmse_test, R2_train, R2_test, hub_train, hub_test)

class ModelWithData:
    def __init__(self, history, train_x, train_label, train_predicted, test_x, test_label, test_predicted, score:float, iteration, model) -> None:
        self.history = history
        self.train_x = train_x
        self.train_label = train_label
        self.train_predicted = train_predicted
        self.test_x = test_x
        self.test_label = test_label
        self.test_predicted = test_predicted
        self.score = score
        self.iteration = iteration
        self.model = model

    def isBetter(self, otherScore: float) -> bool:
        return otherScore < 0 or (self.score >= 0 and self.score <= otherScore)

# %%
def calculate_groups(years, years_in_group=100):
    groups = np.zeros(len(years))

    for i in range(len(years)):
        groups[i] = years[i] // years_in_group
    
    print("Groups:")
    print(groups)
    return groups

# %%
def evaluations_of_models(features, labels, DenseN, DropoutR, C1_K, C1_S, C2_K, C2_S, C3_K, C3_S, seed=12345, name="Anabell", epochs=100, n_splits=2, years_in_group=100):    

    x = np.array(features)
    y = np.array(labels)
    groups = calculate_groups(y, years_in_group)
    input_dim = 410
    
    # generate model
    model = build_model(DenseN, DropoutR, C1_K, C1_S, C2_K, C2_S, C3_K, C3_S, input_dim)

    # Define the number of folds for Cross-Validation
    skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)
    tss = TimeSeriesSplit(n_splits=n_splits)
    gtss = GroupTimeSeriesSplit(test_size=1, n_splits=n_splits)

    scores_train = { "rmse": [], "r2": [], "huber": []}
    scores_test = { "rmse": [], "r2": [], "huber": []}


    #monitor = EarlyStopping(monitor='val_loss', min_delta=4e-5, patience=50, verbose=0, mode='auto', restore_best_weights=True)
    #rdlr = ReduceLROnPlateau(patience=25, factor=0.5, min_lr=1e-6, monitor='val_loss', verbose=1)

    bestMwd = ModelWithData(None, 0, 0, 0, 0, 0, 0, -1, 0, None)

    tensorboard_base_dir = "tensorboard_logs"
    time_string = datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
    
    # Iterate through the models
    i = 0
    for train_index, test_index in gtss.split(x, y, groups):
        set_reproducible(seed)
        i = i + 1
        print(f'\n\n> Fold {i}')

        tensorboard_log_dir = f"{tensorboard_base_dir}/{name}/{time_string}/{seed}/fold_{i}"
        tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=tensorboard_log_dir)

        x_train, x_test = x[train_index], x[test_index]
        y_train, y_test = y[train_index], y[test_index]

        # Training the CNN-Model on X_train_fold, y_train_fold

        sample_weight=calculate_sample_weights(y_train)
        history = model.fit(x_train, y_train,
                            epochs=epochs, batch_size=45,
                            validation_data=(x_test, y_test),
                            verbose=0,
                            callbacks=[tensorboard_callback],
                            sample_weight=sample_weight)

        # Evaluation of the model on X_test_fold, y_test_fold
        evaluation_results = model.evaluate(x_test, y_test, verbose=0)
        evaluation_labels = model.metrics_names

        for j in range(len(evaluation_results)):
            print(f'{evaluation_labels[j]}: {evaluation_results[j]}')

        # Analyse error metrics

        train_pred = model.predict(x_train, verbose=0)
        test_pred = model.predict(x_test, verbose=0)

        (rmse_train, rmse_test, r2_train, r2_test, huber_train, huber_test) = error_metrices(y_train, train_pred, y_test, test_pred)

        mwd = ModelWithData(history, x_train, y_train, train_pred, x_test, y_test, test_pred, rmse_test, i, model)

        if mwd.isBetter(bestMwd.score):
            bestMwd = mwd

        scores_train["rmse"].append(rmse_train)
        scores_train["r2"].append(r2_train)
        scores_train["huber"].append(huber_train)

        scores_test["rmse"].append(rmse_test)
        scores_test["r2"].append(r2_test)
        scores_test["huber"].append(huber_test)

    ## clear session 
    tf.keras.backend.clear_session()

    scores_train_mean = {}
    scores_test_mean = {}
    num_model = len(scores_train["rmse"])

    for metric in scores_train.keys():
        scores_train_mean[metric] = np.mean(scores_train[metric])
        scores_test_mean[metric] = np.mean(scores_test[metric])
        print(f'Train: {metric} (mean of {num_model} models)= {scores_train_mean[metric]} \nTest: {metric} (mean of {num_model} models)= {scores_test_mean[metric]}')

    return bestMwd

# %%
bestMwd = evaluations_of_models(features, labels, DenseN=351, DropoutR=0.0, C1_K=55, C1_S=45, C2_K=43, C2_S=36, C3_K=63, C3_S=1)
print(f"Best model is from iteration {bestMwd.iteration}")
# Out:
# d:\programming\python\Explainable_CNN_for_spectral_data\.venv\Lib\site-packages\sklearn\model_selection\_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# > Fold 1
# loss: 143.4207305908203
# compile_metrics: 140.7672882080078
# *********** Benchmark results ***********
#
# R2    (Train/Test) = 0.356 / 0.281
# RMSE  (Train/Test) = 158.029 / 165.440
# Huber (Train/Test) = 133.399 / 140.268
#
#
# > Fold 2
# loss: 91.11515808105469
# compile_metrics: 92.26500701904297
# *********** Benchmark results ***********
#
# R2    (Train/Test) = 0.607 / 0.592
# RMSE  (Train/Test) = 122.965 / 125.666
# Huber (Train/Test) = 88.828 / 91.766
#
#
# > Fold 3
# loss: 88.42693328857422
# compile_metrics: 90.39537048339844
# *********** Benchmark results ***********
#
# R2    (Train/Test) = 0.582 / 0.610
# RMSE  (Train/Test) = 126.689 / 123.077
# Huber (Train/Test) = 91.167 / 89.896
# Train: rmse (mean of 3 models)= 135.8943954112315
# Test: rmse (mean of 3 models)= 138.06094149821422
# Train: r2 (mean of 3 models)= 0.5150429045956014
# Test: r2 (mean of 3 models)= 0.4944705177611181
# Train: huber (mean of 3 models)= 104.46487426757812
# Test: huber (mean of 3 models)= 107.31012725830078
# Best model is from iteration 2

# %%
# 3173, 6113
# Anabell: 2 Folds & 100 epochs
iter = 10
seeds = []
random.seed(12345)
for i in range(iter):
    seeds.append(random.randint(1, 10000))

for i in range(iter):
    seed = seeds[i]
    print(f"Using seed {seed}")
    evaluations_of_models(features, labels, DenseN=351, DropoutR=0.0, C1_K=55, C1_S=45, C2_K=43, C2_S=36, C3_K=63, C3_S=1, seed=seed, name="Anabell")
# Out:
# Using seed 6826
#
#
# > Fold 1
# /home/zaufl/Python/Explainable_CNN_for_spectral_data/.venv/lib/python3.11/site-packages/sklearn/model_selection/_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(
# loss: 136.51780700683594
# compile_metrics: 133.8708038330078
# *********** Benchmark results ***********
#
# R2    (Train/Test) = 0.348 / 0.330
# RMSE  (Train/Test) = 160.125 / 159.083
# Huber (Train/Test) = 133.392 / 133.371
#
#
# > Fold 2
# loss: 93.82482147216797
# compile_metrics: 95.8397445678711
# *********** Benchmark results ***********
#
# R2    (Train/Test) = 0.607 / 0.607
# RMSE  (Train/Test) = 121.764 / 124.323
# Huber (Train/Test) = 93.189 / 95.341
# Train: rmse (mean of 2 models)= 140.9445360628595
# Test: rmse (mean of 2 models)= 141.70300119534593
# Train: r2 (mean of 2 models)= 0.47777582908048793
# Test: r2 (mean of 2 models)= 0.4683865808820164
# Train: huber (mean of 2 models)= 113.290771484375
# Test: huber (mean of 2 models)= 114.35566711425781
# Using seed 167
# /home/zaufl/Python/Explainable_CNN_for_spectral_data/.venv/lib/python3.11/site-packages/sklearn/model_selection/_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(
# > Fold 1
# loss: 134.65113830566406
# compile_metrics: 135.10447692871094
# *********** Benchmark results ***********
#
# R2    (Train/Test) = 0.189 / 0.196
# RMSE  (Train/Test) = 178.626 / 174.205
# Huber (Train/Test) = 136.982 / 134.605
#
#
# > Fold 2
# loss: 95.85103607177734
# compile_metrics: 97.74861907958984
# *********** Benchmark results ***********
#
# R2    (Train/Test) = 0.593 / 0.592
# RMSE  (Train/Test) = 123.987 / 126.661
# Huber (Train/Test) = 93.446 / 97.249
# Train: rmse (mean of 2 models)= 151.30658939892874
# Test: rmse (mean of 2 models)= 150.43293585565112
# Train: r2 (mean of 2 models)= 0.39089096215812297
# Test: r2 (mean of 2 models)= 0.39417791905659993
# Train: huber (mean of 2 models)= 115.21401977539062
# Test: huber (mean of 2 models)= 115.92692565917969
# Using seed 4893
# /home/zaufl/Python/Explainable_CNN_for_spectral_data/.venv/lib/python3.11/site-packages/sklearn/model_selection/_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(
# > Fold 1
# loss: 117.0148696899414
# compile_metrics: 118.59379577636719
# *********** Benchmark results ***********
#
# R2    (Train/Test) = 0.271 / 0.298
# RMSE  (Train/Test) = 169.356 / 162.840
# Huber (Train/Test) = 122.701 / 118.095
#
#
# > Fold 2
# loss: 93.43962097167969
# compile_metrics: 97.22865295410156
# *********** Benchmark results ***********
#
# R2    (Train/Test) = 0.556 / 0.548
# RMSE  (Train/Test) = 129.499 / 133.361
# Huber (Train/Test) = 92.496 / 96.729
# Train: rmse (mean of 2 models)= 149.4274263490464
# Test: rmse (mean of 2 models)= 148.10085565408684
# Train: r2 (mean of 2 models)= 0.4133824823304412
# Test: r2 (mean of 2 models)= 0.4227667689401049
# Train: huber (mean of 2 models)= 107.5989761352539
# Test: huber (mean of 2 models)= 107.41197967529297
# Using seed 6037
# /home/zaufl/Python/Explainable_CNN_for_spectral_data/.venv/lib/python3.11/site-packages/sklearn/model_selection/_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(
# > Fold 1
# loss: 157.66639709472656
# compile_metrics: 154.69688415527344
# *********** Benchmark results ***********
#
# R2    (Train/Test) = 0.219 / 0.175
# RMSE  (Train/Test) = 175.324 / 176.428
# Huber (Train/Test) = 152.177 / 154.197
#
#
# > Fold 2
# loss: 98.34732818603516
# compile_metrics: 101.736328125
# *********** Benchmark results ***********
#
# R2    (Train/Test) = 0.522 / 0.506
# RMSE  (Train/Test) = 134.322 / 139.457
# Huber (Train/Test) = 96.053 / 101.238
# Train: rmse (mean of 2 models)= 154.82305128321423
# Test: rmse (mean of 2 models)= 157.9425493789061
# Train: r2 (mean of 2 models)= 0.37038666608690773
# Test: r2 (mean of 2 models)= 0.3405759847036986
# Train: huber (mean of 2 models)= 124.11502075195312
# Test: huber (mean of 2 models)= 127.71743774414062
# Using seed 3173
# /home/zaufl/Python/Explainable_CNN_for_spectral_data/.venv/lib/python3.11/site-packages/sklearn/model_selection/_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(
# > Fold 1
# loss: 99.44517517089844
# compile_metrics: 99.27113342285156
# *********** Benchmark results ***********
#
# R2    (Train/Test) = 0.602 / 0.571
# RMSE  (Train/Test) = 125.080 / 127.278
# Huber (Train/Test) = 95.031 / 98.772
#
#
# > Fold 2
# loss: 88.41407775878906
# compile_metrics: 91.0036849975586
# *********** Benchmark results ***********
#
# R2    (Train/Test) = 0.642 / 0.645
# RMSE  (Train/Test) = 116.206 / 118.248
# Huber (Train/Test) = 87.017 / 90.506
# Train: rmse (mean of 2 models)= 120.64316682870998
# Test: rmse (mean of 2 models)= 122.76267293456891
# Train: r2 (mean of 2 models)= 0.6223179011879573
# Test: r2 (mean of 2 models)= 0.6077433199851052
# Train: huber (mean of 2 models)= 91.02391815185547
# Test: huber (mean of 2 models)= 94.63888549804688
# Using seed 4428
# /home/zaufl/Python/Explainable_CNN_for_spectral_data/.venv/lib/python3.11/site-packages/sklearn/model_selection/_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(
# > Fold 1
# loss: 101.11767578125
# compile_metrics: 100.50841522216797
# *********** Benchmark results ***********
#
# R2    (Train/Test) = 0.589 / 0.560
# RMSE  (Train/Test) = 127.138 / 128.896
# Huber (Train/Test) = 97.362 / 100.010
#
#
# > Fold 2
# loss: 89.59337615966797
# compile_metrics: 92.39293670654297
# *********** Benchmark results ***********
#
# R2    (Train/Test) = 0.611 / 0.599
# RMSE  (Train/Test) = 121.246 / 125.632
# Huber (Train/Test) = 87.496 / 91.894
# Train: rmse (mean of 2 models)= 124.19190268891879
# Test: rmse (mean of 2 models)= 127.26368083463481
# Train: r2 (mean of 2 models)= 0.5998724607222636
# Test: r2 (mean of 2 models)= 0.5793674303865064
# Train: huber (mean of 2 models)= 92.42887878417969
# Test: huber (mean of 2 models)= 95.95181274414062
# Using seed 9274
# /home/zaufl/Python/Explainable_CNN_for_spectral_data/.venv/lib/python3.11/site-packages/sklearn/model_selection/_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(
# > Fold 1
# loss: 108.63356018066406
# compile_metrics: 107.03087615966797
# *********** Benchmark results ***********
#
# R2    (Train/Test) = 0.538 / 0.523
# RMSE  (Train/Test) = 134.831 / 134.169
# Huber (Train/Test) = 104.563 / 106.531
#
#
# > Fold 2
# loss: 116.31829071044922
# compile_metrics: 119.58828735351562
# *********** Benchmark results ***********
#
# R2    (Train/Test) = 0.369 / 0.364
# RMSE  (Train/Test) = 154.386 / 158.132
# Huber (Train/Test) = 117.041 / 119.089
# Train: rmse (mean of 2 models)= 144.60876998618247
# Test: rmse (mean of 2 models)= 146.15033194411512
# Train: r2 (mean of 2 models)= 0.4532766766308499
# Test: r2 (mean of 2 models)= 0.4437893536995398
# Train: huber (mean of 2 models)= 110.8017578125
# Test: huber (mean of 2 models)= 112.8103256225586
# Using seed 7148
# /home/zaufl/Python/Explainable_CNN_for_spectral_data/.venv/lib/python3.11/site-packages/sklearn/model_selection/_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(
# > Fold 1
# loss: 113.82952117919922
# compile_metrics: 113.1838150024414
# *********** Benchmark results ***********
#
# R2    (Train/Test) = 0.449 / 0.448
# RMSE  (Train/Test) = 147.250 / 144.404
# Huber (Train/Test) = 112.987 / 112.685
#
#
# > Fold 2
# loss: 90.57345581054688
# compile_metrics: 93.41792297363281
# *********** Benchmark results ***********
#
# R2    (Train/Test) = 0.616 / 0.612
# RMSE  (Train/Test) = 120.460 / 123.592
# Huber (Train/Test) = 87.931 / 92.918
# Train: rmse (mean of 2 models)= 133.855178508397
# Test: rmse (mean of 2 models)= 133.99834709668906
# Train: r2 (mean of 2 models)= 0.5322531972523604
# Test: r2 (mean of 2 models)= 0.529689838157913
# Train: huber (mean of 2 models)= 100.45864868164062
# Test: huber (mean of 2 models)= 102.80168914794922
# Using seed 2650
# /home/zaufl/Python/Explainable_CNN_for_spectral_data/.venv/lib/python3.11/site-packages/sklearn/model_selection/_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(
# > Fold 1
# loss: 134.34011840820312
# compile_metrics: 132.5755157470703
# *********** Benchmark results ***********
#
# R2    (Train/Test) = 0.402 / 0.365
# RMSE  (Train/Test) = 153.342 / 154.791
# Huber (Train/Test) = 129.385 / 132.076
#
#
# > Fold 2
# loss: 101.30384063720703
# compile_metrics: 103.14859771728516
# *********** Benchmark results ***********
#
# R2    (Train/Test) = 0.573 / 0.588
# RMSE  (Train/Test) = 126.997 / 127.352
# Huber (Train/Test) = 101.810 / 102.649
# Train: rmse (mean of 2 models)= 140.16953204077004
# Test: rmse (mean of 2 models)= 141.07140044976737
# Train: r2 (mean of 2 models)= 0.48755684724104015
# Test: r2 (mean of 2 models)= 0.4765414659807992
# Train: huber (mean of 2 models)= 115.59718322753906
# Test: huber (mean of 2 models)= 117.36244201660156
# Using seed 6113
# /home/zaufl/Python/Explainable_CNN_for_spectral_data/.venv/lib/python3.11/site-packages/sklearn/model_selection/_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(
# > Fold 1
# loss: 102.88570404052734
# compile_metrics: 102.60780334472656
# *********** Benchmark results ***********
#
# R2    (Train/Test) = 0.591 / 0.561
# RMSE  (Train/Test) = 126.809 / 128.755
# Huber (Train/Test) = 98.475 / 102.109
#
#
# > Fold 2
# loss: 87.53543853759766
# compile_metrics: 90.0521469116211
# *********** Benchmark results ***********
#
# R2    (Train/Test) = 0.650 / 0.654
# RMSE  (Train/Test) = 114.914 / 116.692
# Huber (Train/Test) = 87.391 / 89.553
# Train: rmse (mean of 2 models)= 120.86148513063273
# Test: rmse (mean of 2 models)= 122.72358900306801
# Train: r2 (mean of 2 models)= 0.6207390280587622
# Test: r2 (mean of 2 models)= 0.6073779132896262
# Train: huber (mean of 2 models)= 92.93280029296875
# Test: huber (mean of 2 models)= 95.83111572265625

# %%
y = np.array(labels)

all(y[i] <= y[i+1] for i in range(len(y) - 1))
# Out:
# True

# %%
# 3173, 6113
# Anabell: 2 Folds & 100 epochs
# Berta: 2 Folds & 500 epochs
seeds = [3173,6113]

for seed in seeds:
    print(f"Using seed {seed}")
    evaluations_of_models(features, labels, DenseN=351, DropoutR=0.0, C1_K=55, C1_S=45, C2_K=43, C2_S=36, C3_K=63, C3_S=1, seed=seed, name="Berta", epochs=500)
# Out:
# Using seed 3173
#
#
# > Fold 1
# /home/zaufl/Python/Explainable_CNN_for_spectral_data/.venv/lib/python3.11/site-packages/sklearn/model_selection/_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(
# loss: 76.82452392578125
# compile_metrics: 77.20238494873047
# *********** Benchmark results ***********
#
# R2    (Train/Test) = 0.743 / 0.687
# RMSE  (Train/Test) = 100.485 / 108.764
# Huber (Train/Test) = 71.201 / 76.705
#
#
# > Fold 2
# loss: 84.21237182617188
# compile_metrics: 85.3816146850586
# *********** Benchmark results ***********
#
# R2    (Train/Test) = 0.702 / 0.660
# RMSE  (Train/Test) = 106.050 / 115.625
# Huber (Train/Test) = 75.310 / 84.882
# Train: rmse (mean of 2 models)= 103.26723327797119
# Test: rmse (mean of 2 models)= 112.19483829793677
# Train: r2 (mean of 2 models)= 0.7227220097522755
# Test: r2 (mean of 2 models)= 0.6734148540155989
# Train: huber (mean of 2 models)= 73.25508880615234
# Test: huber (mean of 2 models)= 80.79376220703125
# Using seed 6113
# /home/zaufl/Python/Explainable_CNN_for_spectral_data/.venv/lib/python3.11/site-packages/sklearn/model_selection/_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(
# > Fold 1
# loss: 80.6082763671875
# compile_metrics: 80.37265014648438
# *********** Benchmark results ***********
#
# R2    (Train/Test) = 0.714 / 0.668
# RMSE  (Train/Test) = 106.006 / 111.990
# Huber (Train/Test) = 74.398 / 79.874
#
#
# > Fold 2
# loss: 88.07733154296875
# compile_metrics: 89.76302337646484
# *********** Benchmark results ***********
#
# R2    (Train/Test) = 0.745 / 0.689
# RMSE  (Train/Test) = 98.111 / 110.615
# Huber (Train/Test) = 79.947 / 89.266
# Train: rmse (mean of 2 models)= 102.05882526476523
# Test: rmse (mean of 2 models)= 111.30255906774615
# Train: r2 (mean of 2 models)= 0.7296973568154734
# Test: r2 (mean of 2 models)= 0.6783893795314856
# Train: huber (mean of 2 models)= 77.17234802246094
# Test: huber (mean of 2 models)= 84.56996154785156

# %%
# 3173, 6113
# Anabell: 2 Folds & 100 epochs
# Berta: 2 Folds & 500 epochs
seeds = [3173,6113]

for seed in seeds:
    print(f"Using seed {seed}")
    evaluations_of_models(features, labels, DenseN=351, DropoutR=0.0, C1_K=55, C1_S=45, C2_K=43, C2_S=36, C3_K=63, C3_S=1, seed=seed, name="Caesar", epochs=500, n_splits=5)
# Out:
# Using seed 3173
#
#
# > Fold 1
# loss: 231.12380981445312
# compile_metrics: 228.64483642578125
# *********** Benchmark results ***********
#
# R2    (Train/Test) = 0.085 / -35.079
# RMSE  (Train/Test) = 79.770 / 238.012
# Huber (Train/Test) = 64.272 / 228.146
#
#
# > Fold 2
# loss: 160.6551971435547
# compile_metrics: 160.01072692871094
# *********** Benchmark results ***********
#
# R2    (Train/Test) = 0.365 / -42.195
# RMSE  (Train/Test) = 99.749 / 175.260
# Huber (Train/Test) = 78.242 / 159.511
#
#
# > Fold 3
# loss: 210.55821228027344
# compile_metrics: 209.90538024902344
# *********** Benchmark results ***********
#
# R2    (Train/Test) = 0.468 / -52.411
# RMSE  (Train/Test) = 104.981 / 227.293
# Huber (Train/Test) = 83.499 / 209.405
#
#
# > Fold 4
# loss: 107.93048858642578
# compile_metrics: 108.70813751220703
# *********** Benchmark results ***********
#
# R2    (Train/Test) = 0.747 / -47.898
# RMSE  (Train/Test) = 82.076 / 134.398
# Huber (Train/Test) = 61.009 / 108.208
#
#
# > Fold 5
# loss: 67.27218627929688
# compile_metrics: 68.02952575683594
# *********** Benchmark results ***********
#
# R2    (Train/Test) = 0.584 / -23.095
# RMSE  (Train/Test) = 117.584 / 89.590
# Huber (Train/Test) = 100.896 / 67.531
# Train: rmse (mean of 5 models)= 96.83201560383152
# Test: rmse (mean of 5 models)= 172.91079266909838
# Train: r2 (mean of 5 models)= 0.44973071489691446
# Test: r2 (mean of 5 models)= -40.13550310814856
# Train: huber (mean of 5 models)= 77.58341979980469
# Test: huber (mean of 5 models)= 154.56027221679688
# Using seed 6113
#
#
# > Fold 1
# loss: 184.13827514648438
# compile_metrics: 181.61480712890625
# *********** Benchmark results ***********
#
# R2    (Train/Test) = 0.089 / -22.595
# RMSE  (Train/Test) = 79.601 / 192.480
# Huber (Train/Test) = 58.625 / 181.115
#
#
# > Fold 2
# loss: 143.0723114013672
# compile_metrics: 142.3326416015625
# *********** Benchmark results ***********
#
# R2    (Train/Test) = 0.322 / -35.060
# RMSE  (Train/Test) = 103.084 / 160.133
# Huber (Train/Test) = 80.884 / 141.833
#
#
# > Fold 3
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[34], line 8
#       6 for seed in seeds:
#       7     print(f"Using seed {seed}")
# ----> 8     evaluations_of_models(features, labels, DenseN=351, DropoutR=0.0, C1_K=55, C1_S=45, C2_K=43, C2_S=36, C3_K=63, C3_S=1, seed=seed, name="Caesar", epochs=500, n_splits=5)
#
# Cell In[33], line 42, in evaluations_of_models(features, labels, DenseN, DropoutR, C1_K, C1_S, C2_K, C2_S, C3_K, C3_S, seed, name, epochs, n_splits)
#      39 # Training the CNN-Model on X_train_fold, y_train_fold
#      41 sample_weight=calculate_sample_weights(y_train)
# ---> 42 history = model.fit(x_train, y_train,
#      43                     epochs=epochs, batch_size=45,
#      44                     validation_data=(x_test, y_test),
#      45                     verbose=0,
#      46                     callbacks=[tensorboard_callback],
#      47                     sample_weight=sample_weight)
#      49 # Evaluation of the model on X_test_fold, y_test_fold
#      50 evaluation_results = model.evaluate(x_test, y_test, verbose=0)
#
# File ~/Python/Explainable_CNN_for_spectral_data/.venv/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:118, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     116 filtered_tb = None
#     117 try:
# --> 118     return fn(*args, **kwargs)
#     119 except Exception as e:
#     120     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/Python/Explainable_CNN_for_spectral_data/.venv/lib/python3.11/site-packages/keras/src/backend/tensorflow/trainer.py:323, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     321 for step, iterator in epoch_iterator.enumerate_epoch():
#     322     callbacks.on_train_batch_begin(step)
# --> 323     logs = self.train_function(iterator)
#     324     callbacks.on_train_batch_end(
#     325         step, self._pythonify_logs(logs)
#     326     )
#     327     if self.stop_training:
#
# File ~/Python/Explainable_CNN_for_spectral_data/.venv/lib/python3.11/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/Python/Explainable_CNN_for_spectral_data/.venv/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/Python/Explainable_CNN_for_spectral_data/.venv/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File ~/Python/Explainable_CNN_for_spectral_data/.venv/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File ~/Python/Explainable_CNN_for_spectral_data/.venv/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/Python/Explainable_CNN_for_spectral_data/.venv/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File ~/Python/Explainable_CNN_for_spectral_data/.venv/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File ~/Python/Explainable_CNN_for_spectral_data/.venv/lib/python3.11/site-packages/tensorflow/python/eager/context.py:1500, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1498 cancellation_context = cancellation.context()
#    1499 if cancellation_context is None:
# -> 1500   outputs = execute.execute(
#    1501       name.decode("utf-8"),
#    1502       num_outputs=num_outputs,
#    1503       inputs=tensor_inputs,
#    1504       attrs=attrs,
#    1505       ctx=self,
#    1506   )
#    1507 else:
#    1508   outputs = execute.execute_with_cancellation(
#    1509       name.decode("utf-8"),
#    1510       num_outputs=num_outputs,
#    (...)
#    1514       cancellation_manager=cancellation_context,
#    1515   )
#
# File ~/Python/Explainable_CNN_for_spectral_data/.venv/lib/python3.11/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
# 3173, 6113
# Anabell: 2 Folds & 100 epochs
# Berta: 2 Folds & 500 epochs
seeds = [3173,6113]

for seed in seeds:
    print(f"Using seed {seed}")
    evaluations_of_models(features, labels, DenseN=351, DropoutR=0.0, C1_K=55, C1_S=45, C2_K=43, C2_S=36, C3_K=63, C3_S=1, seed=seed, name="Dino", epochs=500, n_splits=3)
# Out:
# Using seed 3173
# Groups:
# [11. 12. 12. ... 20. 20. 20.]
#
#
# > Fold 1
# loss: 220.62596130371094
# compile_metrics: 218.10679626464844
# *********** Benchmark results ***********
#
# R2    (Train/Test) = 0.331 / -64.802
# RMSE  (Train/Test) = 122.387 / 240.799
# Huber (Train/Test) = 101.268 / 217.607
#
#
# > Fold 2
# loss: 86.92727661132812
# compile_metrics: 87.28717041015625
# *********** Benchmark results ***********
#
# R2    (Train/Test) = 0.733 / -16.667
# RMSE  (Train/Test) = 87.012 / 115.660
# Huber (Train/Test) = 64.480 / 86.789
#
#
# > Fold 3
# loss: 27.5686092376709
# compile_metrics: 28.0686092376709
# *********** Benchmark results ***********
#
# R2    (Train/Test) = 0.955 / -129.550
# RMSE  (Train/Test) = 38.080 / 33.963
# Huber (Train/Test) = 26.920 / 27.569
# Train: rmse (mean of 3 models)= 82.49282216863871
# Test: rmse (mean of 3 models)= 130.14082808393184
# Train: r2 (mean of 3 models)= 0.6730549191159229
# Test: r2 (mean of 3 models)= -70.33968635730643
# Train: huber (mean of 3 models)= 64.22232818603516
# Test: huber (mean of 3 models)= 110.6546630859375
# Using seed 6113
# Groups:
# [11. 12. 12. ... 20. 20. 20.]
#
#
# > Fold 1
# loss: 177.9349822998047
# compile_metrics: 175.31105041503906
# *********** Benchmark results ***********
#
# R2    (Train/Test) = 0.345 / -41.629
# RMSE  (Train/Test) = 121.086 / 193.815
# Huber (Train/Test) = 91.298 / 174.812
#
#
# > Fold 2
# loss: 69.39517974853516
# compile_metrics: 70.00005340576172
# *********** Benchmark results ***********
#
# R2    (Train/Test) = 0.821 / -10.358
# RMSE  (Train/Test) = 71.305 / 92.736
# Huber (Train/Test) = 49.449 / 69.501
#
#
# > Fold 3
# loss: 59.505523681640625
# compile_metrics: 60.005523681640625
# *********** Benchmark results ***********
#
# R2    (Train/Test) = 0.911 / -632.663
# RMSE  (Train/Test) = 53.655 / 74.825
# Huber (Train/Test) = 37.684 / 59.506
# Train: rmse (mean of 3 models)= 82.01535535650862
# Test: rmse (mean of 3 models)= 120.45873061922457
# Train: r2 (mean of 3 models)= 0.6923638244631326
# Test: r2 (mean of 3 models)= -228.216603068029
# Train: huber (mean of 3 models)= 59.47694778442383
# Test: huber (mean of 3 models)= 101.27285766601562

# %%
# 3173, 6113
# Anabell: 2 Folds & 100 epochs
# Berta: 2 Folds & 500 epochs
seeds = [3173,6113]

for seed in seeds:
    print(f"Using seed {seed}")
    evaluations_of_models(features, labels, DenseN=351, DropoutR=0.0, C1_K=55, C1_S=45, C2_K=43, C2_S=36, C3_K=63, C3_S=1, seed=seed, name="Eos", epochs=500, n_splits=3, years_in_group=50)
# Out:
# Using seed 3173
# Groups:
# [23. 24. 24. ... 40. 40. 40.]
#
#
# > Fold 1
# loss: 65.25067901611328
# compile_metrics: 64.51341247558594
# *********** Benchmark results ***********
#
# R2    (Train/Test) = 0.538 / -30.184
# RMSE  (Train/Test) = 114.778 / 80.509
# Huber (Train/Test) = 85.481 / 64.017
#
#
# > Fold 2
# loss: 74.30915832519531
# compile_metrics: 73.81743621826172
# *********** Benchmark results ***********
#
# R2    (Train/Test) = 0.812 / -33.105
# RMSE  (Train/Test) = 79.630 / 81.668
# Huber (Train/Test) = 58.848 / 73.317
#
#
# > Fold 3
# loss: 24.35570526123047
# compile_metrics: 24.840072631835938
# *********** Benchmark results ***********
#
# R2    (Train/Test) = 0.951 / -118.012
# RMSE  (Train/Test) = 42.025 / 32.427
# Huber (Train/Test) = 28.411 / 24.356
# Train: rmse (mean of 3 models)= 78.81068306448587
# Test: rmse (mean of 3 models)= 64.86803535669857
# Train: r2 (mean of 3 models)= 0.7668795466066708
# Test: r2 (mean of 3 models)= -60.43361533953097
# Train: huber (mean of 3 models)= 57.58024978637695
# Test: huber (mean of 3 models)= 53.8968505859375
# Using seed 6113
# Groups:
# [23. 24. 24. ... 40. 40. 40.]
#
#
# > Fold 1
# loss: 74.7384262084961
# compile_metrics: 74.01692199707031
# *********** Benchmark results ***********
#
# R2    (Train/Test) = 0.640 / -39.942
# RMSE  (Train/Test) = 101.358 / 92.249
# Huber (Train/Test) = 74.840 / 73.519
#
#
# > Fold 2
# loss: 40.140869140625
# compile_metrics: 41.17753219604492
# *********** Benchmark results ***********
#
# R2    (Train/Test) = 0.826 / -13.468
# RMSE  (Train/Test) = 76.493 / 53.192
# Huber (Train/Test) = 52.292 / 40.678
#
#
# > Fold 3
# loss: 39.003623962402344
# compile_metrics: 39.503623962402344
# *********** Benchmark results ***********
#
# R2    (Train/Test) = 0.947 / -280.175
# RMSE  (Train/Test) = 43.427 / 49.843
# Huber (Train/Test) = 34.962 / 39.004
# Train: rmse (mean of 3 models)= 73.75930350278338
# Test: rmse (mean of 3 models)= 65.09470758076117
# Train: r2 (mean of 3 models)= 0.8044967062349634
# Test: r2 (mean of 3 models)= -111.1950642558375
# Train: huber (mean of 3 models)= 54.0316047668457
# Test: huber (mean of 3 models)= 51.06683349609375

# %%
def plot_groups(years_in_group=100, n_splits=3):
    x = np.array(features)
    y = np.array(labels)
    groups = calculate_groups(y, years_in_group)

    cv_args = {"test_size": 1, "n_splits": n_splits}

    plot_splits(x,y,groups, **cv_args)

plot_groups(100, 3)
# Out:
# Groups:
# [11. 12. 12. ... 20. 20. 20.]

# %%
plot_groups(50, 3)
# Out:
# Groups:
# [23. 24. 24. ... 40. 40. 40.]

# %%
# %tensorboard --logdir tensorboard_logs/iteration_2
# Out:
#       <iframe id="tensorboard-frame-452ec40a3193ca54" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-452ec40a3193ca54");
#           const url = new URL("/", window.location);
#           const port = 6007;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
plt.plot(bestMwd.history.history['loss'], label='Training Loss')
plt.plot(bestMwd.history.history['val_loss'], label='Validation Loss')

#plt.yscale('log')
plt.ylabel('Huber Loss')
plt.xlabel('Epochs')
plt.legend()

Eval_of_model = plt.legend()

# %%
plt.plot(bestMwd.history.history['loss'], label='Training Loss')
plt.plot(bestMwd.history.history['val_loss'], label='Validation Loss')

plt.yscale('log')
plt.ylabel('Huber Loss')
plt.xlabel('Epochs')
plt.legend()

Eval_of_model_2 = plt.legend()

# %%
# Create an array of x-values ranging from the minimum to maximum of the data
x_values = np.linspace(min(labels), max(labels), 100)

# Plot the line of equality (y=x)
plt.plot(x_values, x_values, color='blue', linestyle='--', label='Y = X line')

# Scatter plot for predicted values
plt.scatter(bestMwd.train_label, bestMwd.train_predicted, c='k', label='Train Labels')
plt.scatter(bestMwd.test_label, bestMwd.test_predicted, c='r', label='Test Labels')

# Labels, legend, and title
plt.xlabel('True Labels')
plt.ylabel('Predicted Labels')
plt.legend()
plt.title('Scatter Plot of True vs Predicted Labels with Line of Equality')

# Show the plot
plt.show()

# %% [markdown]
# ## Save the model

# %%
bestMwd.model.save('dps1200sub_model.keras')

# %% [markdown]
# # Check if working

# %%
dps1200sub_model = tf.keras.models.load_model('dps1200sub_model.keras')

# Show the model architecture
dps1200sub_model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ gaussian_noise (GaussianNoise)  │ (None, 410, 1)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d (Conv1D)                 │ (None, 366, 55)        │         2,530 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ (None, 331, 43)        │        85,183 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_2 (Conv1D)               │ (None, 331, 63)        │         2,772 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d (MaxPooling1D)    │ (None, 165, 63)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 10395)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 10395)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 351)            │     3,648,996 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 351)            │       123,552 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 351)            │       123,552 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │           352 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 11,960,813 (45.63 MB)
#  Trainable params: 3,986,937 (15.21 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 7,973,876 (30.42 MB)

# %% [markdown]
# # Evaluation of the restored model

# %%
evaluation_results = dps1200sub_model.evaluate(features, labels, verbose=0)
evaluation_labels = dps1200sub_model.metrics_names

for j in range(len(evaluation_results)):
    print(f'{evaluation_labels[j]}: {evaluation_results[j]}')
# Out:
# loss: 34.45152282714844
# compile_metrics: 35.38374328613281

# %%
def error_metrices_restored_model(y_true, y_predicted):
    rmse_train = np.sqrt(mean_squared_error(y_true, y_predicted))
    R2_train= r2_score(y_true, y_predicted)
    h = tf.keras.losses.Huber()
    hub_train = h(y_true, y_predicted).numpy()
    
    print('*********** Benchmark results ***********\n')
    print(f"R2    = {R2_train:.3f}")
    print(f"RMSE  = {rmse_train:.3f}")
    print(f"Huber = {hub_train:.3f}")

# %%
restored_pred = dps1200sub_model.predict(features, verbose=0)

# %%
error_metrices_restored_model(labels, restored_pred)
# Out:
# *********** Benchmark results ***********
#
# R2    = 0.902
# RMSE  = 61.404
# Huber = 34.892
