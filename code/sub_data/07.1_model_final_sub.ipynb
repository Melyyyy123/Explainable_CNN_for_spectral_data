# %% [markdown]
# # Optimal Model

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import random

from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import mean_squared_error, r2_score

import keras

import tensorflow as tf
from tensorflow.keras.layers import MaxPooling1D
from tensorflow.keras.callbacks import EarlyStopping,ReduceLROnPlateau

# %%
def set_reproducible():
    np.random.seed(12345)
    random.seed(12345)
    tf.random.set_seed(12345)
    
set_reproducible()

# %%
dps1200 = pd.read_csv("dps1200.csv")

# %%
features = dps1200.iloc[:, 4:].values
labels = dps1200.iloc[:, 0].values

# %%
def convertToDecade(y:int) -> int: 
    return int(str(y)[:3])

def calculate_sample_weights(y_train):

    decades = [convertToDecade(year) for year in y_train]

    unique_decades, counts = np.unique(decades, return_counts=True)
    total_samples = len(y_train)
    
    weights = {}
    for decade, count in zip(unique_decades, counts):
        weights[decade] = 1 - count/total_samples

    sample_weights = []
    for year in y_train:
        sample_weights.append(weights[convertToDecade(year)])
        
    return np.array(sample_weights)

# %% [markdown]
# First redifine the model into a function where the hyperparameters are inputs. This function evaluates the model and ouptups a desired score/metric.

# %%
def build_model(DenseN, DropoutR, C1_K, C1_S, C2_K, C2_S, C3_K, C3_S, input_dim):

    activation1='relu'
    activation2='linear'
    
    model = keras.Sequential()
    model.add(keras.layers.Input((input_dim, 1)))
    model.add(keras.layers.GaussianNoise(0.0001))

    model.add(keras.layers.Conv1D(C1_K, (C1_S), padding='valid', activation=activation1))
    model.add(keras.layers.Conv1D(C2_K, (C2_S), padding='valid', activation=activation1))
    model.add(keras.layers.Conv1D(C3_K, (C3_S), padding='valid', activation=activation1))
    model.add(MaxPooling1D(pool_size=2))

    model.add(keras.layers.Flatten())
    model.add(keras.layers.Dropout(DropoutR))
    
    model.add(keras.layers.Dense(DenseN, activation=activation1))
    model.add(keras.layers.Dense(DenseN, activation=activation1))
    model.add(keras.layers.Dense(DenseN, activation=activation1))
    model.add(keras.layers.Dense(1, activation=activation2))

    model.compile(loss=tf.keras.losses.Huber(), optimizer=keras.optimizers.Adam(learning_rate=0.004), metrics=['mean_absolute_error'])
    
    return model

# %%
class Metrics(keras.callbacks.Callback):
    def on_train_begin(self, logs={}):
        self._metrics = {"huber_train": [], "huber_validation": []}

    def set_data(self, x_train, y_train, x_validation, y_validation):
        self._x_train = x_train
        self._y_train = y_train
        self._x_validation = x_validation
        self._y_validation = y_validation

    def on_epoch_end(self, epoch, logs={}):
        y_predicted_train = np.asarray(self.model.predict(self._x_train, verbose=0))
        y_predicted_validation = np.asarray(self.model.predict(self._x_validation, verbose=0))

        h = tf.keras.losses.Huber()
        hub_train = h(self._y_train, y_predicted_train).numpy()
        hub_validation = h(self._y_validation, y_predicted_validation).numpy()

        if epoch % 50 == 0:
            print(f"epoch {epoch}: huber_train: {hub_train}, huber_validation: {hub_validation}")

        self._metrics["huber_train"].append(hub_train)
        self._metrics["huber_validation"].append(hub_validation)

    def get(self, metric_name:str):
        if metric_name not in self._metrics.keys():
            print(f"[WARN] metric '{metric_name}' des not exists.")
            
        return self._metrics.get(metric_name, [])

metrics = Metrics()

# %% [markdown]
# # Crossvalidation

# %% [markdown]
# Since NN training involves random sampling and weights initialization (in this case), it is usefull to use cross-validation.

# %%
## Compute error metrics
def error_metrices(y_true_train, y_predicted_train, y_true_test, y_predicted_test):
    rmse_train = np.sqrt(mean_squared_error(y_true_train, y_predicted_train))
    rmse_test = np.sqrt(mean_squared_error(y_true_test, y_predicted_test))
    R2_train= r2_score(y_true_train, y_predicted_train)
    R2_test= r2_score(y_true_test, y_predicted_test)
    h = tf.keras.losses.Huber()
    hub_train = h(y_true_train, y_predicted_train).numpy()
    hub_test = h(y_true_test, y_predicted_test).numpy()
    
    print('*********** Benchmark results ***********\n')
    print(f"R2    (Train/Test) = {R2_train:.3f} / {R2_test:.3f}")
    print(f"RMSE  (Train/Test) = {rmse_train:.3f} / {rmse_test:.3f}")
    print(f"Huber (Train/Test) = {hub_train:.3f} / {hub_test:.3f}")

    return (rmse_train, rmse_test, R2_train, R2_test, hub_train, hub_test)

class ModelWithData:
    def __init__(self, history, train_x, train_label, train_predicted, test_x, test_label, test_predicted, score:float, iteration, model, huber_train, huber_validation) -> None:
        self.history = history
        self.train_x = train_x
        self.train_label = train_label
        self.train_predicted = train_predicted
        self.test_x = test_x
        self.test_label = test_label
        self.test_predicted = test_predicted
        self.score = score
        self.iteration = iteration
        self.model = model
        self.huber_train = huber_train
        self.huber_validation = huber_validation

    def isBetter(self, otherScore: float) -> bool:
        return otherScore < 0 or (self.score >= 0 and self.score <= otherScore)

# %%
def evaluations_of_models(features, labels, DenseN, DropoutR, C1_K, C1_S, C2_K, C2_S, C3_K, C3_S):    

    x = np.array(features)
    y = np.array(labels)
    input_dim = 410
    epochs = 1000
    
    # generate model
    model = build_model(DenseN, DropoutR, C1_K, C1_S, C2_K, C2_S, C3_K, C3_S, input_dim)

    # Define the number of folds for Cross-Validation
    n_splits = 5
    skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)

    scores_train = { "rmse": [], "r2": [], "huber": []}
    scores_test = { "rmse": [], "r2": [], "huber": []}


    monitor = EarlyStopping(monitor='val_loss', min_delta=4e-5, patience=50, verbose=0, mode='auto', restore_best_weights=True)
    rdlr = ReduceLROnPlateau(patience=25, factor=0.5, min_lr=1e-6, monitor='val_loss', verbose=1)

    bestMwd = ModelWithData(None, 0, 0, 0, 0, 0, 0, -1, 0, None, [], [])

    mwdList = list[ModelWithData]()
    
    # Iterate through the models
    i = 0
    for train_index, test_index in skf.split(x, y):
        i = i + 1
        print(f'\n\n> Iteration {i}')

        x_train, x_test = x[train_index], x[test_index]
        y_train, y_test = y[train_index], y[test_index]

        # Training the CNN-Model on X_train_fold, y_train_fold

        if i == 4:
            callbacks = [metrics]
        else:
            callbacks = [rdlr, monitor, metrics]

        metrics.set_data(x_train, y_train, x_test, y_test)
        sample_weight=calculate_sample_weights(y_train)
        history = model.fit(x_train, y_train, epochs=epochs, batch_size=45, validation_data=(x_test, y_test), verbose=0, callbacks=callbacks, sample_weight=sample_weight)

        # Evaluation of the model on X_test_fold, y_test_fold
        evaluation_results = model.evaluate(x_test, y_test, verbose=0)
        evaluation_labels = model.metrics_names

        for j in range(len(evaluation_results)):
            print(f'{evaluation_labels[j]}: {evaluation_results[j]}')

        # Analyse error metrics

        train_pred = model.predict(x_train, verbose=0)
        test_pred = model.predict(x_test, verbose=0)

        (rmse_train, rmse_test, r2_train, r2_test, huber_train, huber_test) = error_metrices(y_train, train_pred, y_test, test_pred)

        mwd = ModelWithData(history, x_train, y_train, train_pred, x_test, y_test, test_pred, rmse_test, i, model, metrics.get("huber_train"), metrics.get("huber_validation"))

        mwdList.append(mwd)

        if mwd.isBetter(bestMwd.score):
            bestMwd = mwd

        scores_train["rmse"].append(rmse_train)
        scores_train["r2"].append(r2_train)
        scores_train["huber"].append(huber_train)

        scores_test["rmse"].append(rmse_test)
        scores_test["r2"].append(r2_test)
        scores_test["huber"].append(huber_test)

    ## clear session 
    tf.keras.backend.clear_session()

    scores_train_mean = {}
    scores_test_mean = {}
    num_model = len(scores_train["rmse"])

    for metric in scores_train.keys():
        scores_train_mean[metric] = np.mean(scores_train[metric])
        scores_test_mean[metric] = np.mean(scores_test[metric])
        print(f'Train: {metric} (mean of {num_model} models)= {scores_train_mean[metric]} \nTest: {metric} (mean of {num_model} models)= {scores_test_mean[metric]}')

    return (bestMwd, mwdList)

# %%
(bestMwd, mwdList) = evaluations_of_models(features, labels, DenseN=351, DropoutR=0.0, C1_K=55, C1_S=45, C2_K=43, C2_S=36, C3_K=63, C3_S=1)
print(f"Best model is from iteration {bestMwd.iteration}")
# Out:
# d:\programming\python\Explainable_CNN_for_spectral_data\.venv\Lib\site-packages\sklearn\model_selection\_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# > Iteration 1
# epoch 0: huber_train: 229.1443634033203, huber_validation: 224.22193908691406
# epoch 50: huber_train: 97.69102478027344, huber_validation: 99.98184967041016
# epoch 100: huber_train: 96.14991760253906, huber_validation: 97.54347229003906
# epoch 150: huber_train: 99.04331970214844, huber_validation: 100.96373748779297
# epoch 200: huber_train: 80.8631591796875, huber_validation: 88.10435485839844
# epoch 250: huber_train: 63.150291442871094, huber_validation: 74.3456802368164
#
# Epoch 253: ReduceLROnPlateau reducing learning rate to 0.0020000000949949026.
#
# Epoch 292: ReduceLROnPlateau reducing learning rate to 0.0010000000474974513.
# epoch 300: huber_train: 61.2554817199707, huber_validation: 74.35594177246094
#
# Epoch 342: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# epoch 350: huber_train: 50.91067886352539, huber_validation: 68.77362060546875
# epoch 400: huber_train: 49.789154052734375, huber_validation: 68.09822845458984
#
# Epoch 428: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# epoch 450: huber_train: 42.010311126708984, huber_validation: 66.42030334472656
# epoch 500: huber_train: 41.439632415771484, huber_validation: 65.8031997680664
# epoch 550: huber_train: 37.7030143737793, huber_validation: 63.47213363647461
# epoch 600: huber_train: 38.517520904541016, huber_validation: 64.38435363769531
#
# Epoch 648: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# epoch 650: huber_train: 33.29157638549805, huber_validation: 59.031925201416016
#
# Epoch 692: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# epoch 700: huber_train: 29.226606369018555, huber_validation: 58.4184684753418
#
# Epoch 730: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# epoch 750: huber_train: 30.12592887878418, huber_validation: 58.7560920715332
#
# Epoch 755: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# loss: 55.970619201660156
# compile_metrics: 58.805320739746094
# *********** Benchmark results ***********
#
# R2    (Train/Test) = 0.924 / 0.809
# RMSE  (Train/Test) = 54.113 / 84.865
# Huber (Train/Test) = 29.159 / 58.307
#
#
# > Iteration 2
# epoch 0: huber_train: 36.85988998413086, huber_validation: 27.47035789489746
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
#
# Epoch 51: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# epoch 50: huber_train: 36.101863861083984, huber_validation: 28.483970642089844
# loss: 25.260059356689453
# compile_metrics: 27.96111297607422
# *********** Benchmark results ***********
#
# R2    (Train/Test) = 0.897 / 0.924
# RMSE  (Train/Test) = 63.157 / 53.778
# Huber (Train/Test) = 36.860 / 27.470
#
#
# > Iteration 3
# epoch 0: huber_train: 37.1462287902832, huber_validation: 26.242374420166016
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# epoch 50: huber_train: 36.70167922973633, huber_validation: 26.596296310424805
#
# Epoch 53: ReduceLROnPlateau reducing learning rate to 1e-06.
# loss: 24.246789932250977
# compile_metrics: 26.681303024291992
# *********** Benchmark results ***********
#
# R2    (Train/Test) = 0.893 / 0.937
# RMSE  (Train/Test) = 64.106 / 49.445
# Huber (Train/Test) = 37.072 / 26.191
#
#
# > Iteration 4
# epoch 0: huber_train: 36.92262268066406, huber_validation: 26.810434341430664
# epoch 50: huber_train: 36.752437591552734, huber_validation: 27.0880126953125
# epoch 100: huber_train: 36.649879455566406, huber_validation: 27.125640869140625
# epoch 150: huber_train: 36.56925582885742, huber_validation: 27.23758316040039
# epoch 200: huber_train: 36.482425689697266, huber_validation: 27.238773345947266
# epoch 250: huber_train: 36.40990447998047, huber_validation: 27.31960678100586
# epoch 300: huber_train: 36.34536361694336, huber_validation: 27.325782775878906
# epoch 350: huber_train: 36.293182373046875, huber_validation: 27.51671600341797
# epoch 400: huber_train: 36.229793548583984, huber_validation: 27.511913299560547
# epoch 450: huber_train: 36.17887878417969, huber_validation: 27.516176223754883
# epoch 500: huber_train: 36.12513732910156, huber_validation: 27.65453338623047
# epoch 550: huber_train: 36.08436965942383, huber_validation: 27.78130531311035
# epoch 600: huber_train: 36.020347595214844, huber_validation: 27.69954490661621
# epoch 650: huber_train: 35.98257064819336, huber_validation: 27.78798484802246
# epoch 700: huber_train: 35.94050598144531, huber_validation: 27.82313346862793
# epoch 750: huber_train: 35.89316940307617, huber_validation: 27.8667049407959
# epoch 800: huber_train: 35.84742736816406, huber_validation: 27.950593948364258
# epoch 850: huber_train: 35.811622619628906, huber_validation: 27.957700729370117
# epoch 900: huber_train: 35.77445602416992, huber_validation: 28.038806915283203
# epoch 950: huber_train: 35.72903060913086, huber_validation: 28.035480499267578
# loss: 25.251754760742188
# compile_metrics: 28.611806869506836
# *********** Benchmark results ***********
#
# R2    (Train/Test) = 0.897 / 0.939
# RMSE  (Train/Test) = 63.124 / 48.654
# Huber (Train/Test) = 35.692 / 28.116
#
#
# > Iteration 5
# epoch 0: huber_train: 33.84556579589844, huber_validation: 35.442161560058594
# loss: 33.02011489868164
# compile_metrics: 35.92906188964844
# *********** Benchmark results ***********
#
# R2    (Train/Test) = 0.907 / 0.897
# RMSE  (Train/Test) = 59.721 / 63.676
# Huber (Train/Test) = 33.846 / 35.442
# Train: rmse (mean of 5 models)= 60.84416121591808
# Test: rmse (mean of 5 models)= 60.0836417959775
# Train: r2 (mean of 5 models)= 0.90360020441722
# Test: r2 (mean of 5 models)= 0.9012620079148835
# Train: huber (mean of 5 models)= 34.52556228637695
# Test: huber (mean of 5 models)= 35.10530471801758
# Best model is from iteration 4

# %%
def render_learning_curve(mwd:ModelWithData, log_scale = False):
    plt.plot(mwd.huber_train, label='Training Loss')
    plt.plot(mwd.huber_validation, label='Validation Loss')

    if log_scale:
        plt.yscale('log')
    
    plt.ylabel('Huber Loss')
    plt.xlabel('Epochs')
    plt.legend()
    plt.show()

# %%
render_learning_curve(bestMwd)

# %%
render_learning_curve(bestMwd, log_scale=True)

# %%
render_learning_curve(mwdList[0])

# %%
render_learning_curve(mwdList[1])

# %%
render_learning_curve(mwdList[2])

# %%
render_learning_curve(mwdList[3])

# %%
render_learning_curve(mwdList[4])

# %%
def render_scatter_true_vs_predicted(mwd:ModelWithData):
    # Create an array of x-values ranging from the minimum to maximum of the data
    x_values = np.linspace(min(labels), max(labels), 100)

    # Plot the line of equality (y=x)
    plt.plot(x_values, x_values, color='blue', linestyle='--', label='Y = X line')

    # Scatter plot for predicted values
    plt.scatter(mwd.train_label, mwd.train_predicted, c='k', label='Train Labels')
    plt.scatter(mwd.test_label, mwd.test_predicted, c='r', label='Test Labels')

    # Labels, legend, and title
    plt.xlabel('True Labels')
    plt.ylabel('Predicted Labels')
    plt.legend()
    plt.title('Scatter Plot of True vs Predicted Labels with Line of Equality')

    # Show the plot
    plt.show()

# %%
render_scatter_true_vs_predicted(bestMwd)

# %%
render_scatter_true_vs_predicted(mwdList[0])

# %%
render_scatter_true_vs_predicted(mwdList[1])

# %%
render_scatter_true_vs_predicted(mwdList[2])

# %%
render_scatter_true_vs_predicted(mwdList[3])

# %%
render_scatter_true_vs_predicted(mwdList[4])

# %% [markdown]
# ## Save the model

# %%
bestMwd.model.save('dps1200sub_model.keras')

# %% [markdown]
# # Check if working

# %%
dps1200sub_model = tf.keras.models.load_model('dps1200sub_model.keras')

# Show the model architecture
dps1200sub_model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ gaussian_noise (GaussianNoise)  │ (None, 410, 1)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d (Conv1D)                 │ (None, 366, 55)        │         2,530 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ (None, 331, 43)        │        85,183 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_2 (Conv1D)               │ (None, 331, 63)        │         2,772 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d (MaxPooling1D)    │ (None, 165, 63)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 10395)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 10395)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 351)            │     3,648,996 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 351)            │       123,552 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 351)            │       123,552 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │           352 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 11,960,813 (45.63 MB)
#  Trainable params: 3,986,937 (15.21 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 7,973,876 (30.42 MB)

# %% [markdown]
# # Evaluation of the restored model

# %%
evaluation_results = dps1200sub_model.evaluate(features, labels, verbose=0)
evaluation_labels = dps1200sub_model.metrics_names

for j in range(len(evaluation_results)):
    print(f'{evaluation_labels[j]}: {evaluation_results[j]}')
# Out:
# loss: 33.727176666259766
# compile_metrics: 34.656715393066406

# %%
def error_metrices_restored_model(y_true, y_predicted):
    rmse_train = np.sqrt(mean_squared_error(y_true, y_predicted))
    R2_train= r2_score(y_true, y_predicted)
    h = tf.keras.losses.Huber()
    hub_train = h(y_true, y_predicted).numpy()
    
    print('*********** Benchmark results ***********\n')
    print(f"R2    = {R2_train:.3f}")
    print(f"RMSE  = {rmse_train:.3f}")
    print(f"Huber = {hub_train:.3f}")

# %%
restored_pred = dps1200sub_model.predict(features, verbose=0)

# %%
error_metrices_restored_model(labels, restored_pred)
# Out:
# *********** Benchmark results ***********
#
# R2    = 0.905
# RMSE  = 60.532
# Huber = 34.165
