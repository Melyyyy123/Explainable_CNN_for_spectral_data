# %% [markdown]
# # Optimal Architecture Trained several Times

# %% [markdown]
# Which effect has random weight initialization on the model?

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import random

from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import mean_squared_error, r2_score, make_scorer, explained_variance_score

import keras

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.layers import Conv1D,MaxPooling1D
from tensorflow.keras.losses import SparseCategoricalCrossentropy
from tensorflow.keras.callbacks import EarlyStopping,ReduceLROnPlateau
from livelossplot.tf_keras import PlotLossesCallback

# %%
def set_reproducible():
    np.random.seed(12345)
    random.seed(12345)
    tf.random.set_seed(12345)
    
set_reproducible()

# %%
dps1200 = pd.read_csv("dps1200.csv")

# %%
features = dps1200.iloc[:, 4:].values
labels = dps1200.iloc[:, 0].values

# %%
def convertToDecade(y:int) -> int: 
    return int(str(y)[:3])

def calculate_sample_weights(y_train):

    decades = [convertToDecade(year) for year in y_train]

    unique_decades, counts = np.unique(decades, return_counts=True)
    total_samples = len(y_train)
    
    weights = {}
    for decade, count in zip(unique_decades, counts):
        weights[decade] = 1 - count/total_samples

    sample_weights = []
    for year in y_train:
        sample_weights.append(weights[convertToDecade(year)])
        
    return np.array(sample_weights)

# %% [markdown]
# First redifine the model into a function where the hyperparameters are inputs. This function evaluates the model and ouptups a desired score/metric.

# %%
def build_model(DenseN, DropoutR, C1_K, C1_S, C2_K, C2_S, C3_K, C3_S, input_dim):

    activation1='relu'
    activation2='linear'
    
    model = keras.Sequential()
    model.add(keras.layers.Input((input_dim, 1)))
    model.add(keras.layers.GaussianNoise(0.0001))

    model.add(keras.layers.Conv1D(C1_K, (C1_S), padding='valid', activation=activation1))
    model.add(keras.layers.Conv1D(C2_K, (C2_S), padding='valid', activation=activation1))
    model.add(keras.layers.Conv1D(C3_K, (C3_S), padding='valid', activation=activation1))
    model.add(MaxPooling1D(pool_size=2))

    model.add(keras.layers.Flatten())
    model.add(keras.layers.Dropout(DropoutR))
    
    model.add(keras.layers.Dense(DenseN, activation=activation1))
    model.add(keras.layers.Dense(DenseN, activation=activation1))
    model.add(keras.layers.Dense(DenseN, activation=activation1))
    model.add(keras.layers.Dense(1, activation=activation2))

    model.compile(loss=tf.keras.losses.Huber(), optimizer=keras.optimizers.Adam(learning_rate=0.004), metrics=['mean_absolute_error'])
    
    return model

# %% [markdown]
# # Crossvalidation

# %% [markdown]
# Since NN training involves random sampling and weights initialization (in this case), it is usefull to use cross-validation.

# %%
## Compute error metrics
def error_metrices(y_true_train, y_predicted_train, y_true_test, y_predicted_test):
    rmse_train = np.sqrt(mean_squared_error(y_true_train, y_predicted_train))
    rmse_test = np.sqrt(mean_squared_error(y_true_test, y_predicted_test))
    R2_train= r2_score(y_true_train, y_predicted_train)
    R2_test= r2_score(y_true_test, y_predicted_test)
    h = tf.keras.losses.Huber()
    hub_train = h(y_true_train, y_predicted_train).numpy()
    hub_test = h(y_true_test, y_predicted_test).numpy()

    print('*********** Benchmark results ***********\n')
    print(f"R2    (Train/Test) = {R2_train:.3f} / {R2_test:.3f}")
    print(f"RMSE  (Train/Test) = {rmse_train:.3f} / {rmse_test:.3f}")
    print(f"Huber (Train/Test) = {hub_train:.3f} / {hub_test:.3f}")

    return (rmse_train, rmse_test, R2_train, R2_test, hub_train, hub_test)

class ModelWithData:
    def __init__(self, model, train_x, train_label, train_predicted, test_x, test_label, test_predicted, score:float, iteration) -> None:
        self.model = model
        self.train_x = train_x
        self.train_label = train_label
        self.train_predicted = train_predicted
        self.test_x = test_x
        self.test_label = test_label
        self.test_predicted = test_predicted
        self.score = score
        self.iteration = iteration

    def isBetter(self, otherScore: float) -> bool:
        return otherScore < 0 or (self.score >= 0 and self.score <= otherScore)

# %%
def evaluations_of_models(features, labels, DenseN, DropoutR, C1_K, C1_S, C2_K, C2_S, C3_K, C3_S):

    x = np.array(features)
    y = np.array(labels)
    input_dim = 410
    epochs = 1000
    
    # generate model
    model = build_model(DenseN, DropoutR, C1_K, C1_S, C2_K, C2_S, C3_K, C3_S, input_dim)

    # Define the number of Folds for Cross Validation
    n_splits = 5
    skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)

    scores_train = { "rmse": [], "r2": [], "huber": []}
    scores_test = { "rmse": [], "r2": [], "huber": []}


    monitor = EarlyStopping(monitor='val_loss', min_delta=4e-5, patience=50, verbose=0, mode='auto', restore_best_weights=True)
    rdlr = ReduceLROnPlateau(patience=25, factor=0.5, min_lr=1e-6, monitor='val_loss', verbose=1)

    bestMwd = ModelWithData(None, 0, 0, 0, 0, 0, 0, -1, 0)
    
    # Iterate through the folds and train/test the model
    i = 0
    for train_index, test_index in skf.split(x, y):
        i = i + 1
        print(f'\n\n> Iteration {i}')

        x_train, x_test = x[train_index], x[test_index]
        y_train, y_test = y[train_index], y[test_index]

        # Training the CNN model on X_train_fold, y_train_fold

        sample_weight=calculate_sample_weights(y_train)
        g = model.fit(x_train, y_train, epochs=epochs, batch_size=45, validation_data=(x_test, y_test), verbose=0, callbacks=[rdlr, monitor], sample_weight=sample_weight)

        # Evaluation of the model on X_test_fold, y_test_fold
        accuracy = model.evaluate(x_test, y_test, verbose=0)
        print(f'Fold Accuracy: {accuracy}')

        # Analyse the error metrics

        train_pred = model.predict(x_train, verbose=0)
        test_pred = model.predict(x_test, verbose=0)

        (rmse_train, rmse_test, r2_train, r2_test, huber_train, huber_test) = error_metrices(y_train, train_pred, y_test, test_pred)

        mwd = ModelWithData(g, x_train, y_train, train_pred, x_test, y_test, test_pred, rmse_train, i)

        if mwd.isBetter(bestMwd.score):
            bestMwd = mwd

        scores_train["rmse"].append(rmse_train)
        scores_train["r2"].append(r2_train)
        scores_train["huber"].append(huber_train)

        scores_test["rmse"].append(rmse_test)
        scores_test["r2"].append(r2_test)
        scores_test["huber"].append(huber_test)

    ## clear session 
    tf.keras.backend.clear_session()

    scores_train_mean = {}
    scores_test_mean = {}
    num_model = len(scores_train["rmse"])

    for metric in scores_train.keys():
        scores_train_mean[metric] = np.mean(scores_train[metric])
        scores_test_mean[metric] = np.mean(scores_test[metric])
        print(f'Train: {metric} (mean of {num_model} models)= {scores_train_mean[metric]} \nTest: {metric} (mean of {num_model} models)= {scores_test_mean[metric]}')

    return bestMwd

# %% [markdown]
# # Test 1

# %%
bestMwd = evaluations_of_models(features, labels, DenseN=351, DropoutR=0.0, C1_K=55, C1_S=45, C2_K=43, C2_S=36, C3_K=63, C3_S=1)
print(f"Best model is from iteration {bestMwd.iteration}")
# Out:
# d:\programming\python\first_steps_with_cnns\tensor\Lib\site-packages\sklearn\model_selection\_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# > Iteration 1
#
# Epoch 180: ReduceLROnPlateau reducing learning rate to 0.0020000000949949026.
#
# Epoch 396: ReduceLROnPlateau reducing learning rate to 0.0010000000474974513.
#
# Epoch 609: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 634: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Fold Accuracy: [55.27589416503906, 57.7457389831543]
# *********** Benchmark results ***********
#
# R2    (Train/Test) = 0.888 / 0.801
# RMSE  (Train/Test) = 65.993 / 86.831
# Huber (Train/Test) = 39.968 / 57.248
#
#
# > Iteration 2
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 53: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Fold Accuracy: [33.79041290283203, 36.123374938964844]
# *********** Benchmark results ***********
#
# R2    (Train/Test) = 0.880 / 0.899
# RMSE  (Train/Test) = 68.146 / 62.157
# Huber (Train/Test) = 41.626 / 35.625
#
#
# > Iteration 3
#
# Epoch 27: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 52: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# Fold Accuracy: [31.89584732055664, 34.02232360839844]
# *********** Benchmark results ***********
#
# R2    (Train/Test) = 0.876 / 0.920
# RMSE  (Train/Test) = 68.964 / 55.819
# Huber (Train/Test) = 41.129 / 33.528
#
#
# > Iteration 4
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# Fold Accuracy: [33.07151794433594, 35.758209228515625]
# *********** Benchmark results ***********
#
# R2    (Train/Test) = 0.879 / 0.912
# RMSE  (Train/Test) = 68.340 / 58.260
# Huber (Train/Test) = 40.709 / 35.260
#
#
# > Iteration 5
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# Fold Accuracy: [37.39321517944336, 41.86211395263672]
# *********** Benchmark results ***********
#
# R2    (Train/Test) = 0.888 / 0.874
# RMSE  (Train/Test) = 65.467 / 70.324
# Huber (Train/Test) = 39.113 / 41.364
# WARNING:tensorflow:From d:\programming\python\first_steps_with_cnns\tensor\Lib\site-packages\keras\src\backend\common\global_state.py:73: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# Train: rmse (mean of 5 models)= 67.38204697005574
# Test: rmse (mean of 5 models)= 66.67818835224142
# Train: r2 (mean of 5 models)= 0.882173707180163
# Test: r2 (mean of 5 models)= 0.8810767394108323
# Train: huber (mean of 5 models)= 40.50890350341797
# Test: huber (mean of 5 models)= 40.60491180419922
# Best model is from iteration 5

# %%
plt.plot(bestMwd.model.history['loss'], label='Loss')
plt.plot(bestMwd.model.history['val_loss'], label='Validation Loss')

#plt.yscale('log')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend()
ax2 = plt.gca().twinx()
ax2.plot(bestMwd.model.history['learning_rate'], color='r')
ax2.set_ylabel('Learning Rate',color='r')

Eval_of_model = plt.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# Create an array of x-values ranging from the minimum to maximum of the data
x_values = np.linspace(min(labels), max(labels), 100)

# Plot the line of equality (y=x)
plt.plot(x_values, x_values, color='blue', linestyle='--', label='Y = X line')

# Scatter plot for predicted values
plt.scatter(bestMwd.train_label, bestMwd.train_predicted, c='k', label='Train Labels')
plt.scatter(bestMwd.test_label, bestMwd.test_predicted, c='r', label='Test Labels')

# Labels, legend, and title
plt.xlabel('True Labels')
plt.ylabel('Predicted Labels')
plt.legend()
plt.title('Scatter Plot of True vs Predicted Labels with Line of Equality')

# Show the plot
plt.show()

# %% [markdown]
# # Test 2

# %%
bestMwd = evaluations_of_models(features, labels, DenseN=351, DropoutR=0.0, C1_K=55, C1_S=45, C2_K=43, C2_S=36, C3_K=63, C3_S=1)
print(f"Best model is from iteration {bestMwd.iteration}")
# Out:
# d:\programming\python\first_steps_with_cnns\tensor\Lib\site-packages\sklearn\model_selection\_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# > Iteration 1
#
# Epoch 197: ReduceLROnPlateau reducing learning rate to 0.0020000000949949026.
#
# Epoch 317: ReduceLROnPlateau reducing learning rate to 0.0010000000474974513.
#
# Epoch 447: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 472: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Fold Accuracy: [58.68083190917969, 61.764930725097656]
# *********** Benchmark results ***********
#
# R2    (Train/Test) = 0.855 / 0.791
# RMSE  (Train/Test) = 75.061 / 88.872
# Huber (Train/Test) = 47.094 / 61.269
#
#
# > Iteration 2
#
# Epoch 30: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 55: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Fold Accuracy: [40.1004524230957, 44.04401779174805]
# *********** Benchmark results ***********
#
# R2    (Train/Test) = 0.841 / 0.858
# RMSE  (Train/Test) = 78.392 / 73.712
# Huber (Train/Test) = 50.468 / 43.549
#
#
# > Iteration 3
#
# Epoch 29: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Fold Accuracy: [41.093326568603516, 45.02785110473633]
# *********** Benchmark results ***********
#
# R2    (Train/Test) = 0.836 / 0.876
# RMSE  (Train/Test) = 79.412 / 69.596
# Huber (Train/Test) = 49.768 / 44.531
#
#
# > Iteration 4
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# Fold Accuracy: [44.7015380859375, 47.879615783691406]
# *********** Benchmark results ***********
#
# R2    (Train/Test) = 0.843 / 0.860
# RMSE  (Train/Test) = 77.932 / 73.385
# Huber (Train/Test) = 48.753 / 47.383
#
#
# > Iteration 5
#
# Epoch 29: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# Fold Accuracy: [45.22015380859375, 50.08170700073242]
# *********** Benchmark results ***********
#
# R2    (Train/Test) = 0.850 / 0.833
# RMSE  (Train/Test) = 75.866 / 80.950
# Huber (Train/Test) = 48.260 / 49.585
# Train: rmse (mean of 5 models)= 77.33249734910893
# Test: rmse (mean of 5 models)= 77.30291690626308
# Train: r2 (mean of 5 models)= 0.8447968051390549
# Test: r2 (mean of 5 models)= 0.8435629626970803
# Train: huber (mean of 5 models)= 48.868690490722656
# Test: huber (mean of 5 models)= 49.26340103149414
# Best model is from iteration 1

# %%
plt.plot(bestMwd.model.history['loss'], label='Loss')
plt.plot(bestMwd.model.history['val_loss'], label='Validation Loss')

#plt.yscale('log')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend()
ax2 = plt.gca().twinx()
ax2.plot(bestMwd.model.history['learning_rate'], color='r')
ax2.set_ylabel('Learning Rate',color='r')

Eval_of_model = plt.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# Create an array of x-values ranging from the minimum to maximum of the data
x_values = np.linspace(min(labels), max(labels), 100)

# Plot the line of equality (y=x)
plt.plot(x_values, x_values, color='blue', linestyle='--', label='Y = X line')

# Scatter plot for predicted values
plt.scatter(bestMwd.train_label, bestMwd.train_predicted, c='k', label='Train Labels')
plt.scatter(bestMwd.test_label, bestMwd.test_predicted, c='r', label='Test Labels')

# Labels, legend, and title
plt.xlabel('True Labels')
plt.ylabel('Predicted Labels')
plt.legend()
plt.title('Scatter Plot of True vs Predicted Labels with Line of Equality')

# Show the plot
plt.show()

# %% [markdown]
# # Test 3

# %%
bestMwd = evaluations_of_models(features, labels, DenseN=351, DropoutR=0.0, C1_K=55, C1_S=45, C2_K=43, C2_S=36, C3_K=63, C3_S=1)
print(f"Best model is from iteration {bestMwd.iteration}")
# Out:
# d:\programming\python\first_steps_with_cnns\tensor\Lib\site-packages\sklearn\model_selection\_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# > Iteration 1
#
# Epoch 175: ReduceLROnPlateau reducing learning rate to 0.0020000000949949026.
#
# Epoch 200: ReduceLROnPlateau reducing learning rate to 0.0010000000474974513.
# Fold Accuracy: [74.8272705078125, 78.41437530517578]
# *********** Benchmark results ***********
#
# R2    (Train/Test) = 0.739 / 0.709
# RMSE  (Train/Test) = 100.640 / 104.827
# Huber (Train/Test) = 70.361 / 77.914
#
#
# > Iteration 2
#
# Epoch 50: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 228: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 309: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 334: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Fold Accuracy: [53.04323196411133, 57.755043029785156]
# *********** Benchmark results ***********
#
# R2    (Train/Test) = 0.849 / 0.766
# RMSE  (Train/Test) = 76.289 / 94.623
# Huber (Train/Test) = 46.663 / 57.258
#
#
# > Iteration 3
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 53: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# Fold Accuracy: [39.17650604248047, 43.10886001586914]
# *********** Benchmark results ***********
#
# R2    (Train/Test) = 0.824 / 0.877
# RMSE  (Train/Test) = 82.354 / 69.106
# Huber (Train/Test) = 50.075 / 42.613
#
#
# > Iteration 4
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# Fold Accuracy: [41.83049774169922, 47.01213455200195]
# *********** Benchmark results ***********
#
# R2    (Train/Test) = 0.829 / 0.856
# RMSE  (Train/Test) = 81.159 / 74.351
# Huber (Train/Test) = 48.686 / 46.519
#
#
# > Iteration 5
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# Fold Accuracy: [47.60462951660156, 51.540977478027344]
# *********** Benchmark results ***********
#
# R2    (Train/Test) = 0.841 / 0.811
# RMSE  (Train/Test) = 78.192 / 86.087
# Huber (Train/Test) = 47.588 / 51.043
# Train: rmse (mean of 5 models)= 83.72663055625996
# Test: rmse (mean of 5 models)= 85.79881523022812
# Train: r2 (mean of 5 models)= 0.8162726060901184
# Test: r2 (mean of 5 models)= 0.8040380472297326
# Train: huber (mean of 5 models)= 52.674644470214844
# Test: huber (mean of 5 models)= 55.069549560546875
# Best model is from iteration 2

# %%
plt.plot(bestMwd.model.history['loss'], label='Loss')
plt.plot(bestMwd.model.history['val_loss'], label='Validation Loss')

#plt.yscale('log')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend()
ax2 = plt.gca().twinx()
ax2.plot(bestMwd.model.history['learning_rate'], color='r')
ax2.set_ylabel('Learning Rate',color='r')

Eval_of_model = plt.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# Create an array of x-values ranging from the minimum to maximum of the data
x_values = np.linspace(min(labels), max(labels), 100)

# Plot the line of equality (y=x)
plt.plot(x_values, x_values, color='blue', linestyle='--', label='Y = X line')

# Scatter plot for predicted values
plt.scatter(bestMwd.train_label, bestMwd.train_predicted, c='k', label='Train Labels')
plt.scatter(bestMwd.test_label, bestMwd.test_predicted, c='r', label='Test Labels')

# Labels, legend, and title
plt.xlabel('True Labels')
plt.ylabel('Predicted Labels')
plt.legend()
plt.title('Scatter Plot of True vs Predicted Labels with Line of Equality')

# Show the plot
plt.show()

# %% [markdown]
# # Test 4

# %%
bestMwd = evaluations_of_models(features, labels, DenseN=351, DropoutR=0.0, C1_K=55, C1_S=45, C2_K=43, C2_S=36, C3_K=63, C3_S=1)
print(f"Best model is from iteration {bestMwd.iteration}")
# Out:
# d:\programming\python\first_steps_with_cnns\tensor\Lib\site-packages\sklearn\model_selection\_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# > Iteration 1
#
# Epoch 180: ReduceLROnPlateau reducing learning rate to 0.0020000000949949026.
#
# Epoch 440: ReduceLROnPlateau reducing learning rate to 0.0010000000474974513.
#
# Epoch 465: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Fold Accuracy: [58.31788635253906, 63.4545783996582]
# *********** Benchmark results ***********
#
# R2    (Train/Test) = 0.823 / 0.774
# RMSE  (Train/Test) = 82.715 / 92.349
# Huber (Train/Test) = 52.371 / 62.960
#
#
# > Iteration 2
#
# Epoch 35: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 60: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Fold Accuracy: [42.69015884399414, 46.33513641357422]
# *********** Benchmark results ***********
#
# R2    (Train/Test) = 0.835 / 0.837
# RMSE  (Train/Test) = 79.859 / 78.954
# Huber (Train/Test) = 50.157 / 45.844
#
#
# > Iteration 3
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 51: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Fold Accuracy: [39.88956069946289, 44.449859619140625]
# *********** Benchmark results ***********
#
# R2    (Train/Test) = 0.826 / 0.872
# RMSE  (Train/Test) = 81.820 / 70.563
# Huber (Train/Test) = 50.292 / 43.951
#
#
# > Iteration 4
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# Fold Accuracy: [45.22762680053711, 49.501678466796875]
# *********** Benchmark results ***********
#
# R2    (Train/Test) = 0.834 / 0.834
# RMSE  (Train/Test) = 79.970 / 79.838
# Huber (Train/Test) = 48.820 / 49.006
#
#
# > Iteration 5
#
# Epoch 27: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# Fold Accuracy: [43.67626953125, 48.95414733886719]
# *********** Benchmark results ***********
#
# R2    (Train/Test) = 0.837 / 0.830
# RMSE  (Train/Test) = 79.121 / 81.812
# Huber (Train/Test) = 48.985 / 48.461
# Train: rmse (mean of 5 models)= 80.69676402447706
# Test: rmse (mean of 5 models)= 80.70344153153536
# Train: r2 (mean of 5 models)= 0.8310428834578121
# Test: r2 (mean of 5 models)= 0.8294942338427539
# Train: huber (mean of 5 models)= 50.12480926513672
# Test: huber (mean of 5 models)= 50.04449462890625
# Best model is from iteration 5

# %%
plt.plot(bestMwd.model.history['loss'], label='Loss')
plt.plot(bestMwd.model.history['val_loss'], label='Validation Loss')

#plt.yscale('log')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend()
ax2 = plt.gca().twinx()
ax2.plot(bestMwd.model.history['learning_rate'], color='r')
ax2.set_ylabel('Learning Rate',color='r')

Eval_of_model = plt.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# Create an array of x-values ranging from the minimum to maximum of the data
x_values = np.linspace(min(labels), max(labels), 100)

# Plot the line of equality (y=x)
plt.plot(x_values, x_values, color='blue', linestyle='--', label='Y = X line')

# Scatter plot for predicted values
plt.scatter(bestMwd.train_label, bestMwd.train_predicted, c='k', label='Train Labels')
plt.scatter(bestMwd.test_label, bestMwd.test_predicted, c='r', label='Test Labels')

# Labels, legend, and title
plt.xlabel('True Labels')
plt.ylabel('Predicted Labels')
plt.legend()
plt.title('Scatter Plot of True vs Predicted Labels with Line of Equality')

# Show the plot
plt.show()

# %% [markdown]
# # Test 5

# %%
bestMwd = evaluations_of_models(features, labels, DenseN=351, DropoutR=0.0, C1_K=55, C1_S=45, C2_K=43, C2_S=36, C3_K=63, C3_S=1)
print(f"Best model is from iteration {bestMwd.iteration}")
# Out:
# d:\programming\python\first_steps_with_cnns\tensor\Lib\site-packages\sklearn\model_selection\_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# > Iteration 1
#
# Epoch 204: ReduceLROnPlateau reducing learning rate to 0.0020000000949949026.
#
# Epoch 229: ReduceLROnPlateau reducing learning rate to 0.0010000000474974513.
# Fold Accuracy: [75.17314910888672, 78.65643310546875]
# *********** Benchmark results ***********
#
# R2    (Train/Test) = 0.727 / 0.696
# RMSE  (Train/Test) = 102.893 / 107.120
# Huber (Train/Test) = 71.840 / 78.156
#
#
# > Iteration 2
#
# Epoch 76: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 166: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 283: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 308: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Fold Accuracy: [64.21070861816406, 59.02369689941406]
# *********** Benchmark results ***********
#
# R2    (Train/Test) = 0.844 / 0.763
# RMSE  (Train/Test) = 77.656 / 95.113
# Huber (Train/Test) = 48.730 / 58.530
#
#
# > Iteration 3
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 51: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# Fold Accuracy: [41.16535186767578, 44.8332633972168]
# *********** Benchmark results ***********
#
# R2    (Train/Test) = 0.814 / 0.879
# RMSE  (Train/Test) = 84.541 / 68.584
# Huber (Train/Test) = 51.490 / 44.338
#
#
# > Iteration 4
#
# Epoch 27: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# Fold Accuracy: [44.74302291870117, 48.45124053955078]
# *********** Benchmark results ***********
#
# R2    (Train/Test) = 0.824 / 0.849
# RMSE  (Train/Test) = 82.343 / 76.144
# Huber (Train/Test) = 50.557 / 47.953
#
#
# > Iteration 5
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# Fold Accuracy: [47.084556579589844, 52.178497314453125]
# *********** Benchmark results ***********
#
# R2    (Train/Test) = 0.834 / 0.808
# RMSE  (Train/Test) = 79.695 / 86.759
# Huber (Train/Test) = 49.377 / 51.685
# Train: rmse (mean of 5 models)= 85.42546949146526
# Test: rmse (mean of 5 models)= 86.74387001368706
# Train: r2 (mean of 5 models)= 0.8086760459181859
# Test: r2 (mean of 5 models)= 0.7993567032939717
# Train: huber (mean of 5 models)= 54.39875030517578
# Test: huber (mean of 5 models)= 56.13249969482422
# Best model is from iteration 2

# %%
plt.plot(bestMwd.model.history['loss'], label='Loss')
plt.plot(bestMwd.model.history['val_loss'], label='Validation Loss')

#plt.yscale('log')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend()
ax2 = plt.gca().twinx()
ax2.plot(bestMwd.model.history['learning_rate'], color='r')
ax2.set_ylabel('Learning Rate',color='r')

Eval_of_model = plt.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# Create an array of x-values ranging from the minimum to maximum of the data
x_values = np.linspace(min(labels), max(labels), 100)

# Plot the line of equality (y=x)
plt.plot(x_values, x_values, color='blue', linestyle='--', label='Y = X line')

# Scatter plot for predicted values
plt.scatter(bestMwd.train_label, bestMwd.train_predicted, c='k', label='Train Labels')
plt.scatter(bestMwd.test_label, bestMwd.test_predicted, c='r', label='Test Labels')

# Labels, legend, and title
plt.xlabel('True Labels')
plt.ylabel('Predicted Labels')
plt.legend()
plt.title('Scatter Plot of True vs Predicted Labels with Line of Equality')

# Show the plot
plt.show()
