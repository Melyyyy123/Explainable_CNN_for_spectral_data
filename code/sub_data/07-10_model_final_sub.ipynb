# %% [markdown]
# # Optimal Model

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import random
import math

from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold, TimeSeriesSplit
from mlxtend.evaluate import GroupTimeSeriesSplit
from mlxtend.evaluate.time_series import plot_splits
from sklearn.metrics import mean_squared_error, r2_score

import keras

import tensorflow as tf
from tensorflow.keras.layers import MaxPooling1D
from tensorflow.keras import layers
import datetime

# %load_ext tensorboard
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %%
# GPU Availability Check
print(f"TensorFlow version: {tf.__version__}")
gpus = tf.config.experimental.list_physical_devices('GPU')
print(f"Num GPUs Available: {len(gpus)}")

# List all physical devices
physical_devices = tf.config.list_physical_devices()
print("\n📱 All Physical Devices:")
for device in physical_devices:
    print(f"  {device}")

# Check if TensorFlow is built with CUDA support
print(f"\n🔧 CUDA Support: {tf.test.is_built_with_cuda()}")

# Prevent TensorFlow from allocating all GPU memory at once
if gpus:
    try:
        # Enable memory growth for each GPU
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        print(f"✅ Memory growth enabled for {len(gpus)} GPU(s)")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(f"❌ Error setting memory growth: {e}")
        
# tf.keras.mixed_precision.set_global_policy('mixed_float16')
# Out:
# TensorFlow version: 2.16.1
# Num GPUs Available: 0
#
# 📱 All Physical Devices:
#   PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')
#
# 🔧 CUDA Support: True

# %%
def set_reproducible(seed=12345):
    np.random.seed(seed)
    random.seed(seed)
    tf.random.set_seed(seed)
    keras.utils.set_random_seed(seed)

# %%
dps1200 = pd.read_csv("../../data/dps1200.csv")
dps1200 = dps1200.sort_values("year", ascending=True)
print(dps1200.shape)
dps1200.head()
# Out:
# (1290, 414)
#       year    tree Origin   type     X2970     X2968     X2966     X2964  \
# 408   1194  Bre082    NOR  water  0.017617  0.017783  0.017949  0.018133
# 1016  1202  Sle074    NOR    dry  0.022443  0.022758  0.023074  0.023408
# 409   1206  Bre082    NOR  water  0.016759  0.016905  0.017066  0.017259
# 1017  1211  Sle074    NOR    dry  0.021679  0.022010  0.022333  0.022669
# 410   1216  Bre082    NOR  water  0.017110  0.017286  0.017470  0.017686
#
#          X2962     X2960  ...      X818      X816      X814      X812  \
# 408   0.018348  0.018584  ... -0.019568 -0.019358 -0.019162 -0.018992
# 1016  0.023755  0.024105  ... -0.023845 -0.023755 -0.023694 -0.023661
# 409   0.017477  0.017703  ... -0.019145 -0.018927 -0.018732 -0.018562
# 1017  0.023019  0.023379  ... -0.022540 -0.022422 -0.022334 -0.022283
# 410   0.017928  0.018177  ... -0.019800 -0.019588 -0.019402 -0.019246
#
#           X810      X808      X806      X804      X802      X800
# 408  -0.018855 -0.018760 -0.018710 -0.018708 -0.018751 -0.018827
# 1016 -0.023658 -0.023692 -0.023765 -0.023878 -0.024026 -0.024203
# 409  -0.018425 -0.018331 -0.018287 -0.018293 -0.018340 -0.018420
# 1017 -0.022271 -0.022302 -0.022381 -0.022508 -0.022674 -0.022868
# 410  -0.019122 -0.019033 -0.018987 -0.018990 -0.019036 -0.019116
#
# [5 rows x 414 columns]

# %%
dpa = pd.read_csv("../../data/dpa.csv")
dpa = dpa.sort_values("year", ascending=True)
print(dpa.shape)
dpa.head()
# Out:
# (1652, 414)
#       year origin  Jahr     X3996     X2970     X2968     X2966     X2964  \
# 1645 -1256    HST -1256  0.004886  0.017064  0.017113  0.017169  0.017240
# 1644 -1248    HST -1248  0.006497  0.017340  0.017409  0.017486  0.017574
# 1643 -1238    HST -1238  0.007469  0.018766  0.018888  0.019015  0.019147
# 1642 -1228    HST -1228  0.006979  0.017259  0.017386  0.017524  0.017670
# 1641 -1218    HST -1218  0.006883  0.017824  0.017947  0.018080  0.018215
#
#          X2962     X2960  ...      X818      X816      X814      X812  \
# 1645  0.017326  0.017425  ... -0.019659 -0.019528 -0.019414 -0.019324
# 1644  0.017677  0.017800  ... -0.020023 -0.019873 -0.019741 -0.019632
# 1643  0.019292  0.019449  ... -0.020777 -0.020658 -0.020557 -0.020476
# 1642  0.017822  0.017980  ... -0.020601 -0.020477 -0.020373 -0.020292
# 1641  0.018356  0.018515  ... -0.020728 -0.020569 -0.020432 -0.020323
#
#           X810      X808      X806      X804      X802      X800
# 1645 -0.019263 -0.019233 -0.019233 -0.019259 -0.019302 -0.019355
# 1644 -0.019556 -0.019515 -0.019510 -0.019536 -0.019588 -0.019657
# 1643 -0.020419 -0.020390 -0.020390 -0.020417 -0.020466 -0.020528
# 1642 -0.020236 -0.020210 -0.020215 -0.020246 -0.020298 -0.020365
# 1641 -0.020250 -0.020215 -0.020219 -0.020258 -0.020327 -0.020415
#
# [5 rows x 414 columns]

# %%
daa = pd.read_csv("../../data/daa.csv")
daa = daa.sort_values("year", ascending=True)
print(daa.shape)
daa.head()
# Out:
# (775, 414)
#     year origin  Jahr     X3996     X2970     X2968     X2966     X2964  \
# 15  1249    BHN  1249  0.010141  0.016013  0.016305  0.016595  0.016886
# 16  1259    BHN  1259  0.006478  0.016792  0.017082  0.017375  0.017676
# 17  1269    BHN  1269  0.006970  0.017024  0.017385  0.017742  0.018102
# 18  1279    BHN  1279  0.009484  0.015401  0.015687  0.015979  0.016283
# 19  1280    BHN  1280  0.007507  0.015928  0.016148  0.016385  0.016637
#
#        X2962     X2960  ...      X818      X816      X814      X812      X810  \
# 15  0.017192  0.017515  ... -0.019834 -0.019692 -0.019571 -0.019473 -0.019406
# 16  0.017988  0.018312  ... -0.018187 -0.018026 -0.017892 -0.017787 -0.017716
# 17  0.018468  0.018839  ... -0.018914 -0.018765 -0.018647 -0.018561 -0.018512
# 18  0.016604  0.016943  ... -0.019576 -0.019445 -0.019330 -0.019237 -0.019171
# 19  0.016900  0.017179  ... -0.018113 -0.017934 -0.017778 -0.017652 -0.017562
#
#         X808      X806      X804      X802      X800
# 15 -0.019377 -0.019393 -0.019455 -0.019558 -0.019690
# 16 -0.017683 -0.017695 -0.017755 -0.017860 -0.018000
# 17 -0.018510 -0.018561 -0.018659 -0.018797 -0.018969
# 18 -0.019138 -0.019143 -0.019189 -0.019275 -0.019395
# 19 -0.017514 -0.017512 -0.017564 -0.017668 -0.017811
#
# [5 rows x 414 columns]

# %%
frames = [dps1200, dpa, daa]

result = pd.concat(frames)
result = result.sort_values("year", ascending=True)
result.head()

result = dps1200  # comment out to use all datasets

# %%
features = result.iloc[:, 4:414].values
labels = result.iloc[:, 0].values
print(features.shape)
# Out:
# (1290, 410)

# %%
def convertToDecade(y:int) -> int: 
    return int(str(y)[:3])

def calculate_sample_weights(y_train):

    decades = [convertToDecade(year) for year in y_train]

    unique_decades, counts = np.unique(decades, return_counts=True)
    total_samples = len(y_train)
    
    weights = {}
    for decade, count in zip(unique_decades, counts):
        weights[decade] = 1 - count/total_samples

    sample_weights = []
    for year in y_train:
        sample_weights.append(weights[convertToDecade(year)])
        
    return np.array(sample_weights)

# %%
# Add learning rate scheduling callback
def create_lr_scheduler():
    # reduces LR when validation loss plateaus
    scheduler = tf.keras.callbacks.ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=80,
        min_lr=1e-6,
        verbose=1
    )
    return scheduler

# %%
def create_optimizer():
    # opt = keras.optimizers.AdamW(learning_rate=0.001, weight_decay=1e-5)  # causes underfitting?
    opt = keras.optimizers.Adam(learning_rate=0.001)
    return opt

# %%
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (
    Input, Conv1D, BatchNormalization, Activation, Add,
    MaxPooling1D, GlobalAveragePooling1D, Dense, Concatenate
)

# best so far at loss around 3e-4
# praise be Gemini Pro 2.5, https://g.co/gemini/share/e3f26b1e78f3
def inception_residual_module(input_tensor, num_filters):
    """
    The core building block of the network. It processes data at multiple scales
    and includes a residual connection for stable training.
    """
    # Use a 1x1 convolution as a "bottleneck" to reduce computational cost
    bottleneck = Conv1D(filters=num_filters // 4, kernel_size=1, padding='same', use_bias=False)(input_tensor)
    bottleneck = BatchNormalization()(bottleneck)
    bottleneck = Activation('relu')(bottleneck)

    # --- Parallel branches for multi-scale feature extraction ---
    # Small kernel for sharp peaks
    branch1 = Conv1D(filters=num_filters // 4, kernel_size=3, padding='same', use_bias=False)(bottleneck)

    # Medium kernel for wider features
    branch2 = Conv1D(filters=num_filters // 2, kernel_size=7, padding='same', use_bias=False)(bottleneck)
    
    # Large kernel for broad shapes
    branch3 = Conv1D(filters=num_filters // 4, kernel_size=11, padding='same', use_bias=False)(bottleneck)

    # Combine the features from all branches
    concatenated = Concatenate()([branch1, branch2, branch3])
    
    # Final 1x1 convolution to restore the desired number of filters
    final_conv = Conv1D(filters=num_filters, kernel_size=1, padding='same', use_bias=False)(concatenated)
    final_conv = BatchNormalization()(final_conv)

    # --- Residual Connection ---
    # Add the original input to the output of the convoluted path.
    # This helps prevent vanishing gradients in a deep network.
    if input_tensor.shape[-1] != num_filters:
        shortcut = Conv1D(filters=num_filters, kernel_size=1, padding='same', use_bias=False)(input_tensor)
        shortcut = BatchNormalization()(shortcut)
    else:
        shortcut = input_tensor
        
    output = Add()([final_conv, shortcut])
    output = Activation('relu')(output)
    
    return output

def build_wood_age_incepresnet(input_dim):
    """
    Constructs the full Inception-Residual model.
    """

    inputs = Input(shape=(input_dim, 1))

    # --- Stem: Initial Feature Extraction ---
    # A standard convolution to process the raw input and reduce dimensionality.
    x = Conv1D(filters=64, kernel_size=13, strides=2, padding='same', use_bias=False)(inputs)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling1D(pool_size=3, strides=2, padding='same')(x)

    # --- Core Blocks: Deep Feature Learning ---
    # Stack the custom modules to learn increasingly complex features.
    x = inception_residual_module(x, num_filters=128)
    x = inception_residual_module(x, num_filters=128)
    x = MaxPooling1D(pool_size=3, strides=2, padding='same')(x)

    x = inception_residual_module(x, num_filters=256)
    x = inception_residual_module(x, num_filters=256)
    x = MaxPooling1D(pool_size=3, strides=2, padding='same')(x)

    # --- Head: Final Prediction ---
    # Global Average Pooling is the key to fighting overfitting.
    # It creates one feature per filter, summarizing the entire spectrum.
    x = GlobalAveragePooling1D()(x)
    
    # A small dense head for the final regression output.
    x = Dense(64, activation='relu')(x)
    outputs = Dense(1, activation='linear', name='age_output')(x)

    model = Model(inputs=inputs, outputs=outputs)
    model.compile(loss=tf.keras.losses.Huber(), optimizer=create_optimizer(), metrics=['mean_absolute_error', 'root_mean_squared_error'])
    model.summary()

    return model, 'incepresnet'

# %% [markdown]
# # Crossvalidation

# %% [markdown]
# Since NN training involves random sampling and weights initialization (in this case), it is usefull to use cross-validation.

# %%
## Compute error metrics
def error_metrics(y_true_train, y_predicted_train, y_true_test, y_predicted_test):
    rmse_train = np.sqrt(mean_squared_error(y_true_train, y_predicted_train))
    rmse_test = np.sqrt(mean_squared_error(y_true_test, y_predicted_test))
    R2_train= r2_score(y_true_train, y_predicted_train)
    R2_test= r2_score(y_true_test, y_predicted_test)
    h = tf.keras.losses.Huber()
    hub_train = h(y_true_train, y_predicted_train).numpy()
    hub_test = h(y_true_test, y_predicted_test).numpy()
    
    print('*********** Benchmark results ***********\n')
    print(f"R2    (Train/Test) = {R2_train:.3f} / {R2_test:.3f}")
    print(f"RMSE  (Train/Test) = {rmse_train:.3f} / {rmse_test:.3f}")
    print(f"Huber (Train/Test) = {hub_train:.3f} / {hub_test:.3f}")

    return (rmse_train, rmse_test, R2_train, R2_test, hub_train, hub_test)

class ModelWithData:
    def __init__(self, history, train_x, train_label, train_predicted, test_x, test_label, test_predicted, score:float, model) -> None:
        self.history = history
        self.train_x = train_x
        self.train_label = train_label
        self.train_predicted = train_predicted
        self.test_x = test_x
        self.test_label = test_label
        self.test_predicted = test_predicted
        self.score = score
        self.model = model

    def isBetter(self, otherScore: float) -> bool:
        return otherScore < 0 or (self.score >= 0 and self.score <= otherScore)

EMPTY_MWD = ModelWithData(None, 0, 0, 0, 0, 0, 0, -1, None)

# %%
def calculate_groups(years, years_in_group=100):
    groups = np.zeros(len(years))

    for i in range(len(years)):
        groups[i] = years[i] // years_in_group
    
    print("Groups:")
    print(groups)
    return groups

# %%
class HarmonizedTimeSplit:
    def __init__(self, validation_portion=0.1, random_seed=12345):
        self._validation_portion = validation_portion
        self._random_seed = random_seed
        self._random = random.Random(random_seed)

    def split(self, X, y = None, groups = None):

        if groups is None:
            raise ValueError("The groups should be specified")
        
        self._random = random.Random(self._random_seed)
        group_dict = self._calculate_group_indices(groups)
        train_indices = []
        test_indices = []

        for group_start, group_end in group_dict.values():
            group_indices = []

            for index in range(group_start, group_end):
                group_indices.append(index)
            
            self._random.shuffle(group_indices)

            validation_end = math.floor(len(group_indices)*self._validation_portion)

            if validation_end <= 0:
                train_indices.extend(group_indices)
            else:
                test_indices.extend(group_indices[:validation_end])
                train_indices.extend(group_indices[validation_end:])

        yield np.asarray(sorted(train_indices)), np.asarray(sorted(test_indices))

        
    def _calculate_group_indices(self, groups) -> dict[str, tuple[int,int]]:
        group_dict = {}
        current_group = None

        for index in range(len(groups)):
            group = str(groups[index])

            if group in group_dict:
                if group != current_group:
                    raise ValueError(f"The groups should be specified in consequtive order. Found group '{group}' again at index {index}")
            else:
                if current_group is not None:
                    (current_group_start, current_group_end) = group_dict[current_group]
                    group_dict[current_group] = (current_group_start, index)
                
                current_group = group
                group_dict[group] = (index, len(groups))

        return group_dict

    def plot_splits(self, groups):
        for train_indices, test_indices in self.split(None, None, groups):
            self._plot_split(train_indices, test_indices, groups)
    
    def _plot_split(self, train_indices, test_indices, groups):
        group_dict = self._calculate_group_indices(groups)

        train_in_group = np.zeros(len(group_dict))
        test_in_group = np.zeros(len(group_dict))
        groups = sorted(group_dict.keys())

        for group_index, group_name in enumerate(groups):
            (group_start, group_end) = group_dict[group_name]
            train_in_group[group_index] = self._count_in_group(train_indices, group_start, group_end)
            test_in_group[group_index] = self._count_in_group(test_indices, group_start, group_end)

        x_values = np.arange(len(groups))
        width = 0.33

        rects = plt.bar(x_values, train_in_group, width, color='k', label='Train')
        plt.bar_label(rects, padding=3)
        rects = plt.bar(x_values + width, test_in_group, width, color='r', label='Test')
        plt.bar_label(rects, padding=3)

        # Labels, legend, and title
        plt.xlabel('Groups')
        plt.xticks(x_values + width/2, groups)
        plt.ylabel('Sample Count')
        plt.legend()
        plt.title('Distribution of Train vs Test in Split')

        # Show the plot
        plt.show()
    
    def _count_in_group(self, indices, group_start, group_end):
        count = 0
        for train_index in indices:
            if train_index >= group_start and train_index < group_end:
                count += 1
            elif train_index >= group_end:
                break

        return count

# %%
hts = HarmonizedTimeSplit(validation_portion=0.1)
y = np.array(labels)
groups = calculate_groups(y, 100)
hts.plot_splits(groups)
# Out:
# Groups:
# [11. 12. 12. ... 20. 20. 20.]

# %%
def evaluations_of_models(features, labels, seed=12345, epochs=100, years_in_group=100, validation_portion=0.01):

    # batch_size = 128
    batch_size = 45

    x = np.array(features, dtype=np.float32)  # Convert to float32 upfront
    y_int = np.array(labels)
    y = y_int.astype(np.float32)  # Use float32
    
    groups = calculate_groups(y_int, years_in_group)
    input_dim = 410
    
    # Ensure proper shape for CNN (add channel dimension if needed)
    if x.ndim == 2:
        x = x.reshape((x.shape[0], x.shape[1], 1))
    
    x_full_tensor = tf.convert_to_tensor(x, dtype=tf.float32)
    y_full_tensor = tf.convert_to_tensor(y, dtype=tf.float32)

    model, name = build_wood_age_incepresnet(input_dim)

    # Define the number of folds for Cross-Validation
    hts = HarmonizedTimeSplit(validation_portion=validation_portion)
    hts.plot_splits(groups)

    scores_train = { "rmse": [], "r2": [], "huber": []}
    scores_test = { "rmse": [], "r2": [], "huber": []}

    bestMwd = EMPTY_MWD

    tensorboard_base_dir = "tb_logs"

    all_mwds = []
    
    for train_index, test_index in hts.split(x, y, groups):
        set_reproducible(seed)

        tensorboard_log_dir = f"{tensorboard_base_dir}/{name}/{seed}"
        tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=tensorboard_log_dir)
        
        # Early stopping to prevent overfitting
        # early_stopping = tf.keras.callbacks.EarlyStopping(
        #     monitor='val_loss',
        #     patience=300,
        #     restore_best_weights=True,
        #     verbose=1
        # )
        
        x_train_tensor = tf.gather(x_full_tensor, train_index)
        y_train_tensor = tf.gather(y_full_tensor, train_index)
        x_test_tensor = tf.gather(x_full_tensor, test_index)
        y_test_tensor = tf.gather(y_full_tensor, test_index)
        x_train = x[train_index]
        y_train = y[train_index]
        x_test = x[test_index]
        y_test = y[test_index]
        
        sample_weight = calculate_sample_weights(y_int[train_index])
        sample_weight_tensor = tf.convert_to_tensor(sample_weight, dtype=tf.float32)
        
        weight_dataset = tf.data.Dataset.from_tensor_slices(sample_weight_tensor)
        
        train_dataset_with_weights = tf.data.Dataset.zip((
            tf.data.Dataset.from_tensor_slices(x_train_tensor),
            tf.data.Dataset.from_tensor_slices(y_train_tensor), 
            weight_dataset
        ))
        
        train_dataset_with_weights = train_dataset_with_weights.shuffle(buffer_size=len(train_index))
        train_dataset_with_weights = train_dataset_with_weights.batch(batch_size)
        train_dataset_with_weights = train_dataset_with_weights.prefetch(tf.data.AUTOTUNE)

        val_dataset = tf.data.Dataset.from_tensor_slices((x_test_tensor, y_test_tensor))
        val_dataset = val_dataset.batch(batch_size).prefetch(tf.data.AUTOTUNE)
        
        callbacks = [tensorboard_callback]
        callbacks += [create_lr_scheduler()]
        # callbacks += [early_stopping]
        
        history = model.fit(train_dataset_with_weights,
                            epochs=epochs,
                            validation_data=val_dataset,
                            verbose=1,
                            callbacks=callbacks)
        
        #evaluation_results = model.evaluate(val_dataset, verbose=0)
        #evaluation_labels = model.metrics_names

        #for j in range(len(evaluation_results)):
        #    print(f'{evaluation_labels[j]}: {evaluation_results[j]}')

        train_pred_dataset = tf.data.Dataset.from_tensor_slices(x_train_tensor).batch(batch_size)
        test_pred_dataset = tf.data.Dataset.from_tensor_slices(x_test_tensor).batch(batch_size)
        train_pred = model.predict(train_pred_dataset, verbose=0)
        test_pred = model.predict(test_pred_dataset, verbose=0)

        train_pred = train_pred.flatten()  # Remove extra dimensions
        test_pred = test_pred.flatten()

        (rmse_train, rmse_test, r2_train, r2_test, huber_train, huber_test) = error_metrics(y_train, train_pred, y_test, test_pred)

        mwd = ModelWithData(history, x_train, y_train, train_pred, x_test, y_test, test_pred, rmse_train, model)

        all_mwds.append(mwd)

        if mwd.isBetter(bestMwd.score):
            bestMwd = mwd

        scores_train["rmse"].append(rmse_train)
        scores_train["r2"].append(r2_train)
        scores_train["huber"].append(huber_train)

        scores_test["rmse"].append(rmse_test)
        scores_test["r2"].append(r2_test)
        scores_test["huber"].append(huber_test)

    ## clear session 
    tf.keras.backend.clear_session()

    scores_train_mean = {}
    scores_test_mean = {}
    num_model = len(scores_train["rmse"])

    for metric in scores_train.keys():
        scores_train_mean[metric] = np.mean(scores_train[metric])
        scores_test_mean[metric] = np.mean(scores_test[metric])
        print(f'Train: {metric} (mean of {num_model} models)= {scores_train_mean[metric]} \nTest: {metric} (mean of {num_model} models)= {scores_test_mean[metric]}')
    
    return (bestMwd, all_mwds)

# %%
seeds = [3173 ]#, 6113, 1]
all_mwds : list[ModelWithData] = []

for seed in seeds:
    print(f"Using seed {seed}")
    (bestMwd, all_mwds_of_run) = evaluations_of_models(features, labels, seed=seed, epochs=270, years_in_group=100, validation_portion=0.1)
    all_mwds.extend(all_mwds_of_run)


# epoch 269 42/50 @ seed 3173
# Out:
# Using seed 3173
# Groups:
# [11. 12. 12. ... 20. 20. 20.]
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 410, 1)    │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d (Conv1D)     │ (None, 205, 64)   │        832 │ input_layer[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 205, 64)   │        256 │ conv1d[0][0]      │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 205, 64)   │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d       │ (None, 103, 64)   │          0 │ activation[0][0]  │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_1 (Conv1D)   │ (None, 103, 32)   │      2,048 │ max_pooling1d[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 103, 32)   │        128 │ conv1d_1[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 103, 32)   │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_2 (Conv1D)   │ (None, 103, 32)   │      3,072 │ activation_1[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_3 (Conv1D)   │ (None, 103, 64)   │     14,336 │ activation_1[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_4 (Conv1D)   │ (None, 103, 32)   │     11,264 │ activation_1[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 103, 128)  │          0 │ conv1d_2[0][0],   │
# │ (Concatenate)       │                   │            │ conv1d_3[0][0],   │
# │                     │                   │            │ conv1d_4[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_5 (Conv1D)   │ (None, 103, 128)  │     16,384 │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_6 (Conv1D)   │ (None, 103, 128)  │      8,192 │ max_pooling1d[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 103, 128)  │        512 │ conv1d_5[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 103, 128)  │        512 │ conv1d_6[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 103, 128)  │          0 │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 103, 128)  │          0 │ add[0][0]         │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_7 (Conv1D)   │ (None, 103, 32)   │      4,096 │ activation_2[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 103, 32)   │        128 │ conv1d_7[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 103, 32)   │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_8 (Conv1D)   │ (None, 103, 32)   │      3,072 │ activation_3[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_9 (Conv1D)   │ (None, 103, 64)   │     14,336 │ activation_3[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_10 (Conv1D)  │ (None, 103, 32)   │     11,264 │ activation_3[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 103, 128)  │          0 │ conv1d_8[0][0],   │
# │ (Concatenate)       │                   │            │ conv1d_9[0][0],   │
# │                     │                   │            │ conv1d_10[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_11 (Conv1D)  │ (None, 103, 128)  │     16,384 │ concatenate_1[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 103, 128)  │        512 │ conv1d_11[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 103, 128)  │          0 │ batch_normalizat… │
# │                     │                   │            │ activation_2[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 103, 128)  │          0 │ add_1[0][0]       │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d_1     │ (None, 52, 128)   │          0 │ activation_4[0][… │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_12 (Conv1D)  │ (None, 52, 64)    │      8,192 │ max_pooling1d_1[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 52, 64)    │        256 │ conv1d_12[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (None, 52, 64)    │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_13 (Conv1D)  │ (None, 52, 64)    │     12,288 │ activation_5[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_14 (Conv1D)  │ (None, 52, 128)   │     57,344 │ activation_5[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_15 (Conv1D)  │ (None, 52, 64)    │     45,056 │ activation_5[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 52, 256)   │          0 │ conv1d_13[0][0],  │
# │ (Concatenate)       │                   │            │ conv1d_14[0][0],  │
# │                     │                   │            │ conv1d_15[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_16 (Conv1D)  │ (None, 52, 256)   │     65,536 │ concatenate_2[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_17 (Conv1D)  │ (None, 52, 256)   │     32,768 │ max_pooling1d_1[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 52, 256)   │      1,024 │ conv1d_16[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 52, 256)   │      1,024 │ conv1d_17[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 52, 256)   │          0 │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_6        │ (None, 52, 256)   │          0 │ add_2[0][0]       │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_18 (Conv1D)  │ (None, 52, 64)    │     16,384 │ activation_6[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 52, 64)    │        256 │ conv1d_18[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_7        │ (None, 52, 64)    │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_19 (Conv1D)  │ (None, 52, 64)    │     12,288 │ activation_7[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_20 (Conv1D)  │ (None, 52, 128)   │     57,344 │ activation_7[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_21 (Conv1D)  │ (None, 52, 64)    │     45,056 │ activation_7[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 52, 256)   │          0 │ conv1d_19[0][0],  │
# │ (Concatenate)       │                   │            │ conv1d_20[0][0],  │
# │                     │                   │            │ conv1d_21[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_22 (Conv1D)  │ (None, 52, 256)   │     65,536 │ concatenate_3[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 52, 256)   │      1,024 │ conv1d_22[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 52, 256)   │          0 │ batch_normalizat… │
# │                     │                   │            │ activation_6[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_8        │ (None, 52, 256)   │          0 │ add_3[0][0]       │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d_2     │ (None, 26, 256)   │          0 │ activation_8[0][… │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 256)       │          0 │ max_pooling1d_2[… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 64)        │     16,448 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ age_output (Dense)  │ (None, 1)         │         65 │ dense[0][0]       │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 545,217 (2.08 MB)
#  Trainable params: 542,401 (2.07 MB)
#  Non-trainable params: 2,816 (11.00 KB)
# Epoch 1/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 1700.1118 - mean_absolute_error: 1732.7188 - root_mean_squared_error: 1744.3501 - val_loss: 1755.3419 - val_mean_absolute_error: 1740.1621 - val_root_mean_squared_error: 1750.8962 - learning_rate: 0.0010
# Epoch 2/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1598.8098 - mean_absolute_error: 1629.3931 - root_mean_squared_error: 1641.1060 - val_loss: 1741.3324 - val_mean_absolute_error: 1726.1526 - val_root_mean_squared_error: 1736.9731 - learning_rate: 0.0010
# Epoch 3/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1354.4645 - mean_absolute_error: 1380.4410 - root_mean_squared_error: 1394.8723 - val_loss: 1707.7731 - val_mean_absolute_error: 1692.5942 - val_root_mean_squared_error: 1703.6273 - learning_rate: 0.0010
# Epoch 4/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 986.1077 - mean_absolute_error: 1005.7910 - root_mean_squared_error: 1029.4023 - val_loss: 1641.9052 - val_mean_absolute_error: 1626.7279 - val_root_mean_squared_error: 1638.2031 - learning_rate: 0.0010
# Epoch 5/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 492.6737 - mean_absolute_error: 503.5966 - root_mean_squared_error: 548.2802 - val_loss: 1454.9990 - val_mean_absolute_error: 1439.8235 - val_root_mean_squared_error: 1452.7751 - learning_rate: 0.0010
# Epoch 6/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 124.0551 - mean_absolute_error: 126.6764 - root_mean_squared_error: 157.7097 - val_loss: 942.7220 - val_mean_absolute_error: 927.5606 - val_root_mean_squared_error: 947.5206 - learning_rate: 0.0010
# Epoch 7/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 94.9770 - mean_absolute_error: 96.8904 - root_mean_squared_error: 130.4874 - val_loss: 978.9653 - val_mean_absolute_error: 963.7974 - val_root_mean_squared_error: 983.0320 - learning_rate: 0.0010
# Epoch 8/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 98.5731 - mean_absolute_error: 100.5868 - root_mean_squared_error: 131.2599 - val_loss: 961.8186 - val_mean_absolute_error: 946.6548 - val_root_mean_squared_error: 966.2175 - learning_rate: 0.0010
# Epoch 9/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 91.8256 - mean_absolute_error: 93.6550 - root_mean_squared_error: 125.1158 - val_loss: 882.3845 - val_mean_absolute_error: 867.2246 - val_root_mean_squared_error: 888.5344 - learning_rate: 0.0010
# Epoch 10/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 88.2277 - mean_absolute_error: 89.9822 - root_mean_squared_error: 120.8327 - val_loss: 1036.3746 - val_mean_absolute_error: 1021.2894 - val_root_mean_squared_error: 1039.3389 - learning_rate: 0.0010
# Epoch 11/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 78.2407 - mean_absolute_error: 79.8747 - root_mean_squared_error: 110.8387 - val_loss: 952.8405 - val_mean_absolute_error: 937.7662 - val_root_mean_squared_error: 957.3610 - learning_rate: 0.0010
# Epoch 12/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 81.6977 - mean_absolute_error: 83.3604 - root_mean_squared_error: 113.4210 - val_loss: 828.1582 - val_mean_absolute_error: 813.2220 - val_root_mean_squared_error: 835.4911 - learning_rate: 0.0010
# Epoch 13/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 79.9021 - mean_absolute_error: 81.5405 - root_mean_squared_error: 113.8539 - val_loss: 695.8698 - val_mean_absolute_error: 680.9665 - val_root_mean_squared_error: 707.3339 - learning_rate: 0.0010
# Epoch 14/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 77.8074 - mean_absolute_error: 79.4502 - root_mean_squared_error: 109.5507 - val_loss: 804.6224 - val_mean_absolute_error: 789.6516 - val_root_mean_squared_error: 812.6285 - learning_rate: 0.0010
# Epoch 15/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 74.9283 - mean_absolute_error: 76.4935 - root_mean_squared_error: 105.5068 - val_loss: 834.3130 - val_mean_absolute_error: 819.5295 - val_root_mean_squared_error: 841.3591 - learning_rate: 0.0010
# Epoch 16/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 74.9365 - mean_absolute_error: 76.5295 - root_mean_squared_error: 104.7384 - val_loss: 690.6175 - val_mean_absolute_error: 676.1821 - val_root_mean_squared_error: 701.7895 - learning_rate: 0.0010
# Epoch 17/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 74.0299 - mean_absolute_error: 75.5686 - root_mean_squared_error: 105.5718 - val_loss: 674.7757 - val_mean_absolute_error: 660.6194 - val_root_mean_squared_error: 686.4984 - learning_rate: 0.0010
# Epoch 18/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 76.3614 - mean_absolute_error: 78.0355 - root_mean_squared_error: 105.1970 - val_loss: 438.2496 - val_mean_absolute_error: 425.0820 - val_root_mean_squared_error: 459.2638 - learning_rate: 0.0010
# Epoch 19/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 75.6391 - mean_absolute_error: 77.1881 - root_mean_squared_error: 107.4971 - val_loss: 452.9940 - val_mean_absolute_error: 439.9089 - val_root_mean_squared_error: 473.3410 - learning_rate: 0.0010
# Epoch 20/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 70.5053 - mean_absolute_error: 72.0319 - root_mean_squared_error: 98.7878 - val_loss: 393.5888 - val_mean_absolute_error: 381.4889 - val_root_mean_squared_error: 414.6772 - learning_rate: 0.0010
# Epoch 21/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 74.1082 - mean_absolute_error: 75.6828 - root_mean_squared_error: 106.1892 - val_loss: 204.5527 - val_mean_absolute_error: 196.2042 - val_root_mean_squared_error: 224.1046 - learning_rate: 0.0010
# Epoch 22/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 73.9768 - mean_absolute_error: 75.5218 - root_mean_squared_error: 105.2215 - val_loss: 169.6139 - val_mean_absolute_error: 163.4064 - val_root_mean_squared_error: 188.7912 - learning_rate: 0.0010
# Epoch 23/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 74.6138 - mean_absolute_error: 76.2130 - root_mean_squared_error: 105.8099 - val_loss: 117.6605 - val_mean_absolute_error: 121.3817 - val_root_mean_squared_error: 165.1811 - learning_rate: 0.0010
# Epoch 24/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 77.3209 - mean_absolute_error: 78.9655 - root_mean_squared_error: 108.1891 - val_loss: 101.6372 - val_mean_absolute_error: 105.3892 - val_root_mean_squared_error: 145.3082 - learning_rate: 0.0010
# Epoch 25/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 68.7162 - mean_absolute_error: 70.2384 - root_mean_squared_error: 95.9853 - val_loss: 93.4515 - val_mean_absolute_error: 95.5370 - val_root_mean_squared_error: 128.7616 - learning_rate: 0.0010
# Epoch 26/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 77.9027 - mean_absolute_error: 79.5147 - root_mean_squared_error: 110.6599 - val_loss: 88.7642 - val_mean_absolute_error: 93.5789 - val_root_mean_squared_error: 135.0692 - learning_rate: 0.0010
# Epoch 27/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 67.6587 - mean_absolute_error: 69.1632 - root_mean_squared_error: 95.7953 - val_loss: 75.2306 - val_mean_absolute_error: 78.1969 - val_root_mean_squared_error: 107.5756 - learning_rate: 0.0010
# Epoch 28/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 70.6944 - mean_absolute_error: 72.2472 - root_mean_squared_error: 99.5979 - val_loss: 154.4540 - val_mean_absolute_error: 152.8628 - val_root_mean_squared_error: 168.5488 - learning_rate: 0.0010
# Epoch 29/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 67.4168 - mean_absolute_error: 68.9085 - root_mean_squared_error: 97.1988 - val_loss: 76.1099 - val_mean_absolute_error: 78.4025 - val_root_mean_squared_error: 104.9979 - learning_rate: 0.0010
# Epoch 30/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 70.6063 - mean_absolute_error: 72.1167 - root_mean_squared_error: 100.4106 - val_loss: 69.5451 - val_mean_absolute_error: 73.5870 - val_root_mean_squared_error: 109.7819 - learning_rate: 0.0010
# Epoch 31/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 69.1305 - mean_absolute_error: 70.6541 - root_mean_squared_error: 98.7303 - val_loss: 181.7973 - val_mean_absolute_error: 184.2304 - val_root_mean_squared_error: 205.6934 - learning_rate: 0.0010
# Epoch 32/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 70.5650 - mean_absolute_error: 72.1090 - root_mean_squared_error: 99.5143 - val_loss: 78.8012 - val_mean_absolute_error: 80.0323 - val_root_mean_squared_error: 98.7398 - learning_rate: 0.0010
# Epoch 33/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 68.6426 - mean_absolute_error: 70.1047 - root_mean_squared_error: 99.4608 - val_loss: 67.2058 - val_mean_absolute_error: 69.7056 - val_root_mean_squared_error: 91.7543 - learning_rate: 0.0010
# Epoch 34/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 72.0105 - mean_absolute_error: 73.5585 - root_mean_squared_error: 102.8840 - val_loss: 82.1267 - val_mean_absolute_error: 83.8445 - val_root_mean_squared_error: 102.0684 - learning_rate: 0.0010
# Epoch 35/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 67.2236 - mean_absolute_error: 68.7019 - root_mean_squared_error: 95.9905 - val_loss: 187.9023 - val_mean_absolute_error: 186.1175 - val_root_mean_squared_error: 202.8446 - learning_rate: 0.0010
# Epoch 36/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 67.3992 - mean_absolute_error: 68.8930 - root_mean_squared_error: 97.8674 - val_loss: 68.8612 - val_mean_absolute_error: 71.0495 - val_root_mean_squared_error: 92.7293 - learning_rate: 0.0010
# Epoch 37/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 70.6460 - mean_absolute_error: 72.2046 - root_mean_squared_error: 100.4182 - val_loss: 61.1929 - val_mean_absolute_error: 64.8731 - val_root_mean_squared_error: 95.5051 - learning_rate: 0.0010
# Epoch 38/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 67.3649 - mean_absolute_error: 68.8453 - root_mean_squared_error: 95.5369 - val_loss: 60.7047 - val_mean_absolute_error: 63.7709 - val_root_mean_squared_error: 90.0676 - learning_rate: 0.0010
# Epoch 39/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 65.0813 - mean_absolute_error: 66.5228 - root_mean_squared_error: 94.4749 - val_loss: 139.0457 - val_mean_absolute_error: 138.3382 - val_root_mean_squared_error: 152.7558 - learning_rate: 0.0010
# Epoch 40/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 71.2031 - mean_absolute_error: 72.7855 - root_mean_squared_error: 99.1709 - val_loss: 89.5819 - val_mean_absolute_error: 91.4491 - val_root_mean_squared_error: 114.1349 - learning_rate: 0.0010
# Epoch 41/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 68.0382 - mean_absolute_error: 69.5489 - root_mean_squared_error: 95.5675 - val_loss: 263.7921 - val_mean_absolute_error: 264.5437 - val_root_mean_squared_error: 279.4539 - learning_rate: 0.0010
# Epoch 42/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 66.8329 - mean_absolute_error: 68.3548 - root_mean_squared_error: 93.7975 - val_loss: 59.7578 - val_mean_absolute_error: 63.0748 - val_root_mean_squared_error: 88.7149 - learning_rate: 0.0010
# Epoch 43/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 67.2183 - mean_absolute_error: 68.6842 - root_mean_squared_error: 97.2365 - val_loss: 158.1036 - val_mean_absolute_error: 160.3003 - val_root_mean_squared_error: 180.6192 - learning_rate: 0.0010
# Epoch 44/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 67.6924 - mean_absolute_error: 69.1400 - root_mean_squared_error: 98.8304 - val_loss: 68.2695 - val_mean_absolute_error: 72.0079 - val_root_mean_squared_error: 97.8301 - learning_rate: 0.0010
# Epoch 45/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 67.4475 - mean_absolute_error: 68.9459 - root_mean_squared_error: 99.0102 - val_loss: 183.8231 - val_mean_absolute_error: 185.3320 - val_root_mean_squared_error: 203.4438 - learning_rate: 0.0010
# Epoch 46/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 71.8580 - mean_absolute_error: 73.4564 - root_mean_squared_error: 99.6496 - val_loss: 79.4801 - val_mean_absolute_error: 81.6990 - val_root_mean_squared_error: 105.4108 - learning_rate: 0.0010
# Epoch 47/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 63.7290 - mean_absolute_error: 65.1408 - root_mean_squared_error: 93.0943 - val_loss: 73.5903 - val_mean_absolute_error: 77.5774 - val_root_mean_squared_error: 107.6829 - learning_rate: 0.0010
# Epoch 48/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 62.8171 - mean_absolute_error: 64.2168 - root_mean_squared_error: 90.8174 - val_loss: 147.4383 - val_mean_absolute_error: 151.2724 - val_root_mean_squared_error: 178.0559 - learning_rate: 0.0010
# Epoch 49/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 70.8622 - mean_absolute_error: 72.4152 - root_mean_squared_error: 102.9440 - val_loss: 160.4275 - val_mean_absolute_error: 162.6105 - val_root_mean_squared_error: 182.6572 - learning_rate: 0.0010
# Epoch 50/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 65.7656 - mean_absolute_error: 67.2136 - root_mean_squared_error: 93.7637 - val_loss: 83.1857 - val_mean_absolute_error: 85.5172 - val_root_mean_squared_error: 108.0932 - learning_rate: 0.0010
# Epoch 51/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 63.7394 - mean_absolute_error: 65.2097 - root_mean_squared_error: 89.8527 - val_loss: 91.2248 - val_mean_absolute_error: 92.0398 - val_root_mean_squared_error: 108.0682 - learning_rate: 0.0010
# Epoch 52/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 62.2955 - mean_absolute_error: 63.7363 - root_mean_squared_error: 90.3341 - val_loss: 104.1917 - val_mean_absolute_error: 106.7228 - val_root_mean_squared_error: 131.4192 - learning_rate: 0.0010
# Epoch 53/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 64.9376 - mean_absolute_error: 66.3872 - root_mean_squared_error: 93.0191 - val_loss: 55.9685 - val_mean_absolute_error: 59.2682 - val_root_mean_squared_error: 88.3689 - learning_rate: 0.0010
# Epoch 54/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 62.5891 - mean_absolute_error: 64.0588 - root_mean_squared_error: 87.9713 - val_loss: 62.8497 - val_mean_absolute_error: 65.2552 - val_root_mean_squared_error: 86.5183 - learning_rate: 0.0010
# Epoch 55/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 64.2599 - mean_absolute_error: 65.7538 - root_mean_squared_error: 89.8591 - val_loss: 72.3918 - val_mean_absolute_error: 75.1771 - val_root_mean_squared_error: 96.7686 - learning_rate: 0.0010
# Epoch 56/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 65.3784 - mean_absolute_error: 66.8695 - root_mean_squared_error: 92.0544 - val_loss: 185.8674 - val_mean_absolute_error: 186.2436 - val_root_mean_squared_error: 203.8861 - learning_rate: 0.0010
# Epoch 57/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 61.8594 - mean_absolute_error: 63.3058 - root_mean_squared_error: 90.7299 - val_loss: 59.5291 - val_mean_absolute_error: 62.6116 - val_root_mean_squared_error: 86.5724 - learning_rate: 0.0010
# Epoch 58/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 67.9688 - mean_absolute_error: 69.4694 - root_mean_squared_error: 97.2423 - val_loss: 219.6558 - val_mean_absolute_error: 220.5530 - val_root_mean_squared_error: 234.8685 - learning_rate: 0.0010
# Epoch 59/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 63.6162 - mean_absolute_error: 65.0573 - root_mean_squared_error: 91.0289 - val_loss: 129.1429 - val_mean_absolute_error: 128.3452 - val_root_mean_squared_error: 146.4662 - learning_rate: 0.0010
# Epoch 60/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 62.6816 - mean_absolute_error: 64.1339 - root_mean_squared_error: 89.3752 - val_loss: 74.5104 - val_mean_absolute_error: 76.1371 - val_root_mean_squared_error: 95.2808 - learning_rate: 0.0010
# Epoch 61/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 59.2858 - mean_absolute_error: 60.6574 - root_mean_squared_error: 88.4369 - val_loss: 128.1323 - val_mean_absolute_error: 127.8186 - val_root_mean_squared_error: 144.3353 - learning_rate: 0.0010
# Epoch 62/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 62.0482 - mean_absolute_error: 63.4879 - root_mean_squared_error: 87.7518 - val_loss: 61.2019 - val_mean_absolute_error: 63.9184 - val_root_mean_squared_error: 84.1979 - learning_rate: 0.0010
# Epoch 63/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 60.0553 - mean_absolute_error: 61.4706 - root_mean_squared_error: 85.5384 - val_loss: 111.5939 - val_mean_absolute_error: 113.2805 - val_root_mean_squared_error: 130.7618 - learning_rate: 0.0010
# Epoch 64/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 57.6903 - mean_absolute_error: 59.0757 - root_mean_squared_error: 83.0903 - val_loss: 142.2375 - val_mean_absolute_error: 144.3503 - val_root_mean_squared_error: 165.9689 - learning_rate: 0.0010
# Epoch 65/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 63.6491 - mean_absolute_error: 65.0875 - root_mean_squared_error: 92.4633 - val_loss: 61.5251 - val_mean_absolute_error: 63.6032 - val_root_mean_squared_error: 84.8693 - learning_rate: 0.0010
# Epoch 66/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 56.0277 - mean_absolute_error: 57.3515 - root_mean_squared_error: 80.7987 - val_loss: 140.9955 - val_mean_absolute_error: 141.0705 - val_root_mean_squared_error: 154.4242 - learning_rate: 0.0010
# Epoch 67/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 56.9881 - mean_absolute_error: 58.3577 - root_mean_squared_error: 80.9577 - val_loss: 108.9672 - val_mean_absolute_error: 108.9675 - val_root_mean_squared_error: 124.5674 - learning_rate: 0.0010
# Epoch 68/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 57.6099 - mean_absolute_error: 58.9603 - root_mean_squared_error: 84.5262 - val_loss: 85.9104 - val_mean_absolute_error: 86.9811 - val_root_mean_squared_error: 102.0917 - learning_rate: 0.0010
# Epoch 69/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 54.7144 - mean_absolute_error: 56.0283 - root_mean_squared_error: 81.8128 - val_loss: 69.3747 - val_mean_absolute_error: 71.5272 - val_root_mean_squared_error: 92.6649 - learning_rate: 0.0010
# Epoch 70/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 55.6428 - mean_absolute_error: 56.9785 - root_mean_squared_error: 80.1258 - val_loss: 146.8971 - val_mean_absolute_error: 147.5526 - val_root_mean_squared_error: 164.0237 - learning_rate: 0.0010
# Epoch 71/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 62.7717 - mean_absolute_error: 64.2509 - root_mean_squared_error: 90.6273 - val_loss: 53.1898 - val_mean_absolute_error: 55.7459 - val_root_mean_squared_error: 78.9459 - learning_rate: 0.0010
# Epoch 72/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 61.3331 - mean_absolute_error: 62.7337 - root_mean_squared_error: 88.5655 - val_loss: 57.9964 - val_mean_absolute_error: 61.1427 - val_root_mean_squared_error: 85.8999 - learning_rate: 0.0010
# Epoch 73/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 59.3724 - mean_absolute_error: 60.7997 - root_mean_squared_error: 84.9717 - val_loss: 90.5449 - val_mean_absolute_error: 93.0796 - val_root_mean_squared_error: 114.9538 - learning_rate: 0.0010
# Epoch 74/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 61.0461 - mean_absolute_error: 62.4205 - root_mean_squared_error: 89.0591 - val_loss: 153.3507 - val_mean_absolute_error: 153.9999 - val_root_mean_squared_error: 170.5204 - learning_rate: 0.0010
# Epoch 75/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 61.4653 - mean_absolute_error: 62.9075 - root_mean_squared_error: 86.0925 - val_loss: 51.2771 - val_mean_absolute_error: 54.1584 - val_root_mean_squared_error: 78.9086 - learning_rate: 0.0010
# Epoch 76/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 52.1237 - mean_absolute_error: 53.4355 - root_mean_squared_error: 76.3679 - val_loss: 122.3424 - val_mean_absolute_error: 123.2914 - val_root_mean_squared_error: 139.3450 - learning_rate: 0.0010
# Epoch 77/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 50.0699 - mean_absolute_error: 51.3046 - root_mean_squared_error: 73.1917 - val_loss: 146.3789 - val_mean_absolute_error: 145.8658 - val_root_mean_squared_error: 158.4429 - learning_rate: 0.0010
# Epoch 78/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 56.5599 - mean_absolute_error: 57.8974 - root_mean_squared_error: 82.5626 - val_loss: 60.1206 - val_mean_absolute_error: 63.2761 - val_root_mean_squared_error: 88.6993 - learning_rate: 0.0010
# Epoch 79/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 60.0929 - mean_absolute_error: 61.4845 - root_mean_squared_error: 87.4561 - val_loss: 236.6230 - val_mean_absolute_error: 238.6332 - val_root_mean_squared_error: 253.9482 - learning_rate: 0.0010
# Epoch 80/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 66.1507 - mean_absolute_error: 67.6375 - root_mean_squared_error: 92.0276 - val_loss: 54.6291 - val_mean_absolute_error: 57.4616 - val_root_mean_squared_error: 80.4311 - learning_rate: 0.0010
# Epoch 81/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 58.6602 - mean_absolute_error: 60.0528 - root_mean_squared_error: 83.2546 - val_loss: 99.3190 - val_mean_absolute_error: 101.2890 - val_root_mean_squared_error: 123.4009 - learning_rate: 0.0010
# Epoch 82/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 67.6762 - mean_absolute_error: 69.2108 - root_mean_squared_error: 94.7229 - val_loss: 62.7600 - val_mean_absolute_error: 65.7916 - val_root_mean_squared_error: 91.5038 - learning_rate: 0.0010
# Epoch 83/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 58.7642 - mean_absolute_error: 60.1907 - root_mean_squared_error: 84.3161 - val_loss: 101.6836 - val_mean_absolute_error: 104.7251 - val_root_mean_squared_error: 130.9495 - learning_rate: 0.0010
# Epoch 84/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 59.3506 - mean_absolute_error: 60.7573 - root_mean_squared_error: 85.0616 - val_loss: 63.5907 - val_mean_absolute_error: 65.5961 - val_root_mean_squared_error: 86.6438 - learning_rate: 0.0010
# Epoch 85/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 55.2887 - mean_absolute_error: 56.6078 - root_mean_squared_error: 82.2974 - val_loss: 58.0983 - val_mean_absolute_error: 60.6958 - val_root_mean_squared_error: 88.3773 - learning_rate: 0.0010
# Epoch 86/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 55.1157 - mean_absolute_error: 56.4695 - root_mean_squared_error: 80.3963 - val_loss: 153.7667 - val_mean_absolute_error: 154.0591 - val_root_mean_squared_error: 170.7039 - learning_rate: 0.0010
# Epoch 87/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 56.4677 - mean_absolute_error: 57.8153 - root_mean_squared_error: 81.9118 - val_loss: 56.9871 - val_mean_absolute_error: 58.5731 - val_root_mean_squared_error: 79.7395 - learning_rate: 0.0010
# Epoch 88/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 50.6352 - mean_absolute_error: 51.8791 - root_mean_squared_error: 75.1474 - val_loss: 52.6541 - val_mean_absolute_error: 55.1395 - val_root_mean_squared_error: 75.7999 - learning_rate: 0.0010
# Epoch 89/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 58.7290 - mean_absolute_error: 60.1066 - root_mean_squared_error: 86.1542 - val_loss: 81.5014 - val_mean_absolute_error: 82.5109 - val_root_mean_squared_error: 101.0721 - learning_rate: 0.0010
# Epoch 90/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 52.7524 - mean_absolute_error: 54.0419 - root_mean_squared_error: 76.8176 - val_loss: 52.8947 - val_mean_absolute_error: 56.0861 - val_root_mean_squared_error: 80.8329 - learning_rate: 0.0010
# Epoch 91/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 55.1851 - mean_absolute_error: 56.5443 - root_mean_squared_error: 81.6611 - val_loss: 57.4424 - val_mean_absolute_error: 60.1443 - val_root_mean_squared_error: 80.8070 - learning_rate: 0.0010
# Epoch 92/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 55.6473 - mean_absolute_error: 57.0101 - root_mean_squared_error: 78.9472 - val_loss: 100.4336 - val_mean_absolute_error: 103.2868 - val_root_mean_squared_error: 124.9337 - learning_rate: 0.0010
# Epoch 93/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 53.0843 - mean_absolute_error: 54.3737 - root_mean_squared_error: 79.9410 - val_loss: 77.1020 - val_mean_absolute_error: 77.7292 - val_root_mean_squared_error: 93.1693 - learning_rate: 0.0010
# Epoch 94/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 55.4158 - mean_absolute_error: 56.7585 - root_mean_squared_error: 82.3978 - val_loss: 58.7931 - val_mean_absolute_error: 61.3204 - val_root_mean_squared_error: 85.8967 - learning_rate: 0.0010
# Epoch 95/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 55.2512 - mean_absolute_error: 56.5583 - root_mean_squared_error: 82.0875 - val_loss: 57.9905 - val_mean_absolute_error: 60.3834 - val_root_mean_squared_error: 86.6543 - learning_rate: 0.0010
# Epoch 96/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 53.3868 - mean_absolute_error: 54.7008 - root_mean_squared_error: 76.9208 - val_loss: 133.3346 - val_mean_absolute_error: 133.1848 - val_root_mean_squared_error: 144.5656 - learning_rate: 0.0010
# Epoch 97/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 57.3218 - mean_absolute_error: 58.6710 - root_mean_squared_error: 82.0835 - val_loss: 117.6194 - val_mean_absolute_error: 118.3728 - val_root_mean_squared_error: 135.4007 - learning_rate: 0.0010
# Epoch 98/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 53.1243 - mean_absolute_error: 54.4365 - root_mean_squared_error: 75.1714 - val_loss: 64.0787 - val_mean_absolute_error: 65.9604 - val_root_mean_squared_error: 80.1338 - learning_rate: 0.0010
# Epoch 99/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 52.6341 - mean_absolute_error: 53.9499 - root_mean_squared_error: 75.9372 - val_loss: 59.7390 - val_mean_absolute_error: 62.7955 - val_root_mean_squared_error: 88.0379 - learning_rate: 0.0010
# Epoch 100/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 55.6110 - mean_absolute_error: 56.9320 - root_mean_squared_error: 81.8921 - val_loss: 91.5736 - val_mean_absolute_error: 92.2950 - val_root_mean_squared_error: 110.9065 - learning_rate: 0.0010
# Epoch 101/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 57.8118 - mean_absolute_error: 59.1870 - root_mean_squared_error: 82.7927 - val_loss: 62.2994 - val_mean_absolute_error: 65.4094 - val_root_mean_squared_error: 95.3076 - learning_rate: 0.0010
# Epoch 102/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 55.3192 - mean_absolute_error: 56.6530 - root_mean_squared_error: 79.5231 - val_loss: 89.7276 - val_mean_absolute_error: 92.0064 - val_root_mean_squared_error: 108.4557 - learning_rate: 0.0010
# Epoch 103/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 54.9049 - mean_absolute_error: 56.1987 - root_mean_squared_error: 80.7618 - val_loss: 59.0834 - val_mean_absolute_error: 61.6097 - val_root_mean_squared_error: 85.3134 - learning_rate: 0.0010
# Epoch 104/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 54.6365 - mean_absolute_error: 55.9444 - root_mean_squared_error: 81.7815 - val_loss: 48.6889 - val_mean_absolute_error: 51.5897 - val_root_mean_squared_error: 76.9668 - learning_rate: 0.0010
# Epoch 105/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 52.4369 - mean_absolute_error: 53.7541 - root_mean_squared_error: 76.0912 - val_loss: 62.6739 - val_mean_absolute_error: 64.1922 - val_root_mean_squared_error: 81.0888 - learning_rate: 0.0010
# Epoch 106/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 49.1194 - mean_absolute_error: 50.3935 - root_mean_squared_error: 73.6579 - val_loss: 70.4702 - val_mean_absolute_error: 72.2460 - val_root_mean_squared_error: 93.2603 - learning_rate: 0.0010
# Epoch 107/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 54.2482 - mean_absolute_error: 55.5193 - root_mean_squared_error: 80.2655 - val_loss: 90.0897 - val_mean_absolute_error: 93.3404 - val_root_mean_squared_error: 118.2222 - learning_rate: 0.0010
# Epoch 108/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 52.5264 - mean_absolute_error: 53.8105 - root_mean_squared_error: 78.0005 - val_loss: 70.3960 - val_mean_absolute_error: 72.8547 - val_root_mean_squared_error: 91.9316 - learning_rate: 0.0010
# Epoch 109/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 51.6424 - mean_absolute_error: 52.9386 - root_mean_squared_error: 76.0589 - val_loss: 85.7542 - val_mean_absolute_error: 86.5122 - val_root_mean_squared_error: 101.2266 - learning_rate: 0.0010
# Epoch 110/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 52.3899 - mean_absolute_error: 53.6798 - root_mean_squared_error: 76.5581 - val_loss: 103.0381 - val_mean_absolute_error: 103.2378 - val_root_mean_squared_error: 119.6120 - learning_rate: 0.0010
# Epoch 111/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 54.3108 - mean_absolute_error: 55.6836 - root_mean_squared_error: 76.3306 - val_loss: 134.2048 - val_mean_absolute_error: 135.2661 - val_root_mean_squared_error: 151.2514 - learning_rate: 0.0010
# Epoch 112/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 53.6920 - mean_absolute_error: 55.0355 - root_mean_squared_error: 77.2372 - val_loss: 95.0938 - val_mean_absolute_error: 94.7475 - val_root_mean_squared_error: 106.6469 - learning_rate: 0.0010
# Epoch 113/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 47.6470 - mean_absolute_error: 48.8648 - root_mean_squared_error: 72.5903 - val_loss: 47.0308 - val_mean_absolute_error: 49.7980 - val_root_mean_squared_error: 74.2360 - learning_rate: 0.0010
# Epoch 114/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 51.3493 - mean_absolute_error: 52.5972 - root_mean_squared_error: 77.0564 - val_loss: 97.4557 - val_mean_absolute_error: 99.8597 - val_root_mean_squared_error: 120.2342 - learning_rate: 0.0010
# Epoch 115/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 47.2042 - mean_absolute_error: 48.4124 - root_mean_squared_error: 71.4479 - val_loss: 69.2760 - val_mean_absolute_error: 70.0436 - val_root_mean_squared_error: 81.6942 - learning_rate: 0.0010
# Epoch 116/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 51.5214 - mean_absolute_error: 52.8229 - root_mean_squared_error: 75.9611 - val_loss: 62.1578 - val_mean_absolute_error: 65.2299 - val_root_mean_squared_error: 88.0594 - learning_rate: 0.0010
# Epoch 117/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 49.8862 - mean_absolute_error: 51.1415 - root_mean_squared_error: 76.1127 - val_loss: 92.9597 - val_mean_absolute_error: 94.5799 - val_root_mean_squared_error: 112.0814 - learning_rate: 0.0010
# Epoch 118/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 54.5709 - mean_absolute_error: 55.8522 - root_mean_squared_error: 80.3297 - val_loss: 122.9175 - val_mean_absolute_error: 126.1069 - val_root_mean_squared_error: 145.6491 - learning_rate: 0.0010
# Epoch 119/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 52.8795 - mean_absolute_error: 54.1625 - root_mean_squared_error: 78.0929 - val_loss: 83.5116 - val_mean_absolute_error: 84.1800 - val_root_mean_squared_error: 98.1245 - learning_rate: 0.0010
# Epoch 120/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 55.2831 - mean_absolute_error: 56.6415 - root_mean_squared_error: 78.2220 - val_loss: 106.6592 - val_mean_absolute_error: 108.4408 - val_root_mean_squared_error: 126.4987 - learning_rate: 0.0010
# Epoch 121/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 47.7483 - mean_absolute_error: 48.9737 - root_mean_squared_error: 71.5354 - val_loss: 71.1355 - val_mean_absolute_error: 73.3054 - val_root_mean_squared_error: 93.8448 - learning_rate: 0.0010
# Epoch 122/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 48.4741 - mean_absolute_error: 49.7023 - root_mean_squared_error: 72.6206 - val_loss: 87.6225 - val_mean_absolute_error: 88.8581 - val_root_mean_squared_error: 104.1167 - learning_rate: 0.0010
# Epoch 123/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 47.7327 - mean_absolute_error: 48.9677 - root_mean_squared_error: 70.3558 - val_loss: 59.9659 - val_mean_absolute_error: 62.1127 - val_root_mean_squared_error: 78.5454 - learning_rate: 0.0010
# Epoch 124/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 46.1247 - mean_absolute_error: 47.3328 - root_mean_squared_error: 69.2838 - val_loss: 102.5571 - val_mean_absolute_error: 103.9100 - val_root_mean_squared_error: 120.2293 - learning_rate: 0.0010
# Epoch 125/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 44.7599 - mean_absolute_error: 45.9261 - root_mean_squared_error: 68.0748 - val_loss: 127.6544 - val_mean_absolute_error: 128.2073 - val_root_mean_squared_error: 142.5799 - learning_rate: 0.0010
# Epoch 126/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 49.9637 - mean_absolute_error: 51.2210 - root_mean_squared_error: 73.4935 - val_loss: 65.9270 - val_mean_absolute_error: 68.0677 - val_root_mean_squared_error: 86.7253 - learning_rate: 0.0010
# Epoch 127/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 44.3309 - mean_absolute_error: 45.5071 - root_mean_squared_error: 67.3420 - val_loss: 74.6016 - val_mean_absolute_error: 75.6738 - val_root_mean_squared_error: 90.5123 - learning_rate: 0.0010
# Epoch 128/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 55.8144 - mean_absolute_error: 57.1974 - root_mean_squared_error: 75.0123 - val_loss: 74.6704 - val_mean_absolute_error: 77.7647 - val_root_mean_squared_error: 101.0131 - learning_rate: 0.0010
# Epoch 129/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 52.3863 - mean_absolute_error: 53.7277 - root_mean_squared_error: 72.5718 - val_loss: 78.8797 - val_mean_absolute_error: 80.3267 - val_root_mean_squared_error: 93.9979 - learning_rate: 0.0010
# Epoch 130/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 48.0306 - mean_absolute_error: 49.3018 - root_mean_squared_error: 71.0926 - val_loss: 75.9459 - val_mean_absolute_error: 76.2250 - val_root_mean_squared_error: 90.1554 - learning_rate: 0.0010
# Epoch 131/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 46.2563 - mean_absolute_error: 47.4779 - root_mean_squared_error: 69.0462 - val_loss: 81.1479 - val_mean_absolute_error: 82.0660 - val_root_mean_squared_error: 97.2192 - learning_rate: 0.0010
# Epoch 132/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 43.3298 - mean_absolute_error: 44.5208 - root_mean_squared_error: 64.2242 - val_loss: 53.0053 - val_mean_absolute_error: 54.4992 - val_root_mean_squared_error: 75.2778 - learning_rate: 0.0010
# Epoch 133/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 50.7842 - mean_absolute_error: 52.0413 - root_mean_squared_error: 73.2733 - val_loss: 107.9694 - val_mean_absolute_error: 109.2698 - val_root_mean_squared_error: 123.3843 - learning_rate: 0.0010
# Epoch 134/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 44.5097 - mean_absolute_error: 45.6875 - root_mean_squared_error: 66.7316 - val_loss: 97.5757 - val_mean_absolute_error: 98.4188 - val_root_mean_squared_error: 112.2800 - learning_rate: 0.0010
# Epoch 135/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 45.1436 - mean_absolute_error: 46.3662 - root_mean_squared_error: 65.8110 - val_loss: 119.9600 - val_mean_absolute_error: 122.1895 - val_root_mean_squared_error: 139.5044 - learning_rate: 0.0010
# Epoch 136/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 47.0397 - mean_absolute_error: 48.2494 - root_mean_squared_error: 71.5570 - val_loss: 129.8333 - val_mean_absolute_error: 133.3940 - val_root_mean_squared_error: 151.8575 - learning_rate: 0.0010
# Epoch 137/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 44.9118 - mean_absolute_error: 46.0856 - root_mean_squared_error: 66.9350 - val_loss: 57.5276 - val_mean_absolute_error: 60.5796 - val_root_mean_squared_error: 80.0805 - learning_rate: 0.0010
# Epoch 138/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 44.2229 - mean_absolute_error: 45.4332 - root_mean_squared_error: 65.3523 - val_loss: 64.9489 - val_mean_absolute_error: 66.5551 - val_root_mean_squared_error: 82.8915 - learning_rate: 0.0010
# Epoch 139/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 43.0862 - mean_absolute_error: 44.2628 - root_mean_squared_error: 61.9888 - val_loss: 47.2136 - val_mean_absolute_error: 49.9741 - val_root_mean_squared_error: 74.1292 - learning_rate: 0.0010
# Epoch 140/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 43.9589 - mean_absolute_error: 45.1400 - root_mean_squared_error: 63.2580 - val_loss: 87.3071 - val_mean_absolute_error: 88.5719 - val_root_mean_squared_error: 105.9060 - learning_rate: 0.0010
# Epoch 141/270
# ...
# Epoch 210/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 28.2245 - mean_absolute_error: 29.1676 - root_mean_squared_error: 41.4523 - val_loss: 31.9496 - val_mean_absolute_error: 33.6948 - val_root_mean_squared_error: 48.9513 - learning_rate: 0.0010
# Epoch 211/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 28.6542 - mean_absolute_error: 29.6038 - root_mean_squared_error: 43.0633 - val_loss: 43.5148 - val_mean_absolute_error: 44.7587 - val_root_mean_squared_error: 63.1783 - learning_rate: 0.0010
# Epoch 212/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 32.8411 - mean_absolute_error: 33.8688 - root_mean_squared_error: 49.5409 - val_loss: 43.3407 - val_mean_absolute_error: 44.7323 - val_root_mean_squared_error: 62.0065 - learning_rate: 0.0010
# Epoch 213/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 36.5343 - mean_absolute_error: 37.6193 - root_mean_squared_error: 52.9101 - val_loss: 124.4900 - val_mean_absolute_error: 126.2318 - val_root_mean_squared_error: 139.1825 - learning_rate: 0.0010
# Epoch 214/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 31.6871 - mean_absolute_error: 32.6812 - root_mean_squared_error: 47.7690 - val_loss: 105.3121 - val_mean_absolute_error: 105.9827 - val_root_mean_squared_error: 116.5569 - learning_rate: 0.0010
# Epoch 215/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 34.8418 - mean_absolute_error: 35.8808 - root_mean_squared_error: 51.3253 - val_loss: 42.9244 - val_mean_absolute_error: 45.4449 - val_root_mean_squared_error: 67.9352 - learning_rate: 0.0010
# Epoch 216/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 31.2678 - mean_absolute_error: 32.2441 - root_mean_squared_error: 46.6731 - val_loss: 42.6154 - val_mean_absolute_error: 44.2624 - val_root_mean_squared_error: 62.8561 - learning_rate: 0.0010
# Epoch 217/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 30.9524 - mean_absolute_error: 31.9424 - root_mean_squared_error: 47.5442 - val_loss: 81.1378 - val_mean_absolute_error: 81.9693 - val_root_mean_squared_error: 92.3897 - learning_rate: 0.0010
# Epoch 218/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 27.2592 - mean_absolute_error: 28.1709 - root_mean_squared_error: 40.7825 - val_loss: 58.0501 - val_mean_absolute_error: 61.9176 - val_root_mean_squared_error: 94.0678 - learning_rate: 0.0010
# Epoch 219/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 38.2466 - mean_absolute_error: 39.3219 - root_mean_squared_error: 57.2807 - val_loss: 40.9408 - val_mean_absolute_error: 42.8009 - val_root_mean_squared_error: 61.5670 - learning_rate: 0.0010
# Epoch 220/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 29.4122 - mean_absolute_error: 30.3879 - root_mean_squared_error: 43.7643 - val_loss: 74.0045 - val_mean_absolute_error: 75.6617 - val_root_mean_squared_error: 91.7278 - learning_rate: 0.0010
# Epoch 221/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 32.4008 - mean_absolute_error: 33.4203 - root_mean_squared_error: 47.2443 - val_loss: 109.5049 - val_mean_absolute_error: 111.8361 - val_root_mean_squared_error: 128.1673 - learning_rate: 0.0010
# Epoch 222/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 34.7150 - mean_absolute_error: 35.7534 - root_mean_squared_error: 50.0992 - val_loss: 161.7381 - val_mean_absolute_error: 164.6953 - val_root_mean_squared_error: 179.0665 - learning_rate: 0.0010
# Epoch 223/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 41.8543 - mean_absolute_error: 42.9971 - root_mean_squared_error: 59.5159 - val_loss: 49.2637 - val_mean_absolute_error: 52.3130 - val_root_mean_squared_error: 78.0121 - learning_rate: 0.0010
# Epoch 224/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 35.5244 - mean_absolute_error: 36.5789 - root_mean_squared_error: 52.3067 - val_loss: 61.0942 - val_mean_absolute_error: 62.0827 - val_root_mean_squared_error: 80.4151 - learning_rate: 0.0010
# Epoch 225/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 31.6939 - mean_absolute_error: 32.6792 - root_mean_squared_error: 49.6773 - val_loss: 48.2383 - val_mean_absolute_error: 49.3568 - val_root_mean_squared_error: 68.7845 - learning_rate: 0.0010
# Epoch 226/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 39.2592 - mean_absolute_error: 40.3801 - root_mean_squared_error: 57.3782 - val_loss: 53.5641 - val_mean_absolute_error: 54.5022 - val_root_mean_squared_error: 69.3737 - learning_rate: 0.0010
# Epoch 227/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 29.2004 - mean_absolute_error: 30.1573 - root_mean_squared_error: 42.9140 - val_loss: 35.9301 - val_mean_absolute_error: 38.0595 - val_root_mean_squared_error: 58.1302 - learning_rate: 0.0010
# Epoch 228/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 31.6462 - mean_absolute_error: 32.6297 - root_mean_squared_error: 45.9501 - val_loss: 34.2697 - val_mean_absolute_error: 36.1050 - val_root_mean_squared_error: 55.7369 - learning_rate: 0.0010
# Epoch 229/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 30.6761 - mean_absolute_error: 31.6629 - root_mean_squared_error: 44.5931 - val_loss: 56.2291 - val_mean_absolute_error: 57.9545 - val_root_mean_squared_error: 73.7506 - learning_rate: 0.0010
# Epoch 230/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 30.2338 - mean_absolute_error: 31.2008 - root_mean_squared_error: 46.1811 - val_loss: 43.8265 - val_mean_absolute_error: 46.3283 - val_root_mean_squared_error: 69.6124 - learning_rate: 0.0010
# Epoch 231/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 35.2268 - mean_absolute_error: 36.2998 - root_mean_squared_error: 51.0190 - val_loss: 55.0506 - val_mean_absolute_error: 57.8876 - val_root_mean_squared_error: 87.2488 - learning_rate: 0.0010
# Epoch 232/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 37.2858 - mean_absolute_error: 38.3439 - root_mean_squared_error: 55.6548 - val_loss: 39.3719 - val_mean_absolute_error: 41.2947 - val_root_mean_squared_error: 60.7739 - learning_rate: 0.0010
# Epoch 233/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 27.7360 - mean_absolute_error: 28.6765 - root_mean_squared_error: 40.3083 - val_loss: 43.5869 - val_mean_absolute_error: 45.2896 - val_root_mean_squared_error: 64.0410 - learning_rate: 0.0010
# Epoch 234/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 28.4046 - mean_absolute_error: 29.3575 - root_mean_squared_error: 42.1247 - val_loss: 90.2100 - val_mean_absolute_error: 92.0491 - val_root_mean_squared_error: 108.7327 - learning_rate: 0.0010
# Epoch 235/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 32.3787 - mean_absolute_error: 33.4053 - root_mean_squared_error: 49.1759 - val_loss: 36.9035 - val_mean_absolute_error: 39.0431 - val_root_mean_squared_error: 59.4988 - learning_rate: 0.0010
# Epoch 236/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 30.1837 - mean_absolute_error: 31.1536 - root_mean_squared_error: 46.0255 - val_loss: 67.5106 - val_mean_absolute_error: 69.3883 - val_root_mean_squared_error: 84.8870 - learning_rate: 0.0010
# Epoch 237/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 27.1010 - mean_absolute_error: 28.0294 - root_mean_squared_error: 40.6936 - val_loss: 37.1566 - val_mean_absolute_error: 39.1989 - val_root_mean_squared_error: 56.9319 - learning_rate: 0.0010
# Epoch 238/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 26.7686 - mean_absolute_error: 27.6738 - root_mean_squared_error: 41.4574 - val_loss: 57.6425 - val_mean_absolute_error: 61.1792 - val_root_mean_squared_error: 89.4675 - learning_rate: 0.0010
# Epoch 239/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 30.1929 - mean_absolute_error: 31.1562 - root_mean_squared_error: 46.0571 - val_loss: 35.8443 - val_mean_absolute_error: 37.3441 - val_root_mean_squared_error: 54.4988 - learning_rate: 0.0010
# Epoch 240/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 31.4589 - mean_absolute_error: 32.4451 - root_mean_squared_error: 46.2928 - val_loss: 38.6848 - val_mean_absolute_error: 39.8955 - val_root_mean_squared_error: 55.0190 - learning_rate: 0.0010
# Epoch 241/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 29.2305 - mean_absolute_error: 30.1919 - root_mean_squared_error: 45.7820 - val_loss: 48.4864 - val_mean_absolute_error: 49.4565 - val_root_mean_squared_error: 64.1078 - learning_rate: 0.0010
# Epoch 242/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 36.2477 - mean_absolute_error: 37.3374 - root_mean_squared_error: 51.5512 - val_loss: 45.9121 - val_mean_absolute_error: 48.3475 - val_root_mean_squared_error: 68.7536 - learning_rate: 0.0010
# Epoch 243/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 28.3343 - mean_absolute_error: 29.2973 - root_mean_squared_error: 42.4543 - val_loss: 40.8066 - val_mean_absolute_error: 43.1485 - val_root_mean_squared_error: 59.2523 - learning_rate: 0.0010
# Epoch 244/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 29.7568 - mean_absolute_error: 30.7461 - root_mean_squared_error: 41.4139 - val_loss: 45.7620 - val_mean_absolute_error: 47.0925 - val_root_mean_squared_error: 66.8069 - learning_rate: 0.0010
# Epoch 245/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 27.7549 - mean_absolute_error: 28.6826 - root_mean_squared_error: 43.0175 - val_loss: 39.4892 - val_mean_absolute_error: 41.7201 - val_root_mean_squared_error: 61.8220 - learning_rate: 0.0010
# Epoch 246/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 33.6880 - mean_absolute_error: 34.7092 - root_mean_squared_error: 51.3582 - val_loss: 131.5208 - val_mean_absolute_error: 134.4280 - val_root_mean_squared_error: 148.2393 - learning_rate: 0.0010
# Epoch 247/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 32.0531 - mean_absolute_error: 33.0273 - root_mean_squared_error: 48.5705 - val_loss: 53.5538 - val_mean_absolute_error: 54.7501 - val_root_mean_squared_error: 68.8412 - learning_rate: 0.0010
# Epoch 248/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 31.6715 - mean_absolute_error: 32.6922 - root_mean_squared_error: 43.8131 - val_loss: 37.6053 - val_mean_absolute_error: 39.6893 - val_root_mean_squared_error: 58.6904 - learning_rate: 0.0010
# Epoch 249/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 27.7993 - mean_absolute_error: 28.7478 - root_mean_squared_error: 41.5593 - val_loss: 40.0458 - val_mean_absolute_error: 41.5114 - val_root_mean_squared_error: 57.8152 - learning_rate: 0.0010
# Epoch 250/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 30.4154 - mean_absolute_error: 31.4137 - root_mean_squared_error: 45.4666 - val_loss: 39.8922 - val_mean_absolute_error: 42.3926 - val_root_mean_squared_error: 63.5398 - learning_rate: 0.0010
# Epoch 251/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 30.1995 - mean_absolute_error: 31.1777 - root_mean_squared_error: 45.3172 - val_loss: 48.8635 - val_mean_absolute_error: 50.1734 - val_root_mean_squared_error: 66.5304 - learning_rate: 0.0010
# Epoch 252/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 28.6908 - mean_absolute_error: 29.6333 - root_mean_squared_error: 44.7201 - val_loss: 36.4650 - val_mean_absolute_error: 38.5033 - val_root_mean_squared_error: 55.9190 - learning_rate: 0.0010
# Epoch 253/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 28.2444 - mean_absolute_error: 29.1948 - root_mean_squared_error: 41.3857 - val_loss: 48.6428 - val_mean_absolute_error: 51.0552 - val_root_mean_squared_error: 71.1625 - learning_rate: 0.0010
# Epoch 254/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 29.0353 - mean_absolute_error: 30.0132 - root_mean_squared_error: 45.3428 - val_loss: 49.1699 - val_mean_absolute_error: 50.9802 - val_root_mean_squared_error: 69.7060 - learning_rate: 0.0010
# Epoch 255/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 30.6230 - mean_absolute_error: 31.5951 - root_mean_squared_error: 45.0132 - val_loss: 36.9985 - val_mean_absolute_error: 39.1582 - val_root_mean_squared_error: 57.2358 - learning_rate: 0.0010
# Epoch 256/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 29.3151 - mean_absolute_error: 30.2848 - root_mean_squared_error: 45.3282 - val_loss: 36.9273 - val_mean_absolute_error: 38.6530 - val_root_mean_squared_error: 57.0577 - learning_rate: 0.0010
# Epoch 257/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 28.8290 - mean_absolute_error: 29.7741 - root_mean_squared_error: 42.0873 - val_loss: 36.0643 - val_mean_absolute_error: 38.1049 - val_root_mean_squared_error: 54.6832 - learning_rate: 0.0010
# Epoch 258/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 26.2186 - mean_absolute_error: 27.1289 - root_mean_squared_error: 40.9452 - val_loss: 84.5760 - val_mean_absolute_error: 85.8258 - val_root_mean_squared_error: 99.3835 - learning_rate: 0.0010
# Epoch 259/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 28.1963 - mean_absolute_error: 29.1459 - root_mean_squared_error: 43.4895 - val_loss: 47.2937 - val_mean_absolute_error: 48.4899 - val_root_mean_squared_error: 62.5518 - learning_rate: 0.0010
# Epoch 260/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 30.3191 - mean_absolute_error: 31.3116 - root_mean_squared_error: 45.2632 - val_loss: 47.3072 - val_mean_absolute_error: 49.5573 - val_root_mean_squared_error: 71.8199 - learning_rate: 0.0010
# Epoch 261/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 29.9416 - mean_absolute_error: 30.9156 - root_mean_squared_error: 43.3566 - val_loss: 69.3129 - val_mean_absolute_error: 70.3814 - val_root_mean_squared_error: 85.2545 - learning_rate: 0.0010
# Epoch 262/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 28.8610 - mean_absolute_error: 29.8098 - root_mean_squared_error: 44.9708 - val_loss: 51.8456 - val_mean_absolute_error: 52.2548 - val_root_mean_squared_error: 65.7327 - learning_rate: 0.0010
# Epoch 263/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 26.5376 - mean_absolute_error: 27.4512 - root_mean_squared_error: 40.1416 - val_loss: 41.3331 - val_mean_absolute_error: 43.0333 - val_root_mean_squared_error: 63.1093 - learning_rate: 0.0010
# Epoch 264/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 24.5138 - mean_absolute_error: 25.3881 - root_mean_squared_error: 38.2050 - val_loss: 67.8204 - val_mean_absolute_error: 68.6730 - val_root_mean_squared_error: 80.2298 - learning_rate: 0.0010
# Epoch 265/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 24.9208 - mean_absolute_error: 25.8162 - root_mean_squared_error: 38.2069 - val_loss: 77.2513 - val_mean_absolute_error: 78.7220 - val_root_mean_squared_error: 90.5501 - learning_rate: 0.0010
# Epoch 266/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 27.7532 - mean_absolute_error: 28.6882 - root_mean_squared_error: 40.8075 - val_loss: 61.2839 - val_mean_absolute_error: 62.4169 - val_root_mean_squared_error: 75.7224 - learning_rate: 0.0010
# Epoch 267/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 29.0003 - mean_absolute_error: 29.9389 - root_mean_squared_error: 45.0966 - val_loss: 55.7744 - val_mean_absolute_error: 56.2890 - val_root_mean_squared_error: 70.2534 - learning_rate: 0.0010
# Epoch 268/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 29.4005 - mean_absolute_error: 30.3668 - root_mean_squared_error: 43.2183 - val_loss: 47.8172 - val_mean_absolute_error: 49.9146 - val_root_mean_squared_error: 70.5337 - learning_rate: 0.0010
# Epoch 269/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 29.7056 - mean_absolute_error: 30.6998 - root_mean_squared_error: 42.6375 - val_loss: 38.0008 - val_mean_absolute_error: 40.1266 - val_root_mean_squared_error: 60.3929 - learning_rate: 0.0010
# Epoch 270/270
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 31.3820 - mean_absolute_error: 32.4060 - root_mean_squared_error: 49.3402 - val_loss: 42.9791 - val_mean_absolute_error: 45.2682 - val_root_mean_squared_error: 68.7085 - learning_rate: 0.0010
# *********** Benchmark results ***********
#
# R2    (Train/Test) = 0.889 / 0.874
# RMSE  (Train/Test) = 65.405 / 68.708
# Huber (Train/Test) = 42.679 / 44.774
# Train: rmse (mean of 1 models)= 65.40534210205078
# Test: rmse (mean of 1 models)= 68.70845794677734
# Train: r2 (mean of 1 models)= 0.8893626175380954
# Test: r2 (mean of 1 models)= 0.8740212603118666
# Train: huber (mean of 1 models)= 42.67861557006836
# Test: huber (mean of 1 models)= 44.77351379394531

# %%
def plot_model_performance(mwd: ModelWithData):
    # undo log transformation for better interpretability
    x_train_label = mwd.train_label
    x_test_label = mwd.test_label
    y_train_predicted = mwd.train_predicted
    y_test_predicted = mwd.test_predicted
    
    # Create an array of x-values ranging from the minimum to maximum of the data
    x_values = np.linspace(min(x_train_label), max(x_train_label), 100)

    # Plot the line of equality (y=x)
    plt.plot(x_values, x_values, color='blue', linestyle='--', label='Y = X line')
    plt.grid(visible=True)

    # Scatter plot for predicted values
    plt.scatter(x_train_label, y_train_predicted, c='k', label='Train Labels')
    plt.scatter(x_test_label, y_test_predicted, c='r', label='Test Labels')

    # Labels, legend, and title
    plt.xlabel('True Labels')
    plt.ylabel('Predicted Labels')
    plt.legend()
    plt.title('Scatter Plot of True vs Predicted Labels with Line of Equality')

    # Show the plot
    plt.show()

# %%
bestMwd = EMPTY_MWD

for mwd in all_mwds:
    if mwd.isBetter(bestMwd.score):
            bestMwd = mwd

    plot_model_performance(mwd)

# %%
plt.plot(bestMwd.history.history['loss'], label='Loss')
plt.plot(bestMwd.history.history['val_loss'], label='Validation Loss')

plt.yscale('log')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.grid(visible=True, which='both', axis='y')
plt.legend()
# ax2 = plt.gca().twinx()
# ax2.plot(bestMwd.history.history['learning_rate'], color='r')
# ax2.set_ylabel('Learning Rate',color='r')

Eval_of_model = plt.legend()

# %%
# undo log transformation for better interpretability
x_train_label = bestMwd.train_label
x_test_label = bestMwd.test_label
y_train_predicted = bestMwd.train_predicted
y_test_predicted = bestMwd.test_predicted

# Create an array of x-values ranging from the minimum to maximum of the data
x_values = np.linspace(min(labels), max(labels), 100)

# Plot the line of equality (y=x)
plt.plot(x_values, x_values, color='blue', linestyle='--', label='Y = X line')

# Scatter plot for predicted values
plt.scatter(x_train_label, y_train_predicted, c='k', label='Train Labels')
plt.scatter(x_test_label, y_test_predicted, c='r', label='Test Labels')

# Labels, legend, and title
plt.xlabel('True Labels')
plt.ylabel('Predicted Labels')
plt.legend()
plt.title('Scatter Plot of True vs Predicted Labels with Line of Equality')

# Show the plot
plt.show()

# %% [markdown]
# ## Save the model

# %%
bestMwd.model.save('dps1200sub_model.keras')

# %% [markdown]
# # Evaluation of the restored model

# %%
dps1200sub_model = tf.keras.models.load_model('dps1200sub_model.keras')

# Show the model architecture
dps1200sub_model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 410, 1)    │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d (Conv1D)     │ (None, 205, 64)   │        832 │ input_layer[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 205, 64)   │        256 │ conv1d[0][0]      │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 205, 64)   │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d       │ (None, 103, 64)   │          0 │ activation[0][0]  │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_1 (Conv1D)   │ (None, 103, 32)   │      2,048 │ max_pooling1d[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 103, 32)   │        128 │ conv1d_1[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 103, 32)   │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_2 (Conv1D)   │ (None, 103, 32)   │      3,072 │ activation_1[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_3 (Conv1D)   │ (None, 103, 64)   │     14,336 │ activation_1[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_4 (Conv1D)   │ (None, 103, 32)   │     11,264 │ activation_1[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 103, 128)  │          0 │ conv1d_2[0][0],   │
# │ (Concatenate)       │                   │            │ conv1d_3[0][0],   │
# │                     │                   │            │ conv1d_4[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_5 (Conv1D)   │ (None, 103, 128)  │     16,384 │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_6 (Conv1D)   │ (None, 103, 128)  │      8,192 │ max_pooling1d[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 103, 128)  │        512 │ conv1d_5[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 103, 128)  │        512 │ conv1d_6[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 103, 128)  │          0 │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 103, 128)  │          0 │ add[0][0]         │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_7 (Conv1D)   │ (None, 103, 32)   │      4,096 │ activation_2[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 103, 32)   │        128 │ conv1d_7[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 103, 32)   │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_8 (Conv1D)   │ (None, 103, 32)   │      3,072 │ activation_3[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_9 (Conv1D)   │ (None, 103, 64)   │     14,336 │ activation_3[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_10 (Conv1D)  │ (None, 103, 32)   │     11,264 │ activation_3[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 103, 128)  │          0 │ conv1d_8[0][0],   │
# │ (Concatenate)       │                   │            │ conv1d_9[0][0],   │
# │                     │                   │            │ conv1d_10[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_11 (Conv1D)  │ (None, 103, 128)  │     16,384 │ concatenate_1[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 103, 128)  │        512 │ conv1d_11[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 103, 128)  │          0 │ batch_normalizat… │
# │                     │                   │            │ activation_2[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 103, 128)  │          0 │ add_1[0][0]       │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d_1     │ (None, 52, 128)   │          0 │ activation_4[0][… │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_12 (Conv1D)  │ (None, 52, 64)    │      8,192 │ max_pooling1d_1[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 52, 64)    │        256 │ conv1d_12[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (None, 52, 64)    │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_13 (Conv1D)  │ (None, 52, 64)    │     12,288 │ activation_5[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_14 (Conv1D)  │ (None, 52, 128)   │     57,344 │ activation_5[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_15 (Conv1D)  │ (None, 52, 64)    │     45,056 │ activation_5[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 52, 256)   │          0 │ conv1d_13[0][0],  │
# │ (Concatenate)       │                   │            │ conv1d_14[0][0],  │
# │                     │                   │            │ conv1d_15[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_16 (Conv1D)  │ (None, 52, 256)   │     65,536 │ concatenate_2[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_17 (Conv1D)  │ (None, 52, 256)   │     32,768 │ max_pooling1d_1[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 52, 256)   │      1,024 │ conv1d_16[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 52, 256)   │      1,024 │ conv1d_17[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 52, 256)   │          0 │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_6        │ (None, 52, 256)   │          0 │ add_2[0][0]       │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_18 (Conv1D)  │ (None, 52, 64)    │     16,384 │ activation_6[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 52, 64)    │        256 │ conv1d_18[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_7        │ (None, 52, 64)    │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_19 (Conv1D)  │ (None, 52, 64)    │     12,288 │ activation_7[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_20 (Conv1D)  │ (None, 52, 128)   │     57,344 │ activation_7[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_21 (Conv1D)  │ (None, 52, 64)    │     45,056 │ activation_7[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 52, 256)   │          0 │ conv1d_19[0][0],  │
# │ (Concatenate)       │                   │            │ conv1d_20[0][0],  │
# │                     │                   │            │ conv1d_21[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_22 (Conv1D)  │ (None, 52, 256)   │     65,536 │ concatenate_3[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 52, 256)   │      1,024 │ conv1d_22[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 52, 256)   │          0 │ batch_normalizat… │
# │                     │                   │            │ activation_6[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_8        │ (None, 52, 256)   │          0 │ add_3[0][0]       │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d_2     │ (None, 26, 256)   │          0 │ activation_8[0][… │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 256)       │          0 │ max_pooling1d_2[… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 64)        │     16,448 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ age_output (Dense)  │ (None, 1)         │         65 │ dense[0][0]       │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 1,630,021 (6.22 MB)
#  Trainable params: 542,401 (2.07 MB)
#  Non-trainable params: 2,816 (11.00 KB)
#  Optimizer params: 1,084,804 (4.14 MB)

# %%
def error_metrices_restored_model(y_true, y_predicted):
    rmse_train = np.sqrt(mean_squared_error(y_true, y_predicted))
    R2_train= r2_score(y_true, y_predicted)
    h = tf.keras.losses.Huber()
    hub_train = h(y_true, y_predicted).numpy()
    
    print('*********** Benchmark results ***********\n')
    print(f"R2    = {R2_train:.3f}")
    print(f"RMSE  = {rmse_train:.3f}")
    print(f"Huber = {hub_train:.3f}")

# %%
restored_pred = dps1200sub_model.predict(features, verbose=0)

# %%
error_metrices_restored_model(labels, restored_pred)
# Out:
# *********** Benchmark results ***********
#
# R2    = 0.888
# RMSE  = 65.733
# Huber = 42.882
